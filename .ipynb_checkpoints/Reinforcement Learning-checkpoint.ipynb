# %%
# Imports
import gym
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt

from dataclasses import dataclass
from typing import List, Dict
import numpy as np
from abc import ABC, abstractmethod

from edinburgh_challenge.constants import police_stations
from edinburgh_challenge.simulation import SimulationWithMaxUtilisation
from edinburgh_challenge.models import NaiveModel

# %%
source = "./data.xlsx"

# %%
data = pd.read_excel(source)
data["Time"] = (data["Day"]-1)*24 + data["Hour"]
data.columns = [x.lower() for x in data.columns]

# %% [markdown]
# ## Simulation Environment

# %% [markdown]
# ## Models

# %%
shift_distribution = {
    'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3': 5},
    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}
}

ps_coords = [ (p.x, p.y) for p in 
                [police_stations.one, 
                 police_stations.two, 
                 police_stations.three]]
num_officers_per_station = [4, 5, 6]
simulation = SimulationWithMaxUtilisation(data, ps_coords, shift_distribution, 
                        verbose=1)

# %% [markdown]
# ## Reinforcement Learning

# %%
import gym
from gym import spaces

class SimulationEnv(gym.Env):
    """
    A gym wrapper for the RLEnvironmentModified class to make it compatible with gym.
    """
    def __init__(self, simulation):
        
        
        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions:
        self.action_space = spaces.Discrete(len(self.env.action_space))
        # Example for using image as input:
        self.observation_space = spaces.Box(low=0, high=255, shape=(HEIGHT, WIDTH, CHANNELS), dtype=np.uint8)

    def step(self, action):
        return self.env.step(action)

    def reset(self):
        return self.env.reset()

    def render(self, mode='human'):
        pass  # You can add rendering logic here if needed

    def close(self):
        pass  # Implement any cleanup necessary

# Usage example:
# simulation_instance = SimulationWithMaxUtilisation(...)
# gym_env = RLGymWrapper(simulation_instance)

# %%
class SimulationWithMaxUtilisation:
    SPEED_MPH = 30  # Speed in miles per hour

    def __init__(self, df: pd.DataFrame, station_coords: List[tuple], shift_distribution: ShiftDistribution, verbose:int=0):
        self.df = df.copy()
        self.station_coords = station_coords
        self.shift_distribution = shift_distribution
        self.current_time = 0
        self.officers = { key: [] for key in shift_distribution["Early"].keys() } # Station_1, Station_2 and Station_3
        self.verbose = verbose

        self.timesteps = [0]
        self.completed_hours = []
        
        self.return_times = [] # array keeps a track of return times of officers
        self.done = False
        # This resolved incidents is made to keep a track of when an incident
        # is allocated to an officer. This is to conduct the evaluating model check
        self.resolved_incidents = [] # This list keeps a track and order of the resolved incidents as they are allocated
        self.cumulative_incidents = []  # Global list to track all incidents
        
        # Making the df compatible with data structures
        df.columns = [x.lower() for x in df.columns]
        

    def print_dashboard(self, allocations):
        print(f"\n--- Day {self.current_time // 24 + 1}, Hour {self.current_time % 24} ---")
        pending_cases = [inc for inc in self.cumulative_incidents if not inc.resolved]
        print(f"Pending Cases: {len(pending_cases)}")
        print("Pending Incident URNs:", [inc.urn for inc in pending_cases])

        inv_allocations = {v: k for k, v in allocations.items()}
        
        for station, officers in self.officers.items():
            print(f"\n{station}:")
            for officer in officers:
                # Find the incident the officer is currently assigned to
                if officer.name in inv_allocations.keys():
                    status = inv_allocations[officer.name]
                else: 
                    status = "Busy"
                print(f"  - {officer.name}: {status}")
        
    def calculate_distance(self, lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between two points 
        on the earth (specified in decimal degrees)
        """
        # Convert decimal degrees to radians 
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

        # Haversine formula 
        dlat = lat2 - lat1 
        dlon = lon2 - lon1 
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a)) 
        r = 3956  # Radius of Earth in miles. Use 6371 for kilometers
        return c * r

    def generate_incidents_for_hour(self, global_time):
        hour_incidents = self.df[(self.df['time'] == global_time)]
        incidents = []
        for _, row in hour_incidents.iterrows():
            deployment_time = row.pop("deployment time (hrs)")
            row.pop("time")  # Not needed as we use global_time
            distances = {f'Station_{i+1}': self.calculate_distance(row['latitude'], row['longitude'], lat, lon) 
                         for i, (lat, lon) in enumerate(self.station_coords)}
            incidents.append(Incident(**row, 
                                      deployment_time=deployment_time, 
                                      distances=distances,
                                      global_time=global_time))
        return incidents


    def update_officers_for_shift(self, shift):
        for station, num_officers in self.shift_distribution[shift].items():
            # Update the number of officers for each station
            self.officers[station] = [Officer(f"Officer_{station}_{shift}_{i}", station=station) for i in range(num_officers)]

    def process_allocations(self, allocations):
        if self.verbose > 0:
            print(f"{allocations=}")
        for urn, officer_id in allocations.items():
            incident = next((inc for inc in self.cumulative_incidents if inc.urn == urn), None)
            #print("incident:", incident)
            if officer_id is None:
                if incident:
                    incident.resolved = False
                continue

            officer = next((off for station_officers in self.officers.values() for off in station_officers if off.name == officer_id), None)
            if incident and officer:
                travel_time = incident.distances[officer.station] / self.SPEED_MPH
                officer.available = False  # Mark officer as busy
                officer.return_time = self.current_time + travel_time + incident.deployment_time

                self.timesteps.append(officer.return_time)
                self.return_times.append(officer.return_time)
            
                incident.resolved = True  # Mark incident as resolved
                incident.resolving_officer = officer.name  # Assign officer to incident
                incident.response_time = self.current_time + travel_time # Global time when the response reached
                incident.resolution_time = officer.return_time # Global Time when the incident was resolved
                self.resolved_incidents.append(incident)
                

    def set_next_time(self):
        self.timesteps = self.timesteps.sort()
        self.timesteps = 
    
    def update_officer_availability(self):
        for station, officers in self.officers.items():
            for officer in officers:
                if not officer.available and self.current_time >= officer.return_time:
                    officer.available = True

    
    def get_return_times_for_next_hour(self):
        global_time = self.current_time
        return_times_for_next_hour = [rt for rt in self.return_times if rt <= global_time + 1]
        return sorted(return_times_for_next_hour)
                    
                    
    def step(self, model):
        
        if self.done:
            return {} # For a week-long simulation
        
        day = self.current_time // 24 + 1
        hour = self.current_time % 24
        
        # Update officer availability at the start of each timestep
        self.update_officer_availability()

        # Update officers for shift change
        if hour in [0, 8, 16]:
            shift = 'Early' if hour == 0 else 'Day' if hour == 8 else 'Night'
            #print(f"{shift=}")
            self.update_officers_for_shift(shift)
        
        total_officers = len(self.officers["Station_1"]) + len(self.officers["Station_2"]) + len(self.officers["Station_3"]) 
            
        # Generate and add new incidents
        new_incidents = self.generate_incidents_for_hour(self.current_time)
        self.cumulative_incidents.extend(new_incidents)
        
        # Filter to get only pending incidents
        pending_incidents = [inc for inc in self.cumulative_incidents if not inc.resolved]
        allocations = model.make_allocation(pending_incidents, self.officers, self.current_time)
        
        # Process allocations and update the state
        self.process_allocations(allocations)

        # After making the allocations for the hour
        # get to each return time of the officer
        # and make new allocations
        self.set_next_time()
        

        if self.verbose > 2:
            self.print_dashboard(allocations)
        
        
        # Pending cases after allocation
        pending_incidents = [inc for inc in self.cumulative_incidents if not inc.resolved]
        #print(f"{pending_incidents=}")
        
        #self.current_time += 1  # Move to the next hour
        self.hour_index += 1
        self.current_time = self.hours[self.hour_index]
        
        if self.verbose > 3:
            input("Press Enter to continue to the next hour...\n")
        #print()
        #print([inc.urn for inc in self.cumulative_incidents])
        #print("*"*50)
        done = self.current_time >= 24 * 7

    # Checks and Analysis
    def analyze_simulation_results(self):

        simulation = self
        
        # Initialize counters and accumulators
        incident_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        resolved_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        within_threshold_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        response_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        resolution_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        deployment_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        thresholds = {'Immediate': 1, 'Prompt': 3, 'Standard': 6}
        total_officer_hours = {}
        unresolved_incidents = 0
    
        # Analyze each incident
        for incident in simulation.cumulative_incidents:
            priority = incident.priority
            incident_counts[priority] += 1
    
            if incident.resolved:
                resolved_counts[priority] += 1
                
                response_time = incident.response_time
                resolution_time = incident.resolution_time
                
                response_times[priority].append(response_time)
                resolution_times[priority].append(resolution_time)
                
                deployment_time = incident.deployment_time
                deployment_times[priority].append(deployment_time)
                
                if incident.resolving_officer not in total_officer_hours.keys():
                    total_officer_hours[incident.resolving_officer]  = 0
                
                time_spent_on_incident = incident.resolution_time - incident.global_time
                total_officer_hours[incident.resolving_officer] += time_spent_on_incident
                
                # Calculate the time from incident report to response arrival
                time_to_response = incident.response_time - incident.global_time
    
    
                # Check if the response was within the threshold
                if time_to_response <= thresholds[priority]:
                    within_threshold_counts[priority] += 1
            else:
                unresolved_incidents += 1
    
        # Calculate percentages and mean times
        completion_percentages = {p: (resolved_counts[p] / incident_counts[p]) * 100 if incident_counts[p] > 0 else 0 for p in incident_counts}
        mean_response_times = {p: np.mean(response_times[p]) if response_times[p] else 0 for p in response_times}
        mean_deployment_times = {p: np.mean(deployment_times[p]) if deployment_times[p] else 0 for p in deployment_times}
        threshold_compliance = {p: (within_threshold_counts[p] / resolved_counts[p]) * 100 if resolved_counts[p] > 0 else 0 for p in incident_counts}
    
        # Calculate officer utilization
        #for station in simulation.officers.values():
        #    for officer in station:
        #        if not officer.available:
        #            total_officer_hours[officer.name] += (simulation.current_time - officer.return_time)
        
        #officer_utilization = sum(total_officer_hours.values()) / (len(total_officer_hours) * simulation.current_time) * 100
        sum_total_office_hours = sum(total_officer_hours.values())
        unresolved_incident_percentage = (unresolved_incidents / len(simulation.cumulative_incidents)) * 100 if simulation.cumulative_incidents else 0
    
        return {
            "Completion Percentages": completion_percentages,
            "Mean Response Times": mean_response_times,
            "Mean Deployment Times": mean_deployment_times,
            "Threshold Compliance": threshold_compliance,
            #"Officer Utilization": officer_utilization,
            "Total Officer Hours": sum_total_office_hours, 
            "Unresolved Incident Percentage": unresolved_incident_percentage
        }

    def check_simulation(self):
        simulation = self
        # Initialize officer assignments based on all shifts
        officer_assignments = {}
        for shift, stations in shift_distribution.items():
            for station, num_officers in stations.items():
                for i in range(num_officers):
                    officer_name = f"Officer_{station}_{shift}_{i}"
                    officer_assignments[officer_name] = []
        
        incident_response = {'Immediate': {'total': 0, 'within_time': 0}, 
                             'Prompt': {'total': 0, 'within_time': 0}, 
                             'Standard': {'total': 0, 'within_time': 0}}
        
        time_travel_occurred = False
    
        for incident in simulation.resolved_incidents:
            if incident.resolved:
                # Check officer assignments and time traveling
                if incident.resolving_officer:
                    officer_assignments[incident.resolving_officer].append(incident.resolution_time)
                    if len(officer_assignments[incident.resolving_officer]) > 1:
                        if officer_assignments[incident.resolving_officer][-2] > incident.resolution_time:
                            #print(f"{officer_assignments[incident.resolving_officer]=}")
                            #print(f"{incident.resolving_officer=}")
                            time_travel_occurred = True
    
                # Count incidents and check response time
                incident_response[incident.priority]['total'] += 1
                target_time = {'Immediate': 1, 'Prompt': 3, 'Standard': 6}[incident.priority]
                if incident.response_time - incident.global_time <= target_time:
                    incident_response[incident.priority]['within_time'] += 1
    
        # Calculate percentages
        for priority in incident_response:
            total = incident_response[priority]['total']
            if total > 0:
                incident_response[priority]['percentage'] = (incident_response[priority]['within_time'] / total) * 100
            else:
                incident_response[priority]['percentage'] = 0
    
        return officer_assignments, incident_response, time_travel_occurred
# Out:
#   Cell In[16], line 109
#     self.timesteps =
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Shift allocation

# %%
class Model(ABC):
    @abstractmethod
    def make_allocation(self, incidents, officers, current_time):
        pass

@dataclass
class Incident:
    urn: str
    latitude: float
    longitude: float
    day:int
    hour:int
    global_time: float  # Time at which the incident was reported (24*day + hour)
    deployment_time: float  # Time taken to resolve the incident after reaching the location
    priority: str
    distances: Dict[str, float]  # Distances from each station
    resolved: bool = False
    resolving_officer: str = None
    response_time: float = None  # Global time when the response arrives at the scene
    resolution_time: float = None  # Global time when the incident is resolved

@dataclass
class Officer:
    name: str
    station: str
    available: bool = True
    return_time: float = 0.0
        
from typing import Dict, List

# Shift distribution structure
# Example: {'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3': 5}, ...}
ShiftDistribution = Dict[str, Dict[str, int]]

# %%
from math import radians, cos, sin, asin, sqrt

class SimulationWithMaxUtilisation:
    SPEED_MPH = 30  # Speed in miles per hour

    def __init__(self, df: pd.DataFrame, station_coords: List[tuple], shift_distribution: ShiftDistribution, verbose:int=0):
        self.df = df.copy()
        self.station_coords = station_coords
        self.shift_distribution = shift_distribution
        self.current_time = 0
        self.officers = { key: [] for key in shift_distribution["Early"].keys() } # Station_1, Station_2 and Station_3
        self.verbose = verbose
        self.hours = [i for i in range(24*7 + 1)]
        self.hour_index = 0
        self.return_times = [] # array keeps a track of return times of officers

        # This resolved incidents is made to keep a track of when an incident
        # is allocated to an officer. This is to conduct the evaluating model check
        self.resolved_incidents = [] # This list keeps a track and order of the resolved incidents as they are allocated
    
        
        # Making the df compatible with data structures
        df.columns = [x.lower() for x in df.columns]
        

    def print_dashboard(self, allocations):
        print(f"\n--- Day {self.current_time // 24 + 1}, Hour {self.current_time % 24} ---")
        pending_cases = [inc for inc in self.cumulative_incidents if not inc.resolved]
        print(f"Pending Cases: {len(pending_cases)}")
        print("Pending Incident URNs:", [inc.urn for inc in pending_cases])

        inv_allocations = {v: k for k, v in allocations.items()}
        
        for station, officers in self.officers.items():
            print(f"\n{station}:")
            for officer in officers:
                # Find the incident the officer is currently assigned to
                if officer.name in inv_allocations.keys():
                    status = inv_allocations[officer.name]
                else: 
                    status = "Busy"
                print(f"  - {officer.name}: {status}")
        
    def calculate_distance(self, lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between two points 
        on the earth (specified in decimal degrees)
        """
        # Convert decimal degrees to radians 
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

        # Haversine formula 
        dlat = lat2 - lat1 
        dlon = lon2 - lon1 
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a)) 
        r = 3956  # Radius of Earth in miles. Use 6371 for kilometers
        return c * r

    def generate_incidents_for_hour(self, global_time):
        hour_incidents = self.df[(self.df['time'] == global_time)]
        incidents = []
        for _, row in hour_incidents.iterrows():
            deployment_time = row.pop("deployment time (hrs)")
            row.pop("time")  # Not needed as we use global_time
            distances = {f'Station_{i+1}': self.calculate_distance(row['latitude'], row['longitude'], lat, lon) 
                         for i, (lat, lon) in enumerate(self.station_coords)}
            incidents.append(Incident(**row, 
                                      deployment_time=deployment_time, 
                                      distances=distances,
                                      global_time=global_time))
        return incidents


    def update_officers_for_shift(self, shift):
        for station, num_officers in self.shift_distribution[shift].items():
            # Update the number of officers for each station
            self.officers[station] = [Officer(f"Officer_{station}_{shift}_{i}", station=station) for i in range(num_officers)]

    def process_allocations(self, allocations):
        if self.verbose > 0:
            print(f"{allocations=}")
        for urn, officer_id in allocations.items():
            incident = next((inc for inc in self.cumulative_incidents if inc.urn == urn), None)
            #print("incident:", incident)
            if officer_id is None:
                if incident:
                    incident.resolved = False
                continue

            officer = next((off for station_officers in self.officers.values() for off in station_officers if off.name == officer_id), None)
            if incident and officer:
                travel_time = incident.distances[officer.station] / self.SPEED_MPH
                officer.available = False  # Mark officer as busy
                officer.return_time = self.current_time + travel_time + incident.deployment_time
                
                self.return_times.append(officer.return_time)
            
                incident.resolved = True  # Mark incident as resolved
                incident.resolving_officer = officer.name  # Assign officer to incident
                incident.response_time = self.current_time + travel_time # Global time when the response reached
                incident.resolution_time = officer.return_time # Global Time when the incident was resolved
                self.resolved_incidents.append(incident)
                

                
    def update_officer_availability(self):
        for station, officers in self.officers.items():
            for officer in officers:
                if not officer.available and self.current_time >= officer.return_time:
                    officer.available = True

    
    def get_return_times_for_next_hour(self):
        global_time = self.current_time
        return_times_for_next_hour = [rt for rt in self.return_times if rt <= global_time + 1]
        return sorted(return_times_for_next_hour)
                    
                    
    def run(self, model):
        self.cumulative_incidents = []  # Global list to track all incidents

        while self.current_time < 24 * 7:  # For a week-long simulation
            
            day = self.current_time // 24 + 1
            hour = self.current_time % 24
            
            # Update officer availability at the start of each timestep
            self.update_officer_availability()

            # Update officers for shift change
            if hour in [0, 8, 16]:
                shift = 'Early' if hour == 0 else 'Day' if hour == 8 else 'Night'
                self.update_officers_for_shift(shift)
            
            total_officers = len(self.officers["Station_1"]) + len(self.officers["Station_2"]) + len(self.officers["Station_3"]) 
            #print(f"{total_officers=}")
                
            # Generate and add new incidents
            new_incidents = self.generate_incidents_for_hour(self.current_time)
            self.cumulative_incidents.extend(new_incidents)
            
            # Filter to get only pending incidents
            allocations = model.make_allocation(pending_incidents, self.officers, self.current_time)
            
            # Process allocations and update the state
            self.process_allocations(allocations)
            
            # After making the allocations for the hour
            # get to each return time of the officer
            # and make new allocations
            return_times_within_hour = self.get_return_times_for_next_hour()
            #print(f"{self.current_time=} {return_times_within_hour=}")
            
            for time in return_times_within_hour:
                self.current_time = time
                
                self.update_officer_availability()
                pending_incidents = [inc for inc in self.cumulative_incidents if not inc.resolved]
                allocations = model.make_allocation(pending_incidents, self.officers, self.current_time)
                # Process allocations and update the state
                self.process_allocations(allocations)
                self.return_times.remove(time)
                
                

            if self.verbose > 2:
                self.print_dashboard(allocations)
            
            
            # Pending cases after allocation
            pending_incidents = [inc for inc in self.cumulative_incidents if not inc.resolved]
            #print(f"{pending_incidents=}")
            
            #self.current_time += 1  # Move to the next hour
            self.hour_index += 1
            self.current_time = self.hours[self.hour_index]
            
            if self.verbose > 3:
                input("Press Enter to continue to the next hour...\n")
            #print()
            #print([inc.urn for inc in self.cumulative_incidents])
            #print("*"*50)

    # Checks and Analysis
    def analyze_simulation_results(self):

        simulation = self
        
        # Initialize counters and accumulators
        incident_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        resolved_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        within_threshold_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        response_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        resolution_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        deployment_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        thresholds = {'Immediate': 1, 'Prompt': 3, 'Standard': 6}
        total_officer_hours = {}
        unresolved_incidents = 0
    
        # Analyze each incident
        for incident in simulation.cumulative_incidents:
            priority = incident.priority
            incident_counts[priority] += 1
    
            if incident.resolved:
                resolved_counts[priority] += 1
                
                response_time = incident.response_time
                resolution_time = incident.resolution_time
                
                response_times[priority].append(response_time)
                resolution_times[priority].append(resolution_time)
                
                deployment_time = incident.deployment_time
                deployment_times[priority].append(deployment_time)
                
                if incident.resolving_officer not in total_officer_hours.keys():
                    total_officer_hours[incident.resolving_officer]  = 0
                
                time_spent_on_incident = incident.resolution_time - incident.global_time
                total_officer_hours[incident.resolving_officer] += time_spent_on_incident
                
                # Calculate the time from incident report to response arrival
                time_to_response = incident.response_time - incident.global_time
    
    
                # Check if the response was within the threshold
                if time_to_response <= thresholds[priority]:
                    within_threshold_counts[priority] += 1
            else:
                unresolved_incidents += 1
    
        # Calculate percentages and mean times
        completion_percentages = {p: (resolved_counts[p] / incident_counts[p]) * 100 if incident_counts[p] > 0 else 0 for p in incident_counts}
        mean_response_times = {p: np.mean(response_times[p]) if response_times[p] else 0 for p in response_times}
        mean_deployment_times = {p: np.mean(deployment_times[p]) if deployment_times[p] else 0 for p in deployment_times}
        threshold_compliance = {p: (within_threshold_counts[p] / resolved_counts[p]) * 100 if resolved_counts[p] > 0 else 0 for p in incident_counts}
    
        # Calculate officer utilization
        #for station in simulation.officers.values():
        #    for officer in station:
        #        if not officer.available:
        #            total_officer_hours[officer.name] += (simulation.current_time - officer.return_time)
        
        #officer_utilization = sum(total_officer_hours.values()) / (len(total_officer_hours) * simulation.current_time) * 100
        sum_total_office_hours = sum(total_officer_hours.values())
        unresolved_incident_percentage = (unresolved_incidents / len(simulation.cumulative_incidents)) * 100 if simulation.cumulative_incidents else 0
    
        return {
            "Completion Percentages": completion_percentages,
            "Mean Response Times": mean_response_times,
            "Mean Deployment Times": mean_deployment_times,
            "Threshold Compliance": threshold_compliance,
            #"Officer Utilization": officer_utilization,
            "Total Officer Hours": sum_total_office_hours, 
            "Unresolved Incident Percentage": unresolved_incident_percentage
        }

    def check_simulation(self):
        simulation = self
        # Initialize officer assignments based on all shifts
        officer_assignments = {}
        for shift, stations in shift_distribution.items():
            for station, num_officers in stations.items():
                for i in range(num_officers):
                    officer_name = f"Officer_{station}_{shift}_{i}"
                    officer_assignments[officer_name] = []
        
        incident_response = {'Immediate': {'total': 0, 'within_time': 0}, 
                             'Prompt': {'total': 0, 'within_time': 0}, 
                             'Standard': {'total': 0, 'within_time': 0}}
        
        time_travel_occurred = False
    
        for incident in simulation.resolved_incidents:
            if incident.resolved:
                # Check officer assignments and time traveling
                if incident.resolving_officer:
                    officer_assignments[incident.resolving_officer].append(incident.resolution_time)
                    if len(officer_assignments[incident.resolving_officer]) > 1:
                        if officer_assignments[incident.resolving_officer][-2] > incident.resolution_time:
                            #print(f"{officer_assignments[incident.resolving_officer]=}")
                            #print(f"{incident.resolving_officer=}")
                            time_travel_occurred = True
    
                # Count incidents and check response time
                incident_response[incident.priority]['total'] += 1
                target_time = {'Immediate': 1, 'Prompt': 3, 'Standard': 6}[incident.priority]
                if incident.response_time - incident.global_time <= target_time:
                    incident_response[incident.priority]['within_time'] += 1
    
        # Calculate percentages
        for priority in incident_response:
            total = incident_response[priority]['total']
            if total > 0:
                incident_response[priority]['percentage'] = (incident_response[priority]['within_time'] / total) * 100
            else:
                incident_response[priority]['percentage'] = 0
    
        return officer_assignments, incident_response, time_travel_occurred

# %%
from math import radians, cos, sin, asin, sqrt

class SimulationWithMaxUtilisation:
    SPEED_MPH = 30  # Speed in miles per hour

    def __init__(self, df: pd.DataFrame, station_coords: List[tuple], shift_distribution: ShiftDistribution, verbose:int=0):
        self.df = df.copy()
        self.station_coords = station_coords
        self.shift_distribution = shift_distribution
        self.current_time = 0
        self.officers = { key: [] for key in shift_distribution["Early"].keys() } # Station_1, Station_2 and Station_3
        self.verbose = verbose
        self.hours = [i for i in range(24*7 + 1)]
        self.hour_index = 0
        self.return_times = [] # array keeps a track of return times of officers

        # This resolved incidents is made to keep a track of when an incident
        # is allocated to an officer. This is to conduct the evaluating model check
        self.resolved_incidents = [] # This list keeps a track and order of the resolved incidents as they are allocated
    
        
        # Making the df compatible with data structures
        df.columns = [x.lower() for x in df.columns]
        

    def print_dashboard(self, allocations):
        print(f"\n--- Day {self.current_time // 24 + 1}, Hour {self.current_time % 24} ---")
        pending_cases = [inc for inc in self.cumulative_incidents if not inc.resolved]
        print(f"Pending Cases: {len(pending_cases)}")
        print("Pending Incident URNs:", [inc.urn for inc in pending_cases])

        inv_allocations = {v: k for k, v in allocations.items()}
        
        for station, officers in self.officers.items():
            print(f"\n{station}:")
            for officer in officers:
                # Find the incident the officer is currently assigned to
                if officer.name in inv_allocations.keys():
                    status = inv_allocations[officer.name]
                else: 
                    status = "Busy"
                print(f"  - {officer.name}: {status}")
        
    def calculate_distance(self, lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between two points 
        on the earth (specified in decimal degrees)
        """
        # Convert decimal degrees to radians 
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

        # Haversine formula 
        dlat = lat2 - lat1 
        dlon = lon2 - lon1 
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a)) 
        r = 3956  # Radius of Earth in miles. Use 6371 for kilometers
        return c * r

    def generate_incidents_for_hour(self, global_time):
        hour_incidents = self.df[(self.df['time'] == global_time)]
        incidents = []
        for _, row in hour_incidents.iterrows():
            deployment_time = row.pop("deployment time (hrs)")
            row.pop("time")  # Not needed as we use global_time
            distances = {f'Station_{i+1}': self.calculate_distance(row['latitude'], row['longitude'], lat, lon) 
                         for i, (lat, lon) in enumerate(self.station_coords)}
            incidents.append(Incident(**row, 
                                      deployment_time=deployment_time, 
                                      distances=distances,
                                      global_time=global_time))
        return incidents


    def update_officers_for_shift(self, shift):
        for station, num_officers in self.shift_distribution[shift].items():
            # Update the number of officers for each station
            self.officers[station] = [Officer(f"Officer_{station}_{shift}_{i}", station=station) for i in range(num_officers)]

    def process_allocations(self, allocations):
        #print(f"{allocations}=")
        for urn, officer_id in allocations.items():
            incident = next((inc for inc in self.cumulative_incidents if inc.urn == urn), None)
            #print("incident:", incident)
            if officer_id is None:
                if incident:
                    incident.resolved = False
                continue

            officer = next((off for station_officers in self.officers.values() for off in station_officers if off.name == officer_id), None)
            if incident and officer:
                travel_time = incident.distances[officer.station] / self.SPEED_MPH
                officer.available = False  # Mark officer as busy
                officer.return_time = self.current_time + travel_time + incident.deployment_time
                
                self.return_times.append(officer.return_time)
            
                incident.resolved = True  # Mark incident as resolved
                incident.resolving_officer = officer.name  # Assign officer to incident
                incident.response_time = self.current_time + travel_time # Global time when the response reached
                incident.resolution_time = officer.return_time # Global Time when the incident was resolved
                self.resolved_incidents.append(incident)
                

                
    def update_officer_availability(self):
        for station, officers in self.officers.items():
            for officer in officers:
                if not officer.available and self.current_time >= officer.return_time:
                    officer.available = True

    
    def get_return_times_for_next_hour(self):
        global_time = self.current_time
        return_times_for_next_hour = [rt for rt in self.return_times if rt <= global_time + 1]
        return sorted(return_times_for_next_hour)
                    
                    
    def run(self, model):
        self.cumulative_incidents = []  # Global list to track all incidents

        while self.current_time < 24 * 7:  # For a week-long simulation
            
            day = self.current_time // 24 + 1
            hour = self.current_time % 24
            
            # Update officer availability at the start of each timestep
            self.update_officer_availability()

            # Update officers for shift change
            if hour in [0, 8, 16]:
                shift = 'Early' if hour == 0 else 'Day' if hour == 8 else 'Night'
                #print(f"{shift=}")
                self.update_officers_for_shift(shift)
            
            total_officers = len(self.officers["Station_1"]) + len(self.officers["Station_2"]) + len(self.officers["Station_3"]) 
            #print(f"{total_officers=}")
                
            # Generate and add new incidents
            new_incidents = self.generate_incidents_for_hour(self.current_time)
            self.cumulative_incidents.extend(new_incidents)
            
            # Filter to get only pending incidents
            pending_incidents = [inc for inc in self.cumulative_incidents if not inc.resolved]
            #print(f"{len(pending_incidents)=}")
            #print(f"{pending_incidents=}")
            # Call the model to allocate incidents
            #print(f"{self.officers=}")
            allocations = model.make_allocation(pending_incidents, self.officers, self.current_time)
            
            # Process allocations and update the state
            self.process_allocations(allocations)
            
            # After making the allocations for the hour
            # get to each return time of the officer
            # and make new allocations
            return_times_within_hour = self.get_return_times_for_next_hour()
            #print(f"{self.current_time=} {return_times_within_hour=}")
            
            for time in return_times_within_hour:
                self.current_time = time
                
                self.update_officer_availability()
                pending_incidents = [inc for inc in self.cumulative_incidents if not inc.resolved]
                allocations = model.make_allocation(pending_incidents, self.officers, self.current_time)
                # Process allocations and update the state
                self.process_allocations(allocations)
                self.return_times.remove(time)
                
                

            if self.verbose > 2:
                self.print_dashboard(allocations)
            
            
            # Pending cases after allocation
            pending_incidents = [inc for inc in self.cumulative_incidents if not inc.resolved]
            #print(f"{pending_incidents=}")
            
            #self.current_time += 1  # Move to the next hour
            self.hour_index += 1
            self.current_time = self.hours[self.hour_index]
            
            if self.verbose > 3:
                input("Press Enter to continue to the next hour...\n")
            #print()
            #print([inc.urn for inc in self.cumulative_incidents])
            #print("*"*50)

    # Checks and Analysis
    def analyze_simulation_results(self):

        simulation = self
        
        # Initialize counters and accumulators
        incident_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        resolved_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        within_threshold_counts = {'Immediate': 0, 'Prompt': 0, 'Standard': 0}
        response_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        resolution_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        deployment_times = {'Immediate': [], 'Prompt': [], 'Standard': []}
        thresholds = {'Immediate': 1, 'Prompt': 3, 'Standard': 6}
        total_officer_hours = {}
        unresolved_incidents = 0
    
        # Analyze each incident
        for incident in simulation.cumulative_incidents:
            priority = incident.priority
            incident_counts[priority] += 1
    
            if incident.resolved:
                resolved_counts[priority] += 1
                
                response_time = incident.response_time
                resolution_time = incident.resolution_time
                
                response_times[priority].append(response_time)
                resolution_times[priority].append(resolution_time)
                
                deployment_time = incident.deployment_time
                deployment_times[priority].append(deployment_time)
                
                if incident.resolving_officer not in total_officer_hours.keys():
                    total_officer_hours[incident.resolving_officer]  = 0
                
                time_spent_on_incident = incident.resolution_time - incident.global_time
                total_officer_hours[incident.resolving_officer] += time_spent_on_incident
                
                # Calculate the time from incident report to response arrival
                time_to_response = incident.response_time - incident.global_time
    
    
                # Check if the response was within the threshold
                if time_to_response <= thresholds[priority]:
                    within_threshold_counts[priority] += 1
            else:
                unresolved_incidents += 1
    
        # Calculate percentages and mean times
        completion_percentages = {p: (resolved_counts[p] / incident_counts[p]) * 100 if incident_counts[p] > 0 else 0 for p in incident_counts}
        mean_response_times = {p: np.mean(response_times[p]) if response_times[p] else 0 for p in response_times}
        mean_deployment_times = {p: np.mean(deployment_times[p]) if deployment_times[p] else 0 for p in deployment_times}
        threshold_compliance = {p: (within_threshold_counts[p] / resolved_counts[p]) * 100 if resolved_counts[p] > 0 else 0 for p in incident_counts}
    
        # Calculate officer utilization
        #for station in simulation.officers.values():
        #    for officer in station:
        #        if not officer.available:
        #            total_officer_hours[officer.name] += (simulation.current_time - officer.return_time)
        
        #officer_utilization = sum(total_officer_hours.values()) / (len(total_officer_hours) * simulation.current_time) * 100
        sum_total_office_hours = sum(total_officer_hours.values())
        unresolved_incident_percentage = (unresolved_incidents / len(simulation.cumulative_incidents)) * 100 if simulation.cumulative_incidents else 0
    
        return {
            "Completion Percentages": completion_percentages,
            "Mean Response Times": mean_response_times,
            "Mean Deployment Times": mean_deployment_times,
            "Threshold Compliance": threshold_compliance,
            #"Officer Utilization": officer_utilization,
            "Total Officer Hours": sum_total_office_hours, 
            "Unresolved Incident Percentage": unresolved_incident_percentage
        }

    def check_simulation(self):
        simulation = self
        # Initialize officer assignments based on all shifts
        officer_assignments = {}
        for shift, stations in shift_distribution.items():
            for station, num_officers in stations.items():
                for i in range(num_officers):
                    officer_name = f"Officer_{station}_{shift}_{i}"
                    officer_assignments[officer_name] = []
        
        incident_response = {'Immediate': {'total': 0, 'within_time': 0}, 
                             'Prompt': {'total': 0, 'within_time': 0}, 
                             'Standard': {'total': 0, 'within_time': 0}}
        
        time_travel_occurred = False
    
        for incident in simulation.resolved_incidents:
            if incident.resolved:
                # Check officer assignments and time traveling
                if incident.resolving_officer:
                    officer_assignments[incident.resolving_officer].append(incident.resolution_time)
                    if len(officer_assignments[incident.resolving_officer]) > 1:
                        if officer_assignments[incident.resolving_officer][-2] > incident.resolution_time:
                            #print(f"{officer_assignments[incident.resolving_officer]=}")
                            #print(f"{incident.resolving_officer=}")
                            time_travel_occurred = True
    
                # Count incidents and check response time
                incident_response[incident.priority]['total'] += 1
                target_time = {'Immediate': 1, 'Prompt': 3, 'Standard': 6}[incident.priority]
                if incident.response_time - incident.global_time <= target_time:
                    incident_response[incident.priority]['within_time'] += 1
    
        # Calculate percentages
        for priority in incident_response:
            total = incident_response[priority]['total']
            if total > 0:
                incident_response[priority]['percentage'] = (incident_response[priority]['within_time'] / total) * 100
            else:
                incident_response[priority]['percentage'] = 0
    
        return officer_assignments, incident_response, time_travel_occurred

# %%
shift_distribution = {
    'Early': {'Station_1': 0, 'Station_2': 0, 'Station_3': 0},
    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}
}

ps_coords = [ (p.x, p.y) for p in 
                [police_stations.one, 
                 police_stations.two, 
                 police_stations.three]]
num_officers_per_station = [4, 5, 6]
simulation = SimulationWithMaxUtilisation(data, ps_coords, shift_distribution, 
                        verbose=1)

# %%
simulation.run(naive_model)
simulation.analyze_simulation_results()
# Out:
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None}=
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0551': None, 'PS-20220709-0560': None, 'PS-20220709-0563': None, 'PS-20220709-0571': None, 'PS-20220709-0576': None, 'PS-20220709-0583': None, 'PS-20220709-0595': None, 'PS-20220711-0675': None, 'PS-20220711-0685': None, 'PS-20220711-0696': None, 'PS-20220711-0697': None, 'PS-20220711-0736': None, 'PS-20220711-0751': None, 'PS-20220711-0753': None, 'PS-20220711-0789': None, 'PS-20220711-0816': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None, 'PS-20220709-0561': None, 'PS-20220709-0584': None, 'PS-20220711-0773': None, 'PS-20220711-0785': None}=
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0551': None, 'PS-20220709-0560': None, 'PS-20220709-0563': None, 'PS-20220709-0571': None, 'PS-20220709-0576': None, 'PS-20220709-0583': None, 'PS-20220709-0595': None, 'PS-20220711-0675': None, 'PS-20220711-0685': None, 'PS-20220711-0696': None, 'PS-20220711-0697': None, 'PS-20220711-0736': None, 'PS-20220711-0751': None, 'PS-20220711-0753': None, 'PS-20220711-0789': None, 'PS-20220711-0816': None, 'PS-20220709-0607': None, 'PS-20220711-0817': None, 'PS-20220711-0833': None, 'PS-20220711-0840': None, 'PS-20220711-0847': None, 'PS-20220711-0858': None, 'PS-20220711-0870': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None, 'PS-20220709-0561': None, 'PS-20220709-0584': None, 'PS-20220711-0773': None, 'PS-20220711-0785': None}=
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0551': None, 'PS-20220709-0560': None, 'PS-20220709-0563': None, 'PS-20220709-0571': None, 'PS-20220709-0576': None, 'PS-20220709-0583': None, 'PS-20220709-0595': None, 'PS-20220711-0675': None, 'PS-20220711-0685': None, 'PS-20220711-0696': None, 'PS-20220711-0697': None, 'PS-20220711-0736': None, 'PS-20220711-0751': None, 'PS-20220711-0753': None, 'PS-20220711-0789': None, 'PS-20220711-0816': None, 'PS-20220709-0607': None, 'PS-20220711-0817': None, 'PS-20220711-0833': None, 'PS-20220711-0840': None, 'PS-20220711-0847': None, 'PS-20220711-0858': None, 'PS-20220711-0870': None, 'PS-20220711-0917': None, 'PS-20220711-0920': None, 'PS-20220711-0935': None, 'PS-20220711-0957': None, 'PS-20220711-0977': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None, 'PS-20220709-0561': None, 'PS-20220709-0584': None, 'PS-20220711-0773': None, 'PS-20220711-0785': None}=
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0551': None, 'PS-20220709-0560': None, 'PS-20220709-0563': None, 'PS-20220709-0571': None, 'PS-20220709-0576': None, 'PS-20220709-0583': None, 'PS-20220709-0595': None, 'PS-20220711-0675': None, 'PS-20220711-0685': None, 'PS-20220711-0696': None, 'PS-20220711-0697': None, 'PS-20220711-0736': None, 'PS-20220711-0751': None, 'PS-20220711-0753': None, 'PS-20220711-0789': None, 'PS-20220711-0816': None, 'PS-20220709-0607': None, 'PS-20220711-0817': None, 'PS-20220711-0833': None, 'PS-20220711-0840': None, 'PS-20220711-0847': None, 'PS-20220711-0858': None, 'PS-20220711-0870': None, 'PS-20220711-0917': None, 'PS-20220711-0920': None, 'PS-20220711-0935': None, 'PS-20220711-0957': None, 'PS-20220711-0977': None, 'PS-20220711-0998': None, 'PS-20220711-1008': None, 'PS-20220711-1030': None, 'PS-20220711-1047': None, 'PS-20220711-1076': None, 'PS-20220711-1081': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None, 'PS-20220709-0561': None, 'PS-20220709-0584': None, 'PS-20220711-0773': None, 'PS-20220711-0785': None, 'PS-20220711-0992': None, 'PS-20220711-1044': None, 'PS-20220711-1065': None}=
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220711-1086': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0551': None, 'PS-20220709-0560': None, 'PS-20220709-0563': None, 'PS-20220709-0571': None, 'PS-20220709-0576': None, 'PS-20220709-0583': None, 'PS-20220709-0595': None, 'PS-20220711-0675': None, 'PS-20220711-0685': None, 'PS-20220711-0696': None, 'PS-20220711-0697': None, 'PS-20220711-0736': None, 'PS-20220711-0751': None, 'PS-20220711-0753': None, 'PS-20220711-0789': None, 'PS-20220711-0816': None, 'PS-20220709-0607': None, 'PS-20220711-0817': None, 'PS-20220711-0833': None, 'PS-20220711-0840': None, 'PS-20220711-0847': None, 'PS-20220711-0858': None, 'PS-20220711-0870': None, 'PS-20220711-0917': None, 'PS-20220711-0920': None, 'PS-20220711-0935': None, 'PS-20220711-0957': None, 'PS-20220711-0977': None, 'PS-20220711-0998': None, 'PS-20220711-1008': None, 'PS-20220711-1030': None, 'PS-20220711-1047': None, 'PS-20220711-1076': None, 'PS-20220711-1081': None, 'PS-20220711-1083': None, 'PS-20220711-1088': None, 'PS-20220711-1115': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None, 'PS-20220709-0561': None, 'PS-20220709-0584': None, 'PS-20220711-0773': None, 'PS-20220711-0785': None, 'PS-20220711-0992': None, 'PS-20220711-1044': None, 'PS-20220711-1065': None, 'PS-20220711-1122': None, 'PS-20220711-1124': None}=
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220711-1086': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0551': None, 'PS-20220709-0560': None, 'PS-20220709-0563': None, 'PS-20220709-0571': None, 'PS-20220709-0576': None, 'PS-20220709-0583': None, 'PS-20220709-0595': None, 'PS-20220711-0675': None, 'PS-20220711-0685': None, 'PS-20220711-0696': None, 'PS-20220711-0697': None, 'PS-20220711-0736': None, 'PS-20220711-0751': None, 'PS-20220711-0753': None, 'PS-20220711-0789': None, 'PS-20220711-0816': None, 'PS-20220709-0607': None, 'PS-20220711-0817': None, 'PS-20220711-0833': None, 'PS-20220711-0840': None, 'PS-20220711-0847': None, 'PS-20220711-0858': None, 'PS-20220711-0870': None, 'PS-20220711-0917': None, 'PS-20220711-0920': None, 'PS-20220711-0935': None, 'PS-20220711-0957': None, 'PS-20220711-0977': None, 'PS-20220711-0998': None, 'PS-20220711-1008': None, 'PS-20220711-1030': None, 'PS-20220711-1047': None, 'PS-20220711-1076': None, 'PS-20220711-1081': None, 'PS-20220711-1083': None, 'PS-20220711-1088': None, 'PS-20220711-1115': None, 'PS-20220706-0114': None, 'PS-20220706-0127': None, 'PS-20220711-1136': None, 'PS-20220711-1151': None, 'PS-20220711-1163': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None, 'PS-20220709-0561': None, 'PS-20220709-0584': None, 'PS-20220711-0773': None, 'PS-20220711-0785': None, 'PS-20220711-0992': None, 'PS-20220711-1044': None, 'PS-20220711-1065': None, 'PS-20220711-1122': None, 'PS-20220711-1124': None, 'PS-20220706-0100': None, 'PS-20220711-1145': None}=
# {'PS-20220709-0475': None, 'PS-20220711-0540': None, 'PS-20220711-0568': None, 'PS-20220711-1086': None, 'PS-20220706-0009': None, 'PS-20220706-0021': None, 'PS-20220706-0028': None, 'PS-20220706-0035': None, 'PS-20220706-0043': None, 'PS-20220706-0054': None, 'PS-20220706-0091': None, 'PS-20220706-0092': None, 'PS-20220709-0465': None, 'PS-20220709-0467': None, 'PS-20220709-0493': None, 'PS-20220709-0496': None, 'PS-20220709-0502': None, 'PS-20220709-0527': None, 'PS-20220709-0540': None, 'PS-20220711-0538': None, 'PS-20220711-0546': None, 'PS-20220711-0547': None, 'PS-20220711-0563': None, 'PS-20220711-0588': None, 'PS-20220711-0589': None, 'PS-20220711-0592': None, 'PS-20220711-0606': None, 'PS-20220711-0645': None, 'PS-20220709-0551': None, 'PS-20220709-0560': None, 'PS-20220709-0563': None, 'PS-20220709-0571': None, 'PS-20220709-0576': None, 'PS-20220709-0583': None, 'PS-20220709-0595': None, 'PS-20220711-0675': None, 'PS-20220711-0685': None, 'PS-20220711-0696': None, 'PS-20220711-0697': None, 'PS-20220711-0736': None, 'PS-20220711-0751': None, 'PS-20220711-0753': None, 'PS-20220711-0789': None, 'PS-20220711-0816': None, 'PS-20220709-0607': None, 'PS-20220711-0817': None, 'PS-20220711-0833': None, 'PS-20220711-0840': None, 'PS-20220711-0847': None, 'PS-20220711-0858': None, 'PS-20220711-0870': None, 'PS-20220711-0917': None, 'PS-20220711-0920': None, 'PS-20220711-0935': None, 'PS-20220711-0957': None, 'PS-20220711-0977': None, 'PS-20220711-0998': None, 'PS-20220711-1008': None, 'PS-20220711-1030': None, 'PS-20220711-1047': None, 'PS-20220711-1076': None, 'PS-20220711-1081': None, 'PS-20220711-1083': None, 'PS-20220711-1088': None, 'PS-20220711-1115': None, 'PS-20220706-0114': None, 'PS-20220706-0127': None, 'PS-20220711-1136': None, 'PS-20220711-1151': None, 'PS-20220711-1163': None, 'PS-20220711-1218': None, 'PS-20220711-1221': None, 'PS-20220711-1283': None, 'PS-20220709-0490': None, 'PS-20220709-0541': None, 'PS-20220709-0544': None, 'PS-20220709-0561': None, 'PS-20220709-0584': None, 'PS-20220711-0773': None, 'PS-20220711-0785': None, 'PS-20220711-0992': None, 'PS-20220711-1044': None, 'PS-20220711-1065': None, 'PS-20220711-1122': None, 'PS-20220711-1124': None, 'PS-20220706-0100': None, 'PS-20220711-1145': None, 'PS-20220711-1224': None, 'PS-20220711-1281': None}=
# {'PS-20220709-0475': 'Officer_Station_1_Day_0', 'PS-20220711-0540': 'Officer_Station_1_Day_0', 'PS-20220711-0568': 'Officer_Station_1_Day_0', 'PS-20220711-1086': 'Officer_Station_2_Day_0', 'PS-20220706-0009': 'Officer_Station_3_Day_0', 'PS-20220706-0021': 'Officer_Station_2_Day_0', 'PS-20220706-0028': 'Officer_Station_1_Day_0', 'PS-20220706-0035': 'Officer_Station_2_Day_0', 'PS-20220706-0043': 'Officer_Station_3_Day_0', 'PS-20220706-0054': 'Officer_Station_2_Day_0', 'PS-20220706-0091': 'Officer_Station_1_Day_0', 'PS-20220706-0092': 'Officer_Station_1_Day_0', 'PS-20220709-0465': 'Officer_Station_1_Day_0', 'PS-20220709-0467': 'Officer_Station_2_Day_0', 'PS-20220709-0493': 'Officer_Station_1_Day_0', 'PS-20220709-0496': 'Officer_Station_1_Day_0', 'PS-20220709-0502': 'Officer_Station_3_Day_0', 'PS-20220709-0527': 'Officer_Station_1_Day_0', 'PS-20220709-0540': 'Officer_Station_2_Day_0', 'PS-20220711-0538': 'Officer_Station_1_Day_0', 'PS-20220711-0546': 'Officer_Station_3_Day_0', 'PS-20220711-0547': 'Officer_Station_1_Day_0', 'PS-20220711-0563': 'Officer_Station_1_Day_0', 'PS-20220711-0588': 'Officer_Station_2_Day_0', 'PS-20220711-0589': 'Officer_Station_3_Day_0', 'PS-20220711-0592': 'Officer_Station_1_Day_0', 'PS-20220711-0606': 'Officer_Station_3_Day_0', 'PS-20220711-0645': 'Officer_Station_2_Day_0', 'PS-20220709-0551': 'Officer_Station_3_Day_0', 'PS-20220709-0560': 'Officer_Station_1_Day_0', 'PS-20220709-0563': 'Officer_Station_1_Day_0', 'PS-20220709-0571': 'Officer_Station_1_Day_0', 'PS-20220709-0576': 'Officer_Station_3_Day_0', 'PS-20220709-0583': 'Officer_Station_2_Day_0', 'PS-20220709-0595': 'Officer_Station_1_Day_0', 'PS-20220711-0675': 'Officer_Station_1_Day_0', 'PS-20220711-0685': 'Officer_Station_1_Day_0', 'PS-20220711-0696': 'Officer_Station_3_Day_0', 'PS-20220711-0697': 'Officer_Station_3_Day_0', 'PS-20220711-0736': 'Officer_Station_1_Day_0', 'PS-20220711-0751': 'Officer_Station_1_Day_0', 'PS-20220711-0753': 'Officer_Station_1_Day_0', 'PS-20220711-0789': 'Officer_Station_1_Day_0', 'PS-20220711-0816': 'Officer_Station_3_Day_0', 'PS-20220709-0607': 'Officer_Station_3_Day_0', 'PS-20220711-0817': 'Officer_Station_2_Day_0', 'PS-20220711-0833': 'Officer_Station_2_Day_0', 'PS-20220711-0840': 'Officer_Station_2_Day_0', 'PS-20220711-0847': 'Officer_Station_3_Day_0', 'PS-20220711-0858': 'Officer_Station_3_Day_0', 'PS-20220711-0870': 'Officer_Station_1_Day_0', 'PS-20220711-0917': 'Officer_Station_1_Day_0', 'PS-20220711-0920': 'Officer_Station_1_Day_0', 'PS-20220711-0935': 'Officer_Station_1_Day_0', 'PS-20220711-0957': 'Officer_Station_2_Day_0', 'PS-20220711-0977': 'Officer_Station_3_Day_0', 'PS-20220711-0998': 'Officer_Station_2_Day_0', 'PS-20220711-1008': 'Officer_Station_1_Day_0', 'PS-20220711-1030': 'Officer_Station_1_Day_0', 'PS-20220711-1047': 'Officer_Station_1_Day_0', 'PS-20220711-1076': 'Officer_Station_2_Day_0', 'PS-20220711-1081': 'Officer_Station_2_Day_0', 'PS-20220711-1083': 'Officer_Station_1_Day_0', 'PS-20220711-1088': 'Officer_Station_1_Day_0', 'PS-20220711-1115': 'Officer_Station_1_Day_0', 'PS-20220706-0114': 'Officer_Station_1_Day_0', 'PS-20220706-0127': 'Officer_Station_1_Day_0', 'PS-20220711-1136': 'Officer_Station_1_Day_0', 'PS-20220711-1151': 'Officer_Station_3_Day_0', 'PS-20220711-1163': 'Officer_Station_1_Day_0', 'PS-20220711-1218': 'Officer_Station_1_Day_0', 'PS-20220711-1221': 'Officer_Station_1_Day_0', 'PS-20220711-1283': 'Officer_Station_3_Day_0', 'PS-20220711-1286': 'Officer_Station_1_Day_0', 'PS-20220711-1315': 'Officer_Station_1_Day_0', 'PS-20220711-1338': 'Officer_Station_2_Day_0', 'PS-20220711-1356': 'Officer_Station_3_Day_0', 'PS-20220711-1384': 'Officer_Station_1_Day_0', 'PS-20220711-1396': 'Officer_Station_1_Day_0', 'PS-20220709-0490': 'Officer_Station_1_Day_0', 'PS-20220709-0541': 'Officer_Station_3_Day_0', 'PS-20220709-0544': 'Officer_Station_2_Day_0', 'PS-20220709-0561': 'Officer_Station_1_Day_0', 'PS-20220709-0584': 'Officer_Station_1_Day_0', 'PS-20220711-0773': 'Officer_Station_3_Day_0', 'PS- ...
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220711-1406': 'Officer_Station_2_Day_1', 'PS-20220711-1417': 'Officer_Station_1_Day_1', 'PS-20220711-1455': 'Officer_Station_1_Day_1', 'PS-20220711-1493': 'Officer_Station_3_Day_1', 'PS-20220706-0130': 'Officer_Station_1_Day_1', 'PS-20220706-0139': 'Officer_Station_1_Day_1', 'PS-20220706-0141': 'Officer_Station_1_Day_1', 'PS-20220706-0151': 'Officer_Station_3_Day_1', 'PS-20220706-0155': 'Officer_Station_1_Day_1', 'PS-20220706-0167': 'Officer_Station_1_Day_1', 'PS-20220711-1437': 'Officer_Station_1_Day_1', 'PS-20220711-1446': 'Officer_Station_1_Day_1', 'PS-20220711-1461': 'Officer_Station_3_Day_1', 'PS-20220711-1482': 'Officer_Station_2_Day_1', 'PS-20220711-1497': 'Officer_Station_1_Day_1', 'PS-20220711-1538': 'Officer_Station_3_Day_1', 'PS-20220711-1439': 'Officer_Station_1_Day_1', 'PS-20220711-1506': 'Officer_Station_1_Day_1', 'PS-20220711-1516': 'Officer_Station_1_Day_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0173': 'Officer_Station_2_Day_0', 'PS-20220711-1629': 'Officer_Station_3_Day_0', 'PS-20220706-0181': 'Officer_Station_3_Day_0', 'PS-20220706-0223': 'Officer_Station_1_Day_0', 'PS-20220706-0225': 'Officer_Station_2_Day_0', 'PS-20220706-0252': 'Officer_Station_3_Day_0', 'PS-20220711-1546': 'Officer_Station_1_Day_0', 'PS-20220711-1559': 'Officer_Station_3_Day_0', 'PS-20220711-1560': 'Officer_Station_1_Day_0', 'PS-20220711-1614': 'Officer_Station_1_Day_0', 'PS-20220711-1627': 'Officer_Station_1_Day_0', 'PS-20220711-1637': 'Officer_Station_1_Day_0', 'PS-20220711-1662': 'Officer_Station_3_Day_0', 'PS-20220711-1678': 'Officer_Station_3_Day_0', 'PS-20220711-1592': 'Officer_Station_1_Day_0', 'PS-20220711-1605': 'Officer_Station_1_Day_0', 'PS-20220711-1665': 'Officer_Station_3_Day_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220711-1818': 'Officer_Station_1_Day_1', 'PS-20220711-1843': 'Officer_Station_1_Day_1', 'PS-20220711-1845': 'Officer_Station_1_Day_1', 'PS-20220706-0258': 'Officer_Station_3_Day_1', 'PS-20220706-0262': 'Officer_Station_1_Day_1', 'PS-20220706-0266': 'Officer_Station_1_Day_1', 'PS-20220706-0271': 'Officer_Station_2_Day_1', 'PS-20220706-0272': 'Officer_Station_1_Day_1', 'PS-20220711-1801': 'Officer_Station_1_Day_1', 'PS-20220711-1853': 'Officer_Station_1_Day_1', 'PS-20220711-1936': 'Officer_Station_3_Day_1', 'PS-20220711-1948': 'Officer_Station_1_Day_1', 'PS-20220711-1960': 'Officer_Station_3_Day_1', 'PS-20220711-1962': 'Officer_Station_3_Day_1', 'PS-20220711-1979': 'Officer_Station_2_Day_1', 'PS-20220711-1993': 'Officer_Station_1_Day_1', 'PS-20220711-1996': 'Officer_Station_3_Day_1', 'PS-20220711-2003': 'Officer_Station_1_Day_1', 'PS-20220711-2004': 'Officer_Station_1_Day_1', 'PS-20220706-0285': 'Officer_Station_1_Day_1', 'PS-20220706-0288': 'Officer_Station_3_Day_1', 'PS-20220711-1694': 'Officer_Station_1_Day_1', 'PS-20220711-1823': 'Officer_Station_2_Day_1', 'PS-20220711-1867': 'Officer_Station_1_Day_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220711-2032': 'Officer_Station_1_Day_0', 'PS-20220711-2075': 'Officer_Station_2_Day_2', 'PS-20220706-0290': 'Officer_Station_3_Day_2', 'PS-20220706-0305': 'Officer_Station_1_Day_0', 'PS-20220706-0312': 'Officer_Station_2_Day_2', 'PS-20220706-0315': 'Officer_Station_2_Day_2', 'PS-20220711-2021': 'Officer_Station_1_Day_0', 'PS-20220711-2031': 'Officer_Station_1_Day_0', 'PS-20220711-2056': 'Officer_Station_3_Day_2', 'PS-20220711-2098': 'Officer_Station_2_Day_2', 'PS-20220711-2153': 'Officer_Station_1_Day_0', 'PS-20220711-2168': 'Officer_Station_2_Day_2', 'PS-20220706-0291': 'Officer_Station_1_Day_0', 'PS-20220706-0301': 'Officer_Station_1_Day_0', 'PS-20220706-0323': 'Officer_Station_2_Day_2', 'PS-20220711-2019': 'Officer_Station_1_Day_0', 'PS-20220711-2070': 'Officer_Station_2_Day_2', 'PS-20220711-2104': 'Officer_Station_2_Day_2'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0346': 'Officer_Station_1_Day_1', 'PS-20220706-0352': 'Officer_Station_1_Day_1', 'PS-20220706-0361': 'Officer_Station_1_Day_1', 'PS-20220706-0347': 'Officer_Station_1_Day_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0371': 'Officer_Station_1_Day_0', 'PS-20220706-0387': 'Officer_Station_2_Day_0', 'PS-20220706-0386': 'Officer_Station_1_Day_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0390': 'Officer_Station_1_Day_1', 'PS-20220706-0411': 'Officer_Station_3_Day_0', 'PS-20220706-0414': 'Officer_Station_2_Day_1'}=
# {}=
# {}=
# {'PS-20220706-0449': 'Officer_Station_3_Night_0', 'PS-20220709-0610': 'Officer_Station_1_Night_0', 'PS-20220706-0416': 'Officer_Station_1_Night_0', 'PS-20220706-0430': 'Officer_Station_1_Night_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0455': 'Officer_Station_2_Night_0', 'PS-20220706-0469': 'Officer_Station_2_Night_0', 'PS-20220709-0624': 'Officer_Station_1_Night_1', 'PS-20220709-0727': 'Officer_Station_3_Night_1', 'PS-20220706-0453': 'Officer_Station_1_Night_1', 'PS-20220709-0676': 'Officer_Station_2_Night_0', 'PS-20220709-0690': 'Officer_Station_1_Night_1', 'PS-20220709-0652': 'Officer_Station_3_Night_1', 'PS-20220709-0687': 'Officer_Station_3_Night_1'}=
# {}=
# {}=
# {'PS-20220706-0471': 'Officer_Station_2_Night_1', 'PS-20220706-0484': 'Officer_Station_1_Night_0', 'PS-20220706-0474': 'Officer_Station_2_Night_1', 'PS-20220706-0522': 'Officer_Station_2_Night_1', 'PS-20220709-0728': 'Officer_Station_1_Night_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0531': 'Officer_Station_3_Night_0', 'PS-20220709-0740': 'Officer_Station_1_Night_2', 'PS-20220709-0741': 'Officer_Station_2_Night_2'}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220710-4149': 'Officer_Station_1_Night_1', 'PS-20220706-0569': 'Officer_Station_1_Night_1', 'PS-20220706-0614': 'Officer_Station_1_Night_1', 'PS-20220709-0765': 'Officer_Station_1_Night_1', 'PS-20220710-4069': 'Officer_Station_1_Night_1', 'PS-20220710-4125': 'Officer_Station_2_Night_0', 'PS-20220710-4132': 'Officer_Station_3_Night_1', 'PS-20220710-4139': 'Officer_Station_1_Night_1', 'PS-20220710-4152': 'Officer_Station_1_Night_1', 'PS-20220710-4164': 'Officer_Station_1_Night_1', 'PS-20220710-4166': 'Officer_Station_1_Night_1', 'PS-20220706-0565': 'Officer_Station_1_Night_1', 'PS-20220709-0786': 'Officer_Station_2_Night_0', 'PS-20220709-0818': 'Officer_Station_3_Night_1', 'PS-20220710-4134': 'Officer_Station_2_Night_0', 'PS-20220710-4156': 'Officer_Station_1_Night_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0639': 'Officer_Station_1_Night_0', 'PS-20220710-4173': 'Officer_Station_3_Night_1', 'PS-20220710-4221': 'Officer_Station_1_Night_0', 'PS-20220711-2174': 'Officer_Station_1_Night_0', 'PS-20220711-2198': 'Officer_Station_1_Night_0', 'PS-20220706-0633': 'Officer_Station_1_Night_0', 'PS-20220706-0647': 'Officer_Station_1_Night_0', 'PS-20220709-0825': 'Officer_Station_1_Night_0', 'PS-20220710-4172': 'Officer_Station_1_Night_0', 'PS-20220710-4176': 'Officer_Station_3_Night_1', 'PS-20220710-4181': 'Officer_Station_1_Night_0', 'PS-20220710-4199': 'Officer_Station_1_Night_0', 'PS-20220710-4206': 'Officer_Station_2_Night_1', 'PS-20220710-4207': 'Officer_Station_1_Night_0', 'PS-20220711-0009': 'Officer_Station_3_Night_1', 'PS-20220711-0025': 'Officer_Station_3_Night_1', 'PS-20220711-0029': 'Officer_Station_1_Night_0', 'PS-20220711-0048': 'Officer_Station_1_Night_0', 'PS-20220711-0060': 'Officer_Station_3_Night_1', 'PS-20220711-0068': 'Officer_Station_2_Night_1', 'PS-20220711-0105': 'Officer_Station_3_Night_1', 'PS-20220711-0106': 'Officer_Station_1_Night_0', 'PS-20220711-0109': 'Officer_Station_3_Night_1', 'PS-20220711-0159': 'Officer_Station_3_Night_1', 'PS-20220711-0172': 'Officer_Station_3_Night_1', 'PS-20220711-0179': 'Officer_Station_1_Night_0', 'PS-20220711-0198': 'Officer_Station_1_Night_0', 'PS-20220711-2191': 'Officer_Station_1_Night_0', 'PS-20220711-2193': 'Officer_Station_1_Night_0', 'PS-20220711-2197': 'Officer_Station_3_Night_1', 'PS-20220711-2218': 'Officer_Station_1_Night_0', 'PS-20220711-2227': 'Officer_Station_1_Night_0', 'PS-20220711-2245': 'Officer_Station_3_Night_1', 'PS-20220711-2256': 'Officer_Station_3_Night_1', 'PS-20220711-2265': 'Officer_Station_3_Night_1', 'PS-20220711-2282': 'Officer_Station_1_Night_0', 'PS-20220706-0640': 'Officer_Station_1_Night_0', 'PS-20220710-4169': 'Officer_Station_1_Night_0', 'PS-20220711-0108': 'Officer_Station_1_Night_0', 'PS-20220711-0112': 'Officer_Station_1_Night_0', 'PS-20220711-0142': 'Officer_Station_2_Night_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0655': 'Officer_Station_1_Night_1', 'PS-20220709-0831': 'Officer_Station_3_Night_0', 'PS-20220711-0223': 'Officer_Station_2_Night_2', 'PS-20220711-0248': 'Officer_Station_1_Night_1', 'PS-20220711-0330': 'Officer_Station_1_Night_1', 'PS-20220711-2513': 'Officer_Station_2_Night_2', 'PS-20220706-0667': 'Officer_Station_1_Night_1', 'PS-20220706-0706': 'Officer_Station_1_Night_1', 'PS-20220706-0712': 'Officer_Station_1_Night_1', 'PS-20220711-0205': 'Officer_Station_1_Night_1', 'PS-20220711-0209': 'Officer_Station_1_Night_1', 'PS-20220711-0241': 'Officer_Station_2_Night_2', 'PS-20220711-0281': 'Officer_Station_2_Night_2', 'PS-20220711-0282': 'Officer_Station_1_Night_1', 'PS-20220711-0285': 'Officer_Station_1_Night_1', 'PS-20220711-0314': 'Officer_Station_1_Night_1', 'PS-20220711-0317': 'Officer_Station_3_Night_0', 'PS-20220711-0326': 'Officer_Station_1_Night_1', 'PS-20220711-2328': 'Officer_Station_3_Night_0', 'PS-20220711-2337': 'Officer_Station_3_Night_0', 'PS-20220711-2373': 'Officer_Station_3_Night_0', 'PS-20220711-2402': 'Officer_Station_1_Night_1', 'PS-20220711-2411': 'Officer_Station_1_Night_1', 'PS-20220711-2449': 'Officer_Station_1_Night_1', 'PS-20220711-2454': 'Officer_Station_2_Night_2', 'PS-20220711-2521': 'Officer_Station_1_Night_1', 'PS-20220711-2524': 'Officer_Station_3_Night_0', 'PS-20220706-0659': 'Officer_Station_3_Night_0', 'PS-20220706-0699': 'Officer_Station_1_Night_1', 'PS-20220711-0202': 'Officer_Station_1_Night_1', 'PS-20220711-0323': 'Officer_Station_1_Night_1', 'PS-20220711-2283': 'Officer_Station_1_Night_1', 'PS-20220711-2305': 'Officer_Station_3_Night_0', 'PS-20220711-2319': 'Officer_Station_3_Night_0', 'PS-20220711-2326': 'Officer_Station_1_Night_1', 'PS-20220711-2357': 'Officer_Station_2_Night_2', 'PS-20220711-2445': 'Officer_Station_1_Night_1', 'PS-20220711-2474': 'Officer_Station_1_Night_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220706-0739': 'Officer_Station_1_Night_0', 'PS-20220709-0869': 'Officer_Station_1_Night_0', 'PS-20220711-0468': 'Officer_Station_1_Night_0', 'PS-20220711-0526': 'Officer_Station_2_Night_0', 'PS-20220711-2533': 'Officer_Station_1_Night_0', 'PS-20220711-0332': 'Officer_Station_3_Night_0', 'PS-20220711-0353': 'Officer_Station_1_Night_0', 'PS-20220711-0390': 'Officer_Station_1_Night_0', 'PS-20220711-0396': 'Officer_Station_3_Night_0', 'PS-20220711-0445': 'Officer_Station_1_Night_0', 'PS-20220711-0448': 'Officer_Station_1_Night_0', 'PS-20220711-0515': 'Officer_Station_1_Night_0', 'PS-20220711-0524': 'Officer_Station_1_Night_0', 'PS-20220711-2559': 'Officer_Station_1_Night_0', 'PS-20220711-2575': 'Officer_Station_1_Night_0', 'PS-20220711-2624': 'Officer_Station_3_Night_0', 'PS-20220706-0737': 'Officer_Station_1_Night_0', 'PS-20220709-0849': 'Officer_Station_1_Night_0', 'PS-20220711-0371': 'Officer_Station_1_Night_0', 'PS-20220711-0509': 'Officer_Station_1_Night_0', 'PS-20220711-0512': 'Officer_Station_1_Night_0', 'PS-20220711-2528': 'Officer_Station_1_Night_0', 'PS-20220711-2530': 'Officer_Station_3_Night_0', 'PS-20220711-2601': 'Officer_Station_3_Night_0', 'PS-20220711-2622': 'Officer_Station_1_Night_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None}=
# {'PS-20220711-2657': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0795': None, 'PS-20220711-2740': None, 'PS-20220711-2741': None, 'PS-20220711-2742': None, 'PS-20220711-2775': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None, 'PS-20220706-0819': None, 'PS-20220709-0899': None, 'PS-20220709-0919': None, 'PS-20220711-2759': None, 'PS-20220711-2768': None}=
# {'PS-20220711-2657': None, 'PS-20220711-2855': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0795': None, 'PS-20220711-2740': None, 'PS-20220711-2741': None, 'PS-20220711-2742': None, 'PS-20220711-2775': None, 'PS-20220706-0820': None, 'PS-20220711-2788': None, 'PS-20220711-2791': None, 'PS-20220711-2884': None, 'PS-20220711-2912': None, 'PS-20220711-2921': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None, 'PS-20220706-0819': None, 'PS-20220709-0899': None, 'PS-20220709-0919': None, 'PS-20220711-2759': None, 'PS-20220711-2768': None, 'PS-20220711-2818': None, 'PS-20220711-2879': None}=
# {'PS-20220711-2657': None, 'PS-20220711-2855': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0795': None, 'PS-20220711-2740': None, 'PS-20220711-2741': None, 'PS-20220711-2742': None, 'PS-20220711-2775': None, 'PS-20220706-0820': None, 'PS-20220711-2788': None, 'PS-20220711-2791': None, 'PS-20220711-2884': None, 'PS-20220711-2912': None, 'PS-20220711-2921': None, 'PS-20220706-0830': None, 'PS-20220709-0924': None, 'PS-20220711-2963': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None, 'PS-20220706-0819': None, 'PS-20220709-0899': None, 'PS-20220709-0919': None, 'PS-20220711-2759': None, 'PS-20220711-2768': None, 'PS-20220711-2818': None, 'PS-20220711-2879': None}=
# {'PS-20220711-2657': None, 'PS-20220711-2855': None, 'PS-20220709-0933': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0795': None, 'PS-20220711-2740': None, 'PS-20220711-2741': None, 'PS-20220711-2742': None, 'PS-20220711-2775': None, 'PS-20220706-0820': None, 'PS-20220711-2788': None, 'PS-20220711-2791': None, 'PS-20220711-2884': None, 'PS-20220711-2912': None, 'PS-20220711-2921': None, 'PS-20220706-0830': None, 'PS-20220709-0924': None, 'PS-20220711-2963': None, 'PS-20220711-2971': None, 'PS-20220711-2984': None, 'PS-20220711-2993': None, 'PS-20220711-2999': None, 'PS-20220711-3027': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None, 'PS-20220706-0819': None, 'PS-20220709-0899': None, 'PS-20220709-0919': None, 'PS-20220711-2759': None, 'PS-20220711-2768': None, 'PS-20220711-2818': None, 'PS-20220711-2879': None, 'PS-20220709-0952': None}=
# {'PS-20220711-2657': None, 'PS-20220711-2855': None, 'PS-20220709-0933': None, 'PS-20220706-0741': None, 'PS-20220706-0763': None, 'PS-20220706-0774': None, 'PS-20220709-0876': None, 'PS-20220709-0893': None, 'PS-20220711-2629': None, 'PS-20220711-2674': None, 'PS-20220711-2681': None, 'PS-20220711-2699': None, 'PS-20220706-0776': None, 'PS-20220706-0792': None, 'PS-20220711-2701': None, 'PS-20220706-0795': None, 'PS-20220711-2740': None, 'PS-20220711-2741': None, 'PS-20220711-2742': None, 'PS-20220711-2775': None, 'PS-20220706-0820': None, 'PS-20220711-2788': None, 'PS-20220711-2791': None, 'PS-20220711-2884': None, 'PS-20220711-2912': None, 'PS-20220711-2921': None, 'PS-20220706-0830': None, 'PS-20220709-0924': None, 'PS-20220711-2963': None, 'PS-20220711-2971': None, 'PS-20220711-2984': None, 'PS-20220711-2993': None, 'PS-20220711-2999': None, 'PS-20220711-3027': None, 'PS-20220711-3035': None, 'PS-20220706-0767': None, 'PS-20220711-2679': None, 'PS-20220711-2687': None, 'PS-20220706-0786': None, 'PS-20220711-2717': None, 'PS-20220711-2727': None, 'PS-20220706-0819': None, 'PS-20220709-0899': None, 'PS-20220709-0919': None, 'PS-20220711-2759': None, 'PS-20220711-2768': None, 'PS-20220711-2818': None, 'PS-20220711-2879': None, 'PS-20220709-0952': None, 'PS-20220711-3045': None}=
# ...
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220715-1004': 'Officer_Station_1_Day_1', 'PS-20220707-1170': 'Officer_Station_3_Day_1', 'PS-20220707-1171': 'Officer_Station_1_Day_1', 'PS-20220715-0997': 'Officer_Station_2_Day_1', 'PS-20220715-1014': 'Officer_Station_1_Day_1', 'PS-20220715-1015': 'Officer_Station_1_Day_1', 'PS-20220715-1017': 'Officer_Station_2_Day_1', 'PS-20220715-1020': 'Officer_Station_1_Day_1', 'PS-20220715-1041': 'Officer_Station_1_Day_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220709-4197': 'Officer_Station_1_Day_0', 'PS-20220707-1181': 'Officer_Station_1_Day_0', 'PS-20220707-1244': 'Officer_Station_1_Day_0', 'PS-20220715-1053': 'Officer_Station_1_Day_0', 'PS-20220715-1077': 'Officer_Station_3_Day_0', 'PS-20220707-1203': 'Officer_Station_3_Day_0', 'PS-20220707-1231': 'Officer_Station_3_Day_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220707-1251': 'Officer_Station_2_Day_0', 'PS-20220709-4199': 'Officer_Station_3_Day_1', 'PS-20220715-1119': 'Officer_Station_3_Day_1', 'PS-20220715-1129': 'Officer_Station_3_Day_1', 'PS-20220715-1141': 'Officer_Station_2_Day_0', 'PS-20220715-1179': 'Officer_Station_1_Day_2', 'PS-20220715-1181': 'Officer_Station_1_Day_2', 'PS-20220715-1185': 'Officer_Station_1_Day_2', 'PS-20220707-1288': 'Officer_Station_3_Day_1', 'PS-20220715-1086': 'Officer_Station_2_Day_0', 'PS-20220715-1111': 'Officer_Station_2_Day_0', 'PS-20220715-1182': 'Officer_Station_2_Day_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220707-1374': 'Officer_Station_1_Day_0', 'PS-20220715-1267': 'Officer_Station_1_Day_0', 'PS-20220707-1311': 'Officer_Station_1_Day_0', 'PS-20220707-1345': 'Officer_Station_1_Day_0', 'PS-20220707-1349': 'Officer_Station_3_Day_0', 'PS-20220707-1356': 'Officer_Station_1_Day_0', 'PS-20220707-1366': 'Officer_Station_1_Day_0', 'PS-20220709-4208': 'Officer_Station_3_Day_0', 'PS-20220715-1189': 'Officer_Station_1_Day_0', 'PS-20220715-1198': 'Officer_Station_2_Day_1', 'PS-20220715-1226': 'Officer_Station_1_Day_0', 'PS-20220715-1238': 'Officer_Station_1_Day_0', 'PS-20220715-1264': 'Officer_Station_3_Day_0', 'PS-20220715-1265': 'Officer_Station_2_Day_1', 'PS-20220707-1321': 'Officer_Station_2_Day_1', 'PS-20220707-1338': 'Officer_Station_3_Day_0', 'PS-20220707-1371': 'Officer_Station_1_Day_0', 'PS-20220707-1372': 'Officer_Station_1_Day_0', 'PS-20220715-1225': 'Officer_Station_1_Day_0', 'PS-20220715-1236': 'Officer_Station_2_Day_1', 'PS-20220715-1288': 'Officer_Station_1_Day_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220715-1291': 'Officer_Station_1_Day_1', 'PS-20220707-1381': 'Officer_Station_1_Day_1', 'PS-20220707-1407': 'Officer_Station_2_Day_0', 'PS-20220707-1418': 'Officer_Station_3_Day_2', 'PS-20220709-4209': 'Officer_Station_1_Day_1', 'PS-20220709-4225': 'Officer_Station_2_Day_0', 'PS-20220709-4259': 'Officer_Station_3_Day_2', 'PS-20220715-1305': 'Officer_Station_1_Day_1', 'PS-20220715-1309': 'Officer_Station_1_Day_1', 'PS-20220715-1344': 'Officer_Station_2_Day_0', 'PS-20220715-1377': 'Officer_Station_1_Day_1', 'PS-20220707-1426': 'Officer_Station_1_Day_1', 'PS-20220715-1308': 'Officer_Station_1_Day_1', 'PS-20220715-1310': 'Officer_Station_1_Day_1', 'PS-20220715-1316': 'Officer_Station_1_Day_1', 'PS-20220715-1331': 'Officer_Station_3_Day_2'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220709-4333': 'Officer_Station_2_Day_1', 'PS-20220715-1460': 'Officer_Station_3_Day_0', 'PS-20220715-1522': 'Officer_Station_2_Day_1', 'PS-20220715-1541': 'Officer_Station_1_Day_0', 'PS-20220707-1440': 'Officer_Station_1_Day_0', 'PS-20220707-1479': 'Officer_Station_1_Day_0', 'PS-20220709-4285': 'Officer_Station_1_Day_0', 'PS-20220709-4292': 'Officer_Station_1_Day_0', 'PS-20220709-4365': 'Officer_Station_3_Day_0', 'PS-20220715-1379': 'Officer_Station_1_Day_0', 'PS-20220715-1390': 'Officer_Station_1_Day_0', 'PS-20220715-1433': 'Officer_Station_3_Day_0', 'PS-20220715-1467': 'Officer_Station_2_Day_1', 'PS-20220715-1469': 'Officer_Station_1_Day_0', 'PS-20220715-1505': 'Officer_Station_1_Day_0', 'PS-20220715-1512': 'Officer_Station_1_Day_0', 'PS-20220715-1586': 'Officer_Station_1_Day_0', 'PS-20220715-1589': 'Officer_Station_1_Day_0', 'PS-20220715-1601': 'Officer_Station_1_Day_0', 'PS-20220715-1392': 'Officer_Station_1_Day_0', 'PS-20220715-1555': 'Officer_Station_1_Day_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220709-4426': 'Officer_Station_1_Day_1', 'PS-20220715-1662': 'Officer_Station_3_Day_0', 'PS-20220707-1508': 'Officer_Station_2_Day_0', 'PS-20220709-4389': 'Officer_Station_1_Day_1', 'PS-20220709-4399': 'Officer_Station_1_Day_1', 'PS-20220709-4413': 'Officer_Station_1_Day_1', 'PS-20220709-4415': 'Officer_Station_1_Day_1', 'PS-20220715-1634': 'Officer_Station_3_Day_0', 'PS-20220715-1650': 'Officer_Station_1_Day_1', 'PS-20220715-1681': 'Officer_Station_1_Day_1', 'PS-20220715-1685': 'Officer_Station_1_Day_1', 'PS-20220715-1698': 'Officer_Station_1_Day_1', 'PS-20220715-1723': 'Officer_Station_2_Day_0', 'PS-20220715-1747': 'Officer_Station_1_Day_1', 'PS-20220715-1757': 'Officer_Station_2_Day_0', 'PS-20220715-1766': 'Officer_Station_2_Day_0', 'PS-20220715-1770': 'Officer_Station_2_Day_0', 'PS-20220715-1807': 'Officer_Station_3_Day_0', 'PS-20220707-1489': 'Officer_Station_3_Day_0', 'PS-20220709-4422': 'Officer_Station_1_Day_1', 'PS-20220715-1625': 'Officer_Station_3_Day_0', 'PS-20220715-1645': 'Officer_Station_1_Day_1', 'PS-20220715-1652': 'Officer_Station_2_Day_0', 'PS-20220715-1755': 'Officer_Station_1_Day_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220707-1542': 'Officer_Station_1_Night_0', 'PS-20220710-0006': 'Officer_Station_2_Night_0', 'PS-20220715-1912': 'Officer_Station_1_Night_0', 'PS-20220715-1922': 'Officer_Station_1_Night_0', 'PS-20220715-2100': 'Officer_Station_1_Night_0', 'PS-20220707-1538': 'Officer_Station_2_Night_0', 'PS-20220707-1551': 'Officer_Station_3_Night_0', 'PS-20220710-0004': 'Officer_Station_1_Night_0', 'PS-20220710-0008': 'Officer_Station_2_Night_0', 'PS-20220715-1811': 'Officer_Station_1_Night_0', 'PS-20220715-1816': 'Officer_Station_3_Night_0', 'PS-20220715-1818': 'Officer_Station_1_Night_0', 'PS-20220715-1858': 'Officer_Station_1_Night_0', 'PS-20220715-1895': 'Officer_Station_2_Night_0', 'PS-20220715-1914': 'Officer_Station_1_Night_0', 'PS-20220715-1923': 'Officer_Station_2_Night_0', 'PS-20220715-1954': 'Officer_Station_1_Night_0', 'PS-20220715-1958': 'Officer_Station_1_Night_0', 'PS-20220715-1973': 'Officer_Station_1_Night_0', 'PS-20220707-1550': 'Officer_Station_1_Night_0', 'PS-20220715-1819': 'Officer_Station_3_Night_0', 'PS-20220715-1910': 'Officer_Station_1_Night_0', 'PS-20220715-2028': 'Officer_Station_3_Night_0', 'PS-20220715-2075': 'Officer_Station_1_Night_0', 'PS-20220715-2107': 'Officer_Station_1_Night_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220707-1599': 'Officer_Station_2_Night_1', 'PS-20220715-2115': 'Officer_Station_2_Night_1', 'PS-20220715-2208': 'Officer_Station_1_Night_1', 'PS-20220715-2218': 'Officer_Station_3_Night_0', 'PS-20220715-2227': 'Officer_Station_2_Night_1', 'PS-20220707-1578': 'Officer_Station_2_Night_1', 'PS-20220707-1584': 'Officer_Station_3_Night_0', 'PS-20220715-2166': 'Officer_Station_3_Night_0', 'PS-20220715-2172': 'Officer_Station_2_Night_1', 'PS-20220715-2180': 'Officer_Station_1_Night_1', 'PS-20220715-2222': 'Officer_Station_1_Night_1', 'PS-20220715-2242': 'Officer_Station_1_Night_1', 'PS-20220715-2247': 'Officer_Station_1_Night_1', 'PS-20220707-1604': 'Officer_Station_1_Night_1', 'PS-20220710-0012': 'Officer_Station_3_Night_0', 'PS-20220715-2122': 'Officer_Station_1_Night_1', 'PS-20220715-2182': 'Officer_Station_1_Night_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220715-2299': 'Officer_Station_1_Night_2', 'PS-20220707-1617': 'Officer_Station_1_Night_2', 'PS-20220707-1644': 'Officer_Station_1_Night_2', 'PS-20220707-1655': 'Officer_Station_1_Night_2', 'PS-20220707-1660': 'Officer_Station_1_Night_2', 'PS-20220710-0025': 'Officer_Station_1_Night_2', 'PS-20220710-0035': 'Officer_Station_3_Night_1', 'PS-20220710-0036': 'Officer_Station_2_Night_2', 'PS-20220710-0041': 'Officer_Station_2_Night_2', 'PS-20220710-0046': 'Officer_Station_1_Night_2', 'PS-20220715-2270': 'Officer_Station_3_Night_1', 'PS-20220715-2286': 'Officer_Station_1_Night_2', 'PS-20220715-2289': 'Officer_Station_2_Night_2', 'PS-20220715-2294': 'Officer_Station_1_Night_2', 'PS-20220715-2297': 'Officer_Station_1_Night_2', 'PS-20220715-2309': 'Officer_Station_3_Night_1', 'PS-20220715-2315': 'Officer_Station_3_Night_1', 'PS-20220715-2327': 'Officer_Station_3_Night_1', 'PS-20220707-1615': 'Officer_Station_1_Night_2', 'PS-20220707-1621': 'Officer_Station_1_Night_2', 'PS-20220715-2307': 'Officer_Station_1_Night_2'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220707-1695': 'Officer_Station_1_Night_0', 'PS-20220715-2362': 'Officer_Station_3_Night_0', 'PS-20220715-2382': 'Officer_Station_1_Night_0', 'PS-20220715-2440': 'Officer_Station_1_Night_0', 'PS-20220715-2490': 'Officer_Station_1_Night_0', 'PS-20220707-1680': 'Officer_Station_1_Night_0', 'PS-20220707-1712': 'Officer_Station_2_Night_0', 'PS-20220707-1728': 'Officer_Station_1_Night_0', 'PS-20220707-1770': 'Officer_Station_1_Night_0', 'PS-20220707-1791': 'Officer_Station_1_Night_0', 'PS-20220707-1793': 'Officer_Station_1_Night_0', 'PS-20220707-1799': 'Officer_Station_1_Night_0', 'PS-20220715-2349': 'Officer_Station_1_Night_0', 'PS-20220715-2380': 'Officer_Station_1_Night_0', 'PS-20220715-2446': 'Officer_Station_1_Night_0', 'PS-20220715-2510': 'Officer_Station_3_Night_0', 'PS-20220715-2524': 'Officer_Station_1_Night_0', 'PS-20220715-2550': 'Officer_Station_1_Night_0', 'PS-20220707-1721': 'Officer_Station_1_Night_0', 'PS-20220710-0056': 'Officer_Station_1_Night_0', 'PS-20220710-0061': 'Officer_Station_3_Night_0', 'PS-20220715-2417': 'Officer_Station_1_Night_0', 'PS-20220715-2428': 'Officer_Station_1_Night_0', 'PS-20220715-2452': 'Officer_Station_1_Night_0', 'PS-20220715-2475': 'Officer_Station_2_Night_0', 'PS-20220715-2485': 'Officer_Station_1_Night_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220707-1812': 'Officer_Station_2_Night_1', 'PS-20220715-2684': 'Officer_Station_2_Night_1', 'PS-20220715-2836': 'Officer_Station_3_Night_1', 'PS-20220707-1807': 'Officer_Station_1_Night_1', 'PS-20220707-1814': 'Officer_Station_1_Night_1', 'PS-20220707-1823': 'Officer_Station_1_Night_1', 'PS-20220707-1831': 'Officer_Station_1_Night_1', 'PS-20220715-2565': 'Officer_Station_3_Night_1', 'PS-20220715-2576': 'Officer_Station_1_Night_1', 'PS-20220715-2648': 'Officer_Station_1_Night_1', 'PS-20220715-2651': 'Officer_Station_1_Night_1', 'PS-20220715-2701': 'Officer_Station_3_Night_1', 'PS-20220715-2787': 'Officer_Station_3_Night_1', 'PS-20220715-2816': 'Officer_Station_1_Night_1', 'PS-20220715-2846': 'Officer_Station_1_Night_1', 'PS-20220715-2858': 'Officer_Station_3_Night_1', 'PS-20220715-2870': 'Officer_Station_3_Night_1', 'PS-20220715-2625': 'Officer_Station_2_Night_1', 'PS-20220715-2666': 'Officer_Station_1_Night_1', 'PS-20220715-2719': 'Officer_Station_1_Night_1', 'PS-20220715-2730': 'Officer_Station_1_Night_1', 'PS-20220715-2783': 'Officer_Station_2_Night_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220715-2887': 'Officer_Station_2_Night_0', 'PS-20220707-1867': 'Officer_Station_1_Night_0', 'PS-20220707-1868': 'Officer_Station_2_Night_0', 'PS-20220707-1870': 'Officer_Station_3_Night_0', 'PS-20220710-0090': 'Officer_Station_1_Night_0', 'PS-20220715-2871': 'Officer_Station_1_Night_0', 'PS-20220715-2889': 'Officer_Station_1_Night_0', 'PS-20220715-2900': 'Officer_Station_1_Night_0', 'PS-20220715-2983': 'Officer_Station_1_Night_0', 'PS-20220715-2996': 'Officer_Station_3_Night_0', 'PS-20220715-3059': 'Officer_Station_1_Night_0', 'PS-20220715-3060': 'Officer_Station_1_Night_0', 'PS-20220710-0069': 'Officer_Station_2_Night_0', 'PS-20220715-2943': 'Officer_Station_1_Night_0', 'PS-20220715-3071': 'Officer_Station_1_Night_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220707-1881': 'Officer_Station_2_Night_1', 'PS-20220715-3092': 'Officer_Station_1_Night_0', 'PS-20220707-1893': 'Officer_Station_1_Night_0', 'PS-20220707-1894': 'Officer_Station_2_Night_1', 'PS-20220710-0110': 'Officer_Station_3_Night_1', 'PS-20220715-3081': 'Officer_Station_2_Night_1', 'PS-20220715-3090': 'Officer_Station_3_Night_1', 'PS-20220715-3101': 'Officer_Station_1_Night_0', 'PS-20220715-3111': 'Officer_Station_3_Night_1', 'PS-20220715-3112': 'Officer_Station_3_Night_1', 'PS-20220715-3114': 'Officer_Station_1_Night_0', 'PS-20220715-3117': 'Officer_Station_1_Night_0', 'PS-20220710-0138': 'Officer_Station_1_Night_0', 'PS-20220710-0157': 'Officer_Station_1_Night_0', 'PS-20220710-0160': 'Officer_Station_1_Night_0', 'PS-20220715-3186': 'Officer_Station_2_Night_1'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'PS-20220715-3270': 'Officer_Station_1_Night_1', 'PS-20220715-3279': 'Officer_Station_1_Night_1', 'PS-20220707-1901': 'Officer_Station_1_Night_1', 'PS-20220707-1914': 'Officer_Station_2_Night_0', 'PS-20220707-1915': 'Officer_Station_1_Night_1', 'PS-20220707-1956': 'Officer_Station_1_Night_1', 'PS-20220710-0163': 'Officer_Station_3_Night_0', 'PS-20220710-0173': 'Officer_Station_2_Night_0', 'PS-20220710-0183': 'Officer_Station_1_Night_1', 'PS-20220715-3216': 'Officer_Station_3_Night_0', 'PS-20220715-3250': 'Officer_Station_1_Night_1', 'PS-20220715-3261': 'Officer_Station_1_Night_1', 'PS-20220715-3276': 'Officer_Station_1_Night_1', 'PS-20220715-3304': 'Officer_Station_3_Night_0', 'PS-20220707-1929': 'Officer_Station_1_Night_1', 'PS-20220710-0198': 'Officer_Station_3_Night_0'}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {}=
# {'Completion Percentages': {'Immediate': 100.0,
#   'Prompt': 100.0,
#   'Standard': 100.0},
#  'Mean Response Times': {'Immediate': 89.17014370738148,
#   'Prompt': 85.6187916891116,
#   'Standard': 88.81233390244294},
#  'Mean Deployment Times': {'Immediate': 1.5403225806451613,
#   'Prompt': 1.5061196105702366,
#   'Standard': 1.4796755725190842},
#  'Threshold Compliance': {'Immediate': 83.87096774193549,
#   'Prompt': 81.0152990264256,
#   'Standard': 87.02290076335878},
#  'Total Officer Hours': 6291.879963110861,
#  'Unresolved Incident Percentage': 0.0}

# %%
simulation.run(naive_model)
simulation.analyze_simulation_results()
# Out:
# {'Completion Percentages': {'Immediate': 100.0,
#   'Prompt': 100.0,
#   'Standard': 100.0},
#  'Mean Response Times': {'Immediate': 88.31291756055249,
#   'Prompt': 84.39669221166272,
#   'Standard': 87.59333263354172},
#  'Mean Deployment Times': {'Immediate': 1.5403225806451613,
#   'Prompt': 1.5061196105702366,
#   'Standard': 1.4796755725190842},
#  'Threshold Compliance': {'Immediate': 100.0,
#   'Prompt': 100.0,
#   'Standard': 100.0},
#  'Total Officer Hours': 3630.004144118147,
#  'Unresolved Incident Percentage': 0.0}

# %%
import gym
from gym import spaces
import numpy as np

class PoliceAllocationEnv(gym.Env):
    """
    A gym environment for allocating police officers to stations.
    """
    def __init__(self, max_officers, stations=3):
        super(PoliceAllocationEnv, self).__init__()
        self.stations = stations
        self.max_officers = max_officers

        # Define action and observation space
        self.action_space = spaces.MultiDiscrete([max_officers + 1] * stations)
        self.observation_space = spaces.Box(low=0, high=max_officers, shape=(stations,), dtype=np.int32)

        self.state = None

    def reset(self):
        self.state = np.zeros(self.stations, dtype=np.int32)
        return self.state

    def step(self, action):
        # Ensure the total officers do not exceed max_officers
        if sum(action) > self.max_officers:
            reward = -1  # Penalize invalid actions
            done = True
        else:
            self.state = action
            reward = self.calculate_reward()
            done = False  # Can implement a condition to end the episode

        return self.state, reward, done, {}

    def calculate_reward(self):
        # Placeholder: Implement the logic to calculate the reward
        reward = 0
        # Example: Reward could be based on the coverage and efficiency of allocation
        return reward

    def close(self):
        pass  # Optional: Cleanup

# %%
import itertools

def generate_shift_distributions(num_officers_per_station, total_shifts=3):
    """
    Generates all possible distributions of officers across three police stations for a given shift.

    :param num_officers_per_station: List of number of officers at each station.
    :param total_shifts: Total number of shifts to consider.
    :return: List of dictionaries representing different officer distributions for each shift.
    """
    distributions = []

    # Generate all combinations of officer distributions for the given numbers
    for distribution in itertools.product(num_officers_per_station, repeat=total_shifts):
        shift_distribution = {
            'Early': {'Station_1': distribution[0], 'Station_2': distribution[1], 'Station_3': distribution[2]},
            'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},  # Keeping day shift constant
            'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}  # Keeping night shift constant
        }
        distributions.append(shift_distribution)

    return distributions

# %%
def run_simulations(data, ps_coords, num_officers_per_station, model):
    distributions = generate_shift_distributions(num_officers_per_station)
    simulation_results = []

    for distribution in distributions:
        simulation = SimulationWithMaxUtilisation(data, ps_coords, distribution, verbose=1)
        simulation.run(model)
        res = simulation.analyze_simulation_results()
        result = calculate_composite_metric(res)
        simulation_results.append((distribution, result))
    
    return simulation_results

# %%
results = run_simulations(data, ps_coords, [4, 5, 6], naive_model)

# %%
def calculate_composite_metric(simulation_results, compliance_weight=2, deployment_weight=1, completion_weight=1):
    """
    Calculate a composite metric from simulation results.

    :param simulation_results: The results from the simulation.
    :param compliance_weight: The weight for threshold compliance in the metric.
    :param deployment_weight: The weight for mean deployment time in the metric.
    :param completion_weight: The weight for completion percentage in the metric.
    :return: The composite metric value.
    """
    mean_deployment_time = sum(simulation_results['Mean Deployment Times'].values()) / len(simulation_results['Mean Deployment Times'])
    threshold_compliance = sum(simulation_results['Threshold Compliance'].values()) / len(simulation_results['Threshold Compliance'])
    completion_percentage = sum(simulation_results['Completion Percentages'].values()) / len(simulation_results['Completion Percentages'])

    # Calculate composite metric
    metric = (compliance_weight * threshold_compliance +
              deployment_weight * mean_deployment_time +
              completion_weight * completion_percentage)

    return metric

# %%
naive_model = NaiveModel()

# %%
results
# Out:
# [({'Early': {'Station_1': 4, 'Station_2': 4, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 4, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 4, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 5, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 5, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 5, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 6, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 6, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 6, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 4, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 4, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 4, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 6, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 6, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 6, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 4, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 4, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 4, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 5, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 5, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 5, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 6, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 6, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 6, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448)]

# %%
def generate_early_shift_distributions(total_officers=15, stations=3):
    """
    Generates all possible distributions of officers across three police stations 
    for the early shift that sum up to a specific total.

    :param total_officers: Total number of officers to be distributed.
    :param stations: Number of stations.
    :return: List of tuples representing different officer distributions for the early shift.
    """
    distributions = []

    # Iterate through all possible combinations
    for distribution in itertools.product(range(total_officers + 1), repeat=stations):
        if sum(distribution) == total_officers:
            distributions.append(distribution)

    return distributions

# %%
shift_distribution = {
    'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3': 5},
    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}
}

ps_coords = [ (p.x, p.y) for p in 
                [police_stations.one, 
                 police_stations.two, 
                 police_stations.three]]

naive_model = NaiveModel()

# %%
early_shift_dist = generate_early_shift_distributions()
simulation_results = []
for dist in distributions:
    new_shift_distribution = dict(shift_distribution)
    new_shift_distribution["Early"] = {'Station_1': dist[0], 'Station_2':dist[1], 'Station_3':dist[2]}
    simulation = SimulationWithMaxUtilisation(data, ps_coords, new_shift_distribution, verbose=1)
    simulation.run(naive_model)
    print(simulation.officers)
    res = simulation.analyze_simulation_results()
    result = calculate_composite_metric(res)
    simulation_results.append((new_shift_distribution, result))
# Out:
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762), Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662), Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614), Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0), Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)], 'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617), Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687), Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196), Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0), Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)], 'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778), Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407), Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0), Officer(name='Officer_Station_3_Night_1 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 7
#       5 new_shift_distribution["Early"] = {'Station_1': dist[0], 'Station_2':dist[1], 'Station_3':dist[2]}
#       6 simulation = SimulationWithMaxUtilisation(data, ps_coords, new_shift_distribution, verbose=1)
# ----> 7 simulation.run(naive_model)
#       8 print(simulation.officers)
#       9 res = simulation.analyze_simulation_results()
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/edinburgh_challenge/simulation.py:182, in SimulationWithMaxUtilisation.run(self, model)
#     178 total_officers = len(self.officers["Station_1"]) + len(self.officers["Station_2"]) + len(self.officers["Station_3"])
#     179 #print(f"{total_officers=}")
#     180
#     181 # Generate and add new incidents
# --> 182 new_incidents = self.generate_incidents_for_hour(self.current_time)
#     183 self.cumulative_incidents.extend(new_incidents)
#     185 # Filter to get only pending incidents
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/edinburgh_challenge/simulation.py:104, in SimulationWithMaxUtilisation.generate_incidents_for_hour(self, global_time)
#     102 hour_incidents = self.df[(self.df['time'] == global_time)]
#     103 incidents = []
# --> 104 for _, row in hour_incidents.iterrows():
#     105     deployment_time = row.pop("deployment time (hrs)")
#     106     row.pop("time")  # Not needed as we use global_time
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/venv/lib/python3.11/site-packages/pandas/core/frame.py:1450, in DataFrame.iterrows(self)
#    1448 using_cow = using_copy_on_write()
#    1449 for k, v in zip(self.index, self.values):
# -> 1450     s = klass(v, index=columns, name=k).__finalize__(self)
#    1451     if using_cow and self._mgr.is_single_block:
#    1452         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/venv/lib/python3.11/site-packages/pandas/core/series.py:512, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     510         data = data.copy()
#     511 else:
# --> 512     data = sanitize_array(data, index, dtype, copy)
#     514     manager = get_option("mode.data_manager")
#     515     if manager == "block":
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/venv/lib/python3.11/site-packages/pandas/core/construction.py:553, in sanitize_array(data, index, dtype, copy, allow_2d)
#     550     dtype = dtype.numpy_dtype
#     552 object_index = False
# --> 553 if isinstance(data, ABCIndex) and data.dtype == object and dtype is None:
#     554     object_index = True
#     556 # extract ndarray or ExtensionArray, ensure we have no NumpyExtensionArray
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/venv/lib/python3.11/site-packages/pandas/core/dtypes/generic.py:44, in create_pandas_abc_type.<locals>._instancecheck(cls, inst)
#      42 @classmethod  # type: ignore[misc]
#      43 def _instancecheck(cls, inst) -> bool:
# ---> 44     return _check(inst) and not isinstance(inst, type)
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/venv/lib/python3.11/site-packages/pandas/core/dtypes/generic.py:37, in create_pandas_abc_type.<locals>._check(inst)
#      36 def create_pandas_abc_type(name, attr, comp):
# ---> 37     def _check(inst) -> bool:
#      38         return getattr(inst, attr, "_typ") in comp
#      40     # https://github.com/python/mypy/issues/1006
#      41     # error: 'classmethod' used with a non-method
#
# KeyboardInterrupt:

# %%
simulation_results
# Out:
# [({'Early': {'Station_1': 0, 'Station_2': 0, 'Station_3': 15},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 1, 'Station_3': 14},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 2, 'Station_3': 13},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 3, 'Station_3': 12},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 4, 'Station_3': 11},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 6, 'Station_3': 9},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 7, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 8, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 9, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 10, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 11, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 12, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 13, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 14, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 0, 'Station_2': 15, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 0, 'Station_3': 14},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 1, 'Station_3': 13},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 2, 'Station_3': 12},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 3, 'Station_3': 11},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 4, 'Station_3': 10},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 5, 'Station_3': 9},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 6, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 7, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 8, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 9, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 10, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 11, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 12, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 13, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 1, 'Station_2': 14, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 0, 'Station_3': 13},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 1, 'Station_3': 12},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 2, 'Station_3': 11},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 3, 'Station_3': 10},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 4, 'Station_3': 9},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 5, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 6, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 7, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 8, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 9, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 10, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 11, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 12, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 2, 'Station_2': 13, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 0, 'Station_3': 12},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 1, 'Station_3': 11},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 2, 'Station_3': 10},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 3, 'Station_3': 9},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 4, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 5, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 6, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 7, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 8, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 9, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 10, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 11, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 3, 'Station_2': 12, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 0, 'Station_3': 11},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 1, 'Station_3': 10},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 2, 'Station_3': 9},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 3, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 4, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 5, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 6, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 7, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 8, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 9, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 10, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 4, 'Station_2': 11, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 0, 'Station_3': 10},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 1, 'Station_3': 9},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 2, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 3, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 4, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 6, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 7, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 8, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 9, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 5, 'Station_2': 10, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 0, 'Station_3': 9},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 1, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 2, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 3, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 4, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 5, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 6, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 7, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 8, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 6, 'Station_2': 9, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 0, 'Station_3': 8},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 1, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 2, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 3, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 4, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 5, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 6, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 7, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 7, 'Station_2': 8, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 0, 'Station_3': 7},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 1, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 2, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 3, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 4, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 5, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 6, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 8, 'Station_2': 7, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 9, 'Station_2': 0, 'Station_3': 6},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 9, 'Station_2': 1, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 9, 'Station_2': 2, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 9, 'Station_2': 3, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 9, 'Station_2': 4, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 9, 'Station_2': 5, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 9, 'Station_2': 6, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 10, 'Station_2': 0, 'Station_3': 5},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 10, 'Station_2': 1, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 10, 'Station_2': 2, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 10, 'Station_2': 3, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 10, 'Station_2': 4, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 10, 'Station_2': 5, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 11, 'Station_2': 0, 'Station_3': 4},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 11, 'Station_2': 1, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 11, 'Station_2': 2, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 11, 'Station_2': 3, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 11, 'Station_2': 4, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 12, 'Station_2': 0, 'Station_3': 3},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 12, 'Station_2': 1, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 12, 'Station_2': 2, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 12, 'Station_2': 3, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 13, 'Station_2': 0, 'Station_3': 2},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 13, 'Station_2': 1, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 13, 'Station_2': 2, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 14, 'Station_2': 0, 'Station_3': 1},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 14, 'Station_2': 1, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448),
#  ({'Early': {'Station_1': 15, 'Station_2': 0, 'Station_3': 0},
#    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#   301.5087059212448)]

# %%
sim = SimulationWithMaxUtilisation(data, ps_coords, {'Early': {'Station_1': 2, 'Station_2': 2, 'Station_3': 11},
 'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
 'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}})

# %%
new_shift_distribution
# Out:
# {'Early': {'Station_1': 2, 'Station_2': 2, 'Station_3': 11},
#  'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#  'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}}

# %%
sim.run(naive_model)

# %%
sim.officers
# Out:
# {'Station_1': [Officer(name='Officer_Station_1_Night_0', station='Station_1', available=True, return_time=167.37891324748762),
#   Officer(name='Officer_Station_1_Night_1', station='Station_1', available=False, return_time=168.96036832642662),
#   Officer(name='Officer_Station_1_Night_2', station='Station_1', available=True, return_time=162.64887202736614),
#   Officer(name='Officer_Station_1_Night_3', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_4', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_5', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_6', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_7', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_8', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_9', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_10', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_11', station='Station_1', available=True, return_time=0.0),
#   Officer(name='Officer_Station_1_Night_12', station='Station_1', available=True, return_time=0.0)],
#  'Station_2': [Officer(name='Officer_Station_2_Night_0', station='Station_2', available=False, return_time=169.0159053676617),
#   Officer(name='Officer_Station_2_Night_1', station='Station_2', available=False, return_time=168.18899902771687),
#   Officer(name='Officer_Station_2_Night_2', station='Station_2', available=True, return_time=164.36554777951196),
#   Officer(name='Officer_Station_2_Night_3', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_4', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_5', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_6', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_7', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_8', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_9', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_10', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_11', station='Station_2', available=True, return_time=0.0),
#   Officer(name='Officer_Station_2_Night_12', station='Station_2', available=True, return_time=0.0)],
#  'Station_3': [Officer(name='Officer_Station_3_Night_0', station='Station_3', available=False, return_time=169.50699085914778),
#   Officer(name='Officer_Station_3_Night_1', station='Station_3', available=False, return_time=168.05286167506407),
#   Officer(name='Officer_Station_3_Night_2', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_3', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_4', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_5', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_6', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_7', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_8', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_9', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_10', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_11', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_12', station='Station_3', available=True, return_time=0.0),
#   Officer(name='Officer_Station_3_Night_13', station='Station_3', available=True, return_time=0.0)]}
