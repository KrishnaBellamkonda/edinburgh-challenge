# %%
import heapq
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
from math import floor, ceil, inf

from edinburgh_challenge.constants import police_stations, police_stations_dict
from edinburgh_challenge.utility import generate_early_shift_distributions
from edinburgh_challenge.models import NaiveModel, GreedyModel
from edinburgh_challenge.simulation import *
from edinburgh_challenge.processing import calculate_metric, calculate_simulation_performance

# %%
source = "./data.xlsx"
data = pd.read_excel(source)
data["Time"] = (data["Day"]-1)*24 + data["Hour"]
data.columns = [x.lower() for x in data.columns]

# %% [markdown]
# ## Making a new model with Bayesian Optimisation

# %%
import numpy as np
from scipy.optimize import minimize
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

class BayesianOptimizationModel(NaiveModel):
    def __init__(self):
        super().__init__()
        self.kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
        self.gp = GaussianProcessRegressor(kernel=self.kernel, n_restarts_optimizer=9)
        self.training_data = []
        self.training_targets = []

    def update_model(self, incident_data, success_metric):
        # Update the Gaussian Process model with new data
        self.training_data.append(incident_data)
        self.training_targets.append(success_metric)
        self.gp.fit(self.training_data, self.training_targets)

    def predict_incident_load(self, current_time):
        # Predict the number of incidents based on current time
        # Note: This is a placeholder function. You'll need to define how the current_time
        # translates into features for your model.
        incident_load_prediction = self.gp.predict(np.array([[current_time]]))
        return incident_load_prediction

    def make_allocation(self, incidents, officers, current_time):
        # Predict the incident load
        predicted_load = self.predict_incident_load(current_time)
        print(f"{predicted_load=}")

        # Modify your allocation strategy based on the predicted load
        # For example, prioritize allocation of officers in high-load time slots

        # For now, we'll call the base class method, but you can modify this
        # to incorporate the predicted incident load.
        return super().make_allocation(incidents, officers, current_time)

# Example usage
# Example of updating the model with new data
# model.update_model(incident_data, success_metric)

# Example of making an allocation decision
# allocations = model.make_allocation(incidents, officers, current_time)

# %%
from collections import defaultdict
import numpy as np

class BayesianOptimizationModel():
    def __init__(self):
        super().__init__()
        self.incidents_history = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
        self.resolution_times = defaultdict(list)

    def calculate_travel_time(self, incident, officer):
        incident_location = Location(x=incident.latitude, y=incident.longitude)
        station_location = police_stations[officer.station]
        distance_miles = calculate_distance(station_location, incident_location)
        travel_time = distance_miles / SPEED_MPH
        return travel_time

    def update_history(self, incident):
        day = incident.day
        hour = incident.hour
        priority = incident.priority
        self.incidents_history[day % 7][hour][priority] += 1

    def estimate_incident_load(self, current_day, current_hour, priority):
        # Estimate based on the previous day's load
        previous_day = (current_day - 1) % 7
        estimated_load = self.incidents_history[previous_day][current_hour][priority]
        return estimated_load


    def make_allocation(self, incidents, officers, current_time):
        current_day = int(current_time // 24)
        current_hour = int(current_time % 24)
        allocations = {}
        officers_allocated = []

        for inc in incidents:
            allocated = False
            sorted_stations = sorted(inc.distances, key=inc.distances.get)

            for station in sorted_stations:
                available_officers = [off for off in officers[station] if off.available and off not in officers_allocated]
                if available_officers:
                    # Estimate incident load for the next hour
                    estimated_load_next_hour = self.estimate_incident_load(current_day, (current_hour + 1) % 24, inc.priority)
                    # Check if officer should wait for next hour's cases
                    if inc.priority in ['standard', 'prompt'] and estimated_load_next_hour > threshold:
                        allocations[inc.urn] = None
                        continue  # Skip to next incident; wait for potentially more important cases

                    chosen_officer = available_officers[0]
                    allocations[inc.urn] = chosen_officer.name
                    officers_allocated.append(chosen_officer)
                    allocated = True
                    break

            if allocated:
                self.update_history(inc)

            if not allocated:
                allocations[inc.urn] = None

        return allocations

# Example usage
model = BayesianOptimizationModel()

# Example of making an allocation decision
# allocations = model.make_allocation(incidents, officers, current_time)

# %%
from collections import defaultdict
from math import floor

class SimplifiedModel(NaiveModel):
    def __init__(self, shift_distribution):
        super().__init__()
        # Initialize a dictionary to count incidents per hour
        self.incidents_per_hour = defaultdict(lambda: defaultdict(int))
        
        # Initialize a dictionary to store resolution times for each priority type
        self.deployment_times = {'Immediate': [], 'Prompt': [], 'Standard': []}

        # Set to keep track of processed incidents
        self.processed_incidents = set()

        self.shift_distribution = shift_distribution

    def get_shift_officers_count(self, shift):
        """
        Get the number of officers available for a given shift.
        """
        shift_officers = self.shift_distribution[shift].values()
        return sum(shift_officers)
        
    
    def calculate_minimum_required_officers(self, current_time):
        """
        Calculate the minimum number of officers required for the next hour.
        """
        today = (int(current_time)  // 24)
        next_hour = (int(current_time) + 1) % 24
        next_shift = self.get_current_shift(next_hour)
        next_shift_officers = self.get_shift_officers_count(next_shift)

        predicted_incidents_next_hour = self.incidents_per_hour[today][next_hour]
            
        print(predicted_incidents_next_hour)
        minimum_required = floor((predicted_incidents_next_hour - next_shift_officers) / 2)
        return max(0, minimum_required)  # Ensuring the number is not negative
    
    
    def update_incident_count(self, incidents):
        """
        Update the count of incidents for each hour of each day.
        Only update for new incidents.
        """
        for incident in incidents:
            if incident.urn not in self.processed_incidents:
                day = incident.day
                hour = incident.hour
                self.incidents_per_hour[day][hour] += 1
                self.processed_incidents.add(incident.urn)

    def update_resolution_times(self, incidents):
        """
        Update the resolution times list for the given priority type of the incident.
        Only update for resolved incidents that haven't been processed before.
        """
        for incident in incidents:
            if incident.urn not in self.processed_incidents and incident.resolved:
                priority = incident.priority
                deployment_time = incident.deployment_time
                self.deployment_times[priority].append(deployment_time)
                self.processed_incidents.add(incident.urn)

    def get_current_shift(self, current_time):
        """
        Determine the current shift based on the current time.
        """
        hour = current_time % 24
        if 0 <= hour < 8:
            return 'Early'
        elif 8 <= hour < 16:
            return 'Day'
        else:
            return 'Night'
    
    def make_allocation(self, incidents, officers, current_time):
        """
        Allocate officers to incidents based on the number of expected incidents
        for the next hour and the number of available officers in the shift.
        """

        # Update incident counts and resolution times
        self.update_incident_count(incidents)
        self.update_resolution_times(incidents)

        day = current_time // 24 + 1
        time = current_time % 24

        if day == 1:
            return super().make_allocation(incidents, officers, current_time)
        
        # Calculate minimum required officers for the next hour
        min_required_officers = self.calculate_minimum_required_officers(current_time)
        
        # Determine the current shift
        current_shift = self.get_current_shift(current_time)

        print(f"{min_required_officers=}")
        
        
         # Perform allocations
        allocations = {}
        officers_resting = 0
        for inc in incidents:
            if inc.priority in ['Standard'] and officers_resting < min_required_officers:
                # Skip allocating "Standard" and "Prompt" cases to rest officers
                allocations[inc.urn] = None
                officers_resting += 1
            else:
                # Existing allocation logic for "Immediate" cases and others
                allocations[inc.urn] = super().make_allocation([inc], officers, current_time)

        return allocations



# Assuming you have a list of incidents
# model.make_allocation(incidents)

# %%
class SimplifiedModel(NaiveModel):

    SPEED_MPH = 30
    
    def __init__(self, shift_distribution, police_stations_dict):
        super().__init__()
        self.shift_distribution = shift_distribution
        self.incident_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
        self.resolution_times = {"Immediate":[], "Standard":[], "Prompt":[]}
        self.processed_incidents = set()
        self.police_stations_dict = police_stations_dict
        
    def update_incident_count(self, incidents):
        """
        Update the count of incidents for each hour of each day.
        Only update for new incidents.
        """
        for incident in incidents:
            if incident.urn not in self.processed_incidents:
                day = incident.day
                hour = incident.hour
                priority = incident.priority
                self.incident_counts[day][hour][priority] += 1
                self.processed_incidents.add(incident.urn)

    def calculate_distance(self, lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between two points
        on the earth (specified in decimal degrees)
        """
        # Convert decimal degrees to radians
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

        # Haversine formula
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a))
        r = 3956  # Radius of Earth in miles. Use 6371 for kilometers
        return c * r

    
    def get_incident_resolution_time(self, incident, officer, current_time):
        officer_police_station_location = self.police_stations_dict[officer.station] 
        distance_to_incident = self.calculate_distance(officer_police_station_location.x, 
                                                  officer_police_station_location.y,
                                                  incident.latitude, 
                                                  incident.longitude
                                                 )
        travel_time = distance_to_incident / self.SPEED_MPH
        deployment_time = incident.deployment_time
        resolution_time = current_time + travel_time + deployment_time
        return resolution_time

    def get_incident_priority_count(self, incidents):
        counts = defaultdict(int)
        for inc in incidents:
            if not inc.resolved:
                counts[inc.priority] += 1
        return counts

    def get_no_available_officers_next_hour(self, officers, current_time):
        next_hour = ceil(current_time)
        no_available_officers = 0
        for station in officers.values():
            for officer in station:
                if officer.available:
                    no_available_officers += 1
                else:
                    if officer.return_time <= next_hour:
                        no_available_officers += 1
        return no_available_officers
            

    def get_mean_resolution_time(self):
        return {
            "Immediate":np.mean(self.resolution_times["Immediate"]), 
            "Prompt":np.mean(self.resolution_times["Prompt"]),
            "Standard": np.mean(self.resolution_times["Standard"])
        }
    
    def make_allocation(self, incidents, officers, current_time):
        self.update_incident_count(incidents)

        day = current_time // 24 + 1
        hour = floor(current_time % 24)
        incidents.sort(key=lambda inc: inc.priority)
        
        if day == 1:  
            allocations = {}
            officers_allocated = []
            for inc in incidents:
                allocated = False
                # Sort stations by distance to the incident
                sorted_stations = sorted(inc.distances, key=inc.distances.get)                                    
                
                for station in sorted_stations:
                    # Check for available officer in the station
                    available_officers = [off for off in officers[station] if (off.available and off not in officers_allocated) ]
                    
                    if available_officers:
                        # Allocate the first available officer
                        chosen_officer = available_officers[0]
                        allocations[inc.urn] = chosen_officer.name
                        officers_allocated.append(chosen_officer)
                        allocated = True
    
                        # If allocated, calculate the 
                        # total resolution time
                        # and save it in a dictionary
                        resolution_time = self.get_incident_resolution_time(inc, chosen_officer, current_time)
                        self.resolution_times[inc.priority].append(resolution_time)
                        break
                        
                if not allocated:
                    # No officers available for this incident
                    allocations[inc.urn] = None
        else:
           
            # Get an estimate of the number of previous immediate, promt
            # and standard cases
            next_immediate_cases = self.incident_counts[day-1][hour]["Immediate"]
            next_prompt_cases = self.incident_counts[day-1][hour]["Prompt"]
            next_standard_cases = self.incident_counts[day-1][hour]["Standard"]
            next_necessary_cases = next_immediate_cases + next_prompt_cases
            
            # Current number of cases
            incident_counts = self.get_incident_priority_count(incidents)
            now_immediate_cases = incident_counts["Immediate"]
            now_prompt_cases = incident_counts["Prompt"]
            now_standard_cases = incident_counts["Standard"]
            now_necessary_cases = now_immediate_cases + now_standard_cases
            
            no_available_officers_next_hour = self.get_no_available_officers_next_hour(officers, current_time)
            
            print(no_available_officers_next_hour)
            print(f"{now_necessary_cases=}")
            print(f"{next_necessary_cases=}")
            
            # If a standard case is being assigned, and we expect a more important prompt case to 
            # be issued in the next hour, we wait. 
            allocations = {}
            officers_allocated = []
            for inc in incidents:
                if inc.priority == "Standard":
                    pass
                else: 
                    allocated = False
                    # Sort stations by distance to the incident
                    sorted_stations = sorted(inc.distances, key=inc.distances.get)                                    
                    
                    for station in sorted_stations:
                        # Check for available officer in the station
                        available_officers = [off for off in officers[station] if (off.available and off not in officers_allocated) ]
                        
                        if available_officers:
                            # Allocate the first available officer
                            chosen_officer = available_officers[0]
                            allocations[inc.urn] = chosen_officer.name
                            officers_allocated.append(chosen_officer)
                            allocated = True
        
                            # If allocated, calculate the 
                            # total resolution time
                            # and save it in a dictionary
                            resolution_time = self.get_incident_resolution_time(inc, chosen_officer, current_time)
                            self.resolution_times[inc.priority].append(resolution_time)
                            break

        return allocations

# %%
class SimplifiedModel(NaiveModel):

    SPEED_MPH = 30
    
    def __init__(self, shift_distribution, police_stations_dict):
        super().__init__()
        self.shift_distribution = shift_distribution
        self.incident_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
        self.resolution_times = {"Immediate":[], "Standard":[], "Prompt":[]}
        self.processed_incidents = set()
        self.police_stations_dict = police_stations_dict
        
    def update_incident_count(self, incidents):
        """
        Update the count of incidents for each hour of each day.
        Only update for new incidents.
        """
        for incident in incidents:
            if incident.urn not in self.processed_incidents:
                day = incident.day
                hour = incident.hour
                priority = incident.priority
                self.incident_counts[day][hour][priority] += 1
                self.processed_incidents.add(incident.urn)

    def calculate_distance(self, lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between two points
        on the earth (specified in decimal degrees)
        """
        # Convert decimal degrees to radians
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

        # Haversine formula
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a))
        r = 3956  # Radius of Earth in miles. Use 6371 for kilometers
        return c * r

    
    def get_incident_resolution_time(self, incident, officer, current_time):
        officer_police_station_location = self.police_stations_dict[officer.station] 
        distance_to_incident = self.calculate_distance(officer_police_station_location.x, 
                                                  officer_police_station_location.y,
                                                  incident.latitude, 
                                                  incident.longitude
                                                 )
        travel_time = distance_to_incident / self.SPEED_MPH
        deployment_time = incident.deployment_time
        resolution_time = current_time + travel_time + deployment_time
        return resolution_time

    def get_incident_priority_count(self, incidents):
        counts = defaultdict(int)
        for inc in incidents:
            if not inc.resolved:
                counts[inc.priority] += 1
        return counts

    def get_no_available_officers_next_hour(self, officers, current_time):
        next_hour = ceil(current_time)
        no_available_officers = 0
        for station in officers.values():
            for officer in station:
                if officer.available:
                    no_available_officers += 1
                else:
                    if officer.return_time <= next_hour:
                        no_available_officers += 1
        return no_available_officers
            

    def get_mean_resolution_time(self):
        return {
            "Immediate":np.mean(self.resolution_times["Immediate"]), 
            "Prompt":np.mean(self.resolution_times["Prompt"]),
            "Standard": np.mean(self.resolution_times["Standard"])
        }
    

    def make_allocation(self, incidents, officers, current_time):
        self.update_incident_count(incidents)
    
        # Define thresholds and priority weights for each priority
        thresholds = {
            'Immediate': 1,  # 1 hour
            'Prompt': 3,     # 3 hours
            'Standard': 6    # 6 hours
        }
        priority_weights = {
            'Immediate': 9,  # 3 times more priority than Standard
            'Prompt': 2.3,   # 1.5 times more priority than Standard
            'Standard': 1    # Base priority
        }
    
        # Get all available officers
        available_officers = [off for station_officers in officers.values() for off in station_officers if off.available]
    
        allocations = {}
    
        for officer in available_officers:
            # Create a priority queue for incidents based on urgency from this officer's station
            officer_station = officer.station
            officer_station_location = self.police_stations_dict[officer_station]
            incident_queue = []
    
            for inc in incidents:
                if inc.urn not in allocations:  # Only consider unallocated incidents
                    travel_time = self.calculate_distance(
                        officer_station_location.x, officer_station_location.y, 
                        inc.latitude, inc.longitude) / self.SPEED_MPH
                    time_since_reported = current_time - inc.global_time
                    # Adjusted urgency calculation
                    urgency = (time_since_reported + travel_time) / (thresholds[inc.priority] * priority_weights[inc.priority])
                    heapq.heappush(incident_queue, (urgency, inc.urn, inc))
    
            # Allocate this officer to the most urgent incident
            if incident_queue:
                _, _, most_urgent_incident = heapq.heappop(incident_queue)
                allocations[most_urgent_incident.urn] = officer.name
                travel_time = self.calculate_distance(
                    officer_station_location.x, officer_station_location.y, 
                    most_urgent_incident.latitude, most_urgent_incident.longitude) / self.SPEED_MPH
                resolution_time = current_time + travel_time + most_urgent_incident.deployment_time
                self.resolution_times[most_urgent_incident.priority].append(resolution_time)
    
        # Mark unallocated incidents
        for inc in incidents:
            if inc.urn not in allocations:
                allocations[inc.urn] = None
    
        return allocations

    def make_allocation(self, incidents, officers, current_time):
        self.update_incident_count(incidents)
    
        # Define thresholds for each priority
        thresholds = {
            'Immediate': 1,  # 1 hour
            'Prompt': 3,     # 3 hours
            'Standard': 6    # 6 hours
        }
    
        # Get all available officers
        available_officers = [off for station_officers in officers.values() for off in station_officers if off.available]
    
        allocations = {}
    
        # Priority queue: (adjusted time to threshold, URN, incident object)
        priority_queue = []
    
        for officer in available_officers:
            # Create a priority queue for incidents based on urgency from this officer's station
            officer_station = officer.station
            officer_station_location = self.police_stations_dict[officer_station]
            incident_queue = []
        
            for inc in incidents:
                if inc.urn not in allocations:  # Only consider unallocated incidents
                    travel_time = self.calculate_distance(
                        officer_station_location.x, 
                        officer_station_location.y, 
                        inc.latitude, inc.longitude) / self.SPEED_MPH
                    elapsed_time = current_time - inc.global_time + travel_time
                    time_to_threshold = thresholds[inc.priority] - elapsed_time
        
                    # Adjust time based on priority (lower is more urgent)
                    adjusted_time = time_to_threshold / thresholds[inc.priority]
                    heapq.heappush(incident_queue, (max(adjusted_time, 0), inc.urn, inc))
        
            # Allocate this officer to the most urgent incident
            if incident_queue:
                _, _, most_urgent_incident = heapq.heappop(incident_queue)
                allocations[most_urgent_incident.urn] = officer.name
                travel_time = self.calculate_distance(
                    officer_station_location.x, 
                    officer_station_location.y, 
                    most_urgent_incident.latitude, most_urgent_incident.longitude) / self.SPEED_MPH
                resolution_time = current_time + travel_time + most_urgent_incident.deployment_time
                self.resolution_times[most_urgent_incident.priority].append(resolution_time)

    
        while available_officers and priority_queue:
            _, _, most_urgent_incident = heapq.heappop(priority_queue)
            chosen_officer = available_officers.pop(0)
            allocations[most_urgent_incident.urn] = chosen_officer.name
    
            travel_time = self.calculate_distance(
                self.police_stations_dict[chosen_officer.station].x, 
                self.police_stations_dict[chosen_officer.station].y, 
                most_urgent_incident.latitude, most_urgent_incident.longitude) / self.SPEED_MPH
            resolution_time = current_time + travel_time + most_urgent_incident.deployment_time
            self.resolution_times[most_urgent_incident.priority].append(resolution_time)
    
        # Mark unallocated incidents
        for inc in incidents:
            if inc.urn not in allocations:
                allocations[inc.urn] = None
    
        return allocations

# %% [markdown]
# ## Running

# %%
shift_distribution = {'Early': {'Station_1': 7, 'Station_2': 0, 'Station_3': 8},
  'Day': {'Station_1': 0, 'Station_2': 0, 'Station_3': 25},
  'Night': {'Station_1': 0, 'Station_2': 11, 'Station_3': 29}
}

ps_coords = [ (p.x, p.y) for p in 
                [police_stations.one, 
                 police_stations.two, 
                 police_stations.three]]

simulation = SimulationWithMaxUtilisation(data, ps_coords, shift_distribution, 
                        verbose=0)

# %%
simple_model = SimplifiedModel({'Early': {'Station_1': 7, 'Station_2': 0, 'Station_3': 8},
  'Day': {'Station_1': 0, 'Station_2': 0, 'Station_3': 25},
  'Night': {'Station_1': 0, 'Station_2': 11, 'Station_3': 29}
}, police_stations_dict)

# %%
simulation.run(simple_model)

# %%
simulation.analyze_simulation_results()
# Out:
# {'Completion Percentages': {'Immediate': 100.0,
#   'Prompt': 100.0,
#   'Standard': 100.0},
#  'Mean Response Times': {'Immediate': 88.39607755668068,
#   'Prompt': 84.75425644714859,
#   'Standard': 88.27611121336604},
#  'Mean Deployment Times': {'Immediate': 1.5403225806451613,
#   'Prompt': 1.5061196105702366,
#   'Standard': 1.4796755725190842},
#  'Threshold Compliance': {'Immediate': 99.35483870967742,
#   'Prompt': 98.40055632823366,
#   'Standard': 98.85496183206108},
#  'Mean Officer Hours': 56.59671361718129,
#  'Unresolved Incident Percentage': 0.0}

# %%
calculate_simulation_performance(simulation.analyze_simulation_results())
# Out:
# 0.25141170071826907

# %%
simple_model.get_mean_resolution_time()
# Out:
# /dcs/21/u2112484/Desktop/EdinburghChallenge/edinburgh-challenge/venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /dcs/21/u2112484/Desktop/EdinburghChallenge/edinburgh-challenge/venv/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'Immediate': nan, 'Prompt': nan, 'Standard': nan}

# %%
simulation.analyze_simulation_results()
# Out:
# {'Completion Percentages': {'Immediate': 100.0,
#   'Prompt': 100.0,
#   'Standard': 100.0},
#  'Mean Response Times': {'Immediate': 88.35582154003671,
#   'Prompt': 84.6725934841217,
#   'Standard': 88.4226394118733},
#  'Mean Deployment Times': {'Immediate': 1.5403225806451613,
#   'Prompt': 1.5061196105702366,
#   'Standard': 1.4796755725190842},
#  'Threshold Compliance': {'Immediate': 100.0,
#   'Prompt': 99.23504867872045,
#   'Standard': 98.09160305343512},
#  'Mean Officer Hours': 55.93258949250007,
#  'Unresolved Incident Percentage': 0.0}

# %%
[inc for inc in simulation.cumulative_incidents if inc.priority=="Standard" and not inc.resolved]
# Out:
# []

# %%
simulation.check_simulation()
# Out:
# ({'Officer_Station_1_Early_0': [2.431411402723678,
#    3.1436983359924007,
#    4.382356757576556,
#    5.63571454264296,
#    7.137892333343168,
#    8.063642970582865,
#    26.503357785066402,
#    29.525466189928398,
#    31.809935477858485,
#    48.8431486746854,
#    51.050669414937985,
#    54.05192075826498,
#    55.81573362528404,
#    74.3114083803523,
#    75.55052388005895,
#    77.1871251316235,
#    79.17754672190138,
#    96.52331854212957,
#    98.39964575742502,
#    100.9506380512824,
#    103.10687547714551,
#    104.87515334999925,
#    120.87194718030646,
#    123.05394385050668,
#    126.33141140272367,
#    127.86118872618657,
#    146.0398404019603,
#    148.54534919760798,
#    151.13441680192514],
#   'Officer_Station_1_Early_1': [1.4063470779965093,
#    2.227006914479122,
#    2.8851955785536942,
#    4.3245816026374415,
#    6.523354245321365,
#    7.042627490547426,
#    7.957626776253839,
#    26.340552165325242,
#    29.53465670124564,
#    32.56112327256202,
#    49.34373666176212,
#    51.41778684073656,
#    52.871955593032666,
#    54.95300740444938,
#    56.99316017403788,
#    73.99101815058768,
#    75.5873035088699,
#    77.24973673220441,
#    80.22566059328545,
#    98.36201952373106,
#    99.1755094847244,
#    101.19021331639362,
#    103.44978661427692,
#    121.1350104218237,
#    122.17735823957095,
#    123.92555465913726,
#    126.47970793194918,
#    145.57636820696646,
#    148.20778298635636,
#    150.85846972088748,
#    153.41301365632978],
#   'Officer_Station_1_Early_2': [1.400669414937981,
#    2.613365712831186,
#    3.5311546034780408,
#    4.325988204292697,
#    5.079345989359101,
#    7.680178332121855,
#    8.206595097784334,
#    24.69946715559873,
#    26.138673032630393,
#    29.6081545533639,
#    32.2159951053262,
#    48.75201875577969,
#    50.66887785457276,
#    53.208193396484624,
#    55.294389086585504,
#    73.87700791196515,
#    76.0639909017991,
#    77.18644812711612,
#    80.22798028669567,
#    98.07636316552,
#    100.55273532078321,
#    102.18183864041605,
#    104.50136163315211,
#    121.29540977918793,
#    123.01102313948749,
#    127.29150876455468,
#    147.23634340262015,
#    149.79899347491997,
#    150.73992677389816],
#   'Officer_Station_1_Early_3': [1.1770079119651518,
#    3.0276773269031327,
#    5.061461476059029,
#    6.466487978047679,
#    8.38725900583981,
#    24.897997187128375,
#    26.907499863210827,
#    30.196111955881516,
#    33.427203600783955,
#    50.37478623311367,
#    53.05221419777245,
#    56.5230206930737,
#    73.25818866407457,
#    75.22280332570676,
#    76.30940457727131,
#    77.57482245908153,
#    79.99378470720025,
#    96.66578826029854,
#    97.46035021664804,
#    98.57059853648494,
#    100.07134080552704,
#    102.38942972673111,
#    103.14243035520077,
#    104.61723698654518,
#    122.55790478165811,
#    124.42082145118434,
#    127.32413088483496,
#    147.07463161384135,
#    149.89564922521024],
#   'Officer_Station_1_Early_4': [1.058912635470806,
#    3.205091775112673,
#    4.427047368145337,
#    6.336657848144921,
#    7.131491448959578,
#    9.066875518876142,
#    25.622046574912435,
#    27.730052731281866,
#    28.7073116253087,
#    30.108361739381387,
#    33.0971247188626,
#    50.2850104218237,
#    52.18610043475662,
#    54.17286444315521,
#    73.21228693326873,
#    74.62239854146942,
#    76.88999409897957,
#    78.66035871831055,
#    80.12827112950747,
#    96.77329878044655,
#    99.00308501016168,
#    100.80795032711336,
#    101.57755156298398,
#    102.22570932933279,
#    104.56783587132122,
#    122.47195559303266,
#    124.58434371174627,
#    126.90466515502118,
#    146.2221302599228,
#    147.88805766767635],
#   'Officer_Station_1_Early_5': [1.5072329267718751,
#    2.951728577199466,
#    3.772480459262141,
#    5.369339622586788,
#    7.8534736955546975,
#    10.162535364789823,
#    26.24635706081028,
#    31.173950325955104,
#    50.61068333406593,
#    54.478665436355165,
#    72.88777671103504,
#    74.70749986321083,
#    76.17754672190138,
#    77.9899799452359,
#    97.42593042198338,
#    99.09417308462008,
#    100.16963927454849,
#    101.83523264542653,
#    102.34939626896242,
#    103.71953602806516,
#    120.7040996375156,
#    123.5960747781645,
#    127.0141166283072,
#    146.6711742001836,
#    148.3883195652933],
#   'Officer_Station_1_Early_6': [1.4209524513937886,
#    3.430488391732477,
#    5.709744421174541,
#    7.348287731891172,
#    8.683198800665226,
#    24.946343708725692,
#    26.641508764554676,
#    29.621584430312385,
#    33.42883886510814,
#    51.68252259383441,
#    54.236100434756615,
#    74.23576099192347,
#    76.11276890388862,
#    78.26147715527742,
#    97.78591107496128,
#    100.23406884131008,
#    101.83657397055637,
#    102.78332569116978,
#    104.87166277859478,
#    122.44911116834126,
#    128.1307147024991,
#    146.8693935974582],
#   'Officer_Station_3_Early_0': [0.8641669619491911,
#    3.4355309533352933,
#    4.8278274817039595,
#    6.822657999168481,
#    7.598177580979235,
#    8.731373510347261,
#    26.624162261539144,
#    28.0244757043372,
#    30.857159048384236,
#    32.94134416952894,
#    50.15286167506404,
#    53.11669111655968,
#    56.17108997555481,
#    74.40822271287459,
#    76.3234504611235,
#    77.63496727736026,
#    80.47866792749858,
#    97.02554455769045,
#    98.89106450624075,
#    100.47366484647142,
#    101.97652652153546,
#    104.14230618701552,
#    120.59514121559714,
#    123.02660562603806,
#    125.1782408014206,
#    127.84295889573136,
#    146.99214333506072,
#    147.68966711307033,
#    150.37875954727645,
#    151.928886633674],
#   'Officer_Station_3_Early_1': [1.7503324095778694,
#    2.9638155298762268,
#    4.031888473638789,
#    4.780978359662171,
#    5.719987491178395,
#    6.831935558860615,
#    9.07855300018125,
#    24.710281291907613,
#    26.82715565212711,
#    29.340048798061698,
#    32.70004020673749,
#    50.03762745810811,
#    53.056101699693045,
#    57.188023842048835,
#    73.79904377872391,
#    74.66602366443561,
#    76.29419710046506,
#    77.87969514358421,
#    97.91393802418656,
#    99.87291197007634,
#    102.20526345739837,
#    104.74976623775298,
#    121.46386846548344,
#    122.28565389073941,
#    125.00876856762477,
#    128.6526605414782,
#    145.7784309405417,
#    148.52520047568208,
#    149.91601422872782,
#    152.98440531235673],
#   'Officer_Station_3_Early_2': [2.5857279340963863,
#    4.165807576121987,
#    5.094475503620567,
#    6.787737481714767,
#    8.068538582284132,
#    25.68251841010388,
#    27.74062802600757,
#    30.212141965881013,
#    32.25646198178731,
#    48.772940417102646,
#    51.55976180657413,
#    54.65876856762476,
#    57.21722295451024,
#    74.2044191709212,
#    75.78041488874759,
#    77.72375909191774,
#    96.72221885042913,
#    99.05252167546087,
#    101.08754034571383,
#    102.9212323083102,
#    104.57912168691587,
#    120.79542495725754,
#    122.30809213163839,
#    125.70959083060237,
#    127.21202453709267,
#    147.56016411589306,
#    152.38415733509353],
#   'Officer_Station_3_Early_3': [2.2335887409340094,
#    3.788444567500417,
#    4.677835534092917,
#    6.136604101717678,
#    8.36867327296464,
#    25.860197495068814,
#    26.6,
#    27.84809168339055,
#    30.680257075758195,
#    31.717302450899894,
#    50.16607144849998,
#    54.508153292944044,
#    74.44431214758724,
#    76.09392407441268,
#    78.78021060037769,
#    98.08486896725434,
#    100.2863796296853,
#    102.25034561901376,
#    104.49685581486062,
#    122.23217978303617,
#    124.27767196597671,
#    126.75533046108599,
#    147.09416490043662],
#   'Officer_Station_3_Early_4': [0.8415918824718713,
#    2.7944535575359133,
#    3.412577430419036,
#    4.158638082724623,
#    4.856844306352925,
#    7.4629602826867085,
#    8.249968610485844,
#    24.518717416747855,
#    28.11607172214924,
#    31.19173990429785,
#    50.06363208774613,
#    74.34410575103423,
#    76.14300660263667,
#    77.27820171562806,
#    97.85809213163839,
#    99.94903583442267,
#    102.05205249626093,
#    104.47281156712,
#    121.76428072841857,
#    123.03913040650308,
#    146.42111044777468,
#    148.26712843290886],
#   'Officer_Station_3_Early_5': [1.8345433872738264,
#    2.5755828247855135,
#    4.546901379722578,
#    6.021010701180716,
#    8.128500765186603,
#    24.31343044539087,
#    29.084586091369015,
#    51.77875850678947,
#    72.95399712044998,
#    74.19530767296418,
#    76.64132565809834,
#    78.10993166259246,
#    98.40822271287459,
#    99.15315386064972,
#    100.86036221949264,
#    102.67869072188054,
#    104.83859643427874,
#    121.92352974359426,
#    124.5582867396436,
#    146.60824918332256,
#    149.42105568878085],
#   'Officer_Station_3_Early_6': [2.0317941887927384,
#    4.397296210219704,
#    5.156290198874865,
#    6.058591046437792,
#    8.351434617098436,
#    24.61626228180538,
#    73.84612419221256,
#    75.20741241517304,
#    76.78718969211097,
#    78.89226324470697,
#    96.94621859036755,
#    97.52125471958533,
#    99.69042746186182,
#    101.05586043633393,
#    103.07435371945937,
#    104.41823460360638,
#    123.50382443458389,
#    148.5078605094694],
#   'Officer_Station_3_Early_7': [2.368811470448298,
#    4.685340762302959,
#    6.8519351580185415,
#    9.284273645391979,
#    26.254142869101443,
#    74.15162765388804,
#    75.03229992667018,
#    76.3341018548264,
#    98.1441385734329,
#    98.85034617903734,
#    100.46628459593465,
#    103.10198026602198,
#    104.43608711609535,
#    122.440442163462,
#    146.61352846927372],
#   'Officer_Station_3_Day_0': [8.792548103936198,
#    9.769585057985267,
#    12.559761806574128,
#    14.748834499524838,
#    15.555597222575031,
#    33.91322715686491,
#    35.41026413751577,
#    36.67330438722651,
#    37.970465308613534,
#    39.293889048783086,
#    40.678279357419974,
#    58.4931941714479,
#    60.22048300898224,
#    62.29654667449982,
#    64.09544635822289,
#    82.59126974841244,
#    84.13245237729123,
#    86.74965430155117,
#    88.80954893634244,
#    105.87603663548411,
#    107.75810812556166,
#    108.79722344829915,
#    109.66443166121644,
#    111.02183911052138,
#    128.79689442914747,
#    130.7338456803069,
#    133.3150582460697,
#    136.31564858219753,
#    153.33289212815544,
#    155.93253247121902,
#    158.1131814685742,
#    158.8111411350493,
#    161.45117143571457],
#   'Officer_Station_3_Day_1': [9.496907093597864,
#    11.877422080389207,
#    13.735282589858617,
#    14.862657303898775,
#    16.836559880328622,
#    33.48983539164397,
#    35.01415409157706,
#    36.57609358046785,
#    38.950582270298305,
#    40.94176166807327,
#    58.396698575282066,
#    61.09241516097251,
#    64.54529829287283,
#    81.54906113062073,
#    82.76785574851141,
#    84.98663031487105,
#    86.26967393174712,
#    88.8718576501299,
#    105.31213077878068,
#    108.40436276523194,
#    110.76399076959,
#    113.2221730145707,
#    129.7329956988201,
#    131.89425204124677,
#    132.93842450026546,
#    134.99589725116962,
#    137.44372060064967,
#    152.9251265136694,
#    155.5004330414098,
#    158.45230084756292,
#    159.56678615478384,
#    161.50751129287426],
#   'Officer_Station_3_Day_2': [9.711104350717134,
#    12.22539932491383,
#    13.184897940733878,
#    13.821745005434678,
#    16.352075560320053,
#    34.369737249330534,
#    35.59309961042515,
#    37.52202072028073,
#    40.316071448499976,
#    57.00933905844369,
#    59.86339419297177,
#    62.40412436344312,
#    64.85842295633121,
#    82.16365920381827,
#    83.66967393174711,
#    86.61096626291486,
#    88.80191186792014,
#    107.36079583412628,
#    109.6726034903048,
#    110.83141107822382,
#    113.07330438722651,
#    129.16840372610503,
#    131.0248927163463,
#    134.4777150658123,
#    137.23523562101605,
#    153.41818793172797,
#    155.62069234214655,
#    156.63289212815545,
#    157.96564858219753,
#    160.02386572748247],
#   'Officer_Station_3_Day_3': [9.243644797352964,
#    10.417506315724985,
#    11.931250954930587,
#    13.152690541501713,
#    14.771644602250253,
#    16.746020155082928,
#    33.01045019469072,
#    35.77336236109461,
#    38.17439786267776,
#    40.651314314916696,
#    57.468412505283446,
#    60.04428762221504,
#    60.742493845843335,
#    63.40230084756293,
#    82.16896141635718,
#    85.48191674441176,
#    88.45014741389377,
#    105.72188281162111,
#    106.814993936457,
#    108.70230084756292,
#    110.49032535292822,
#    112.4701354184243,
#    131.01428072841856,
#    134.52553851048523,
#    137.4051118764962,
#    152.7205158153519,
#    154.54619620214348,
#    157.30451607241116,
#    160.53302274745838],
#   'Officer_Station_3_Day_4': [8.788644048254309,
#    10.723192815270144,
#    13.364899729111952,
#    14.785946945258448,
#    32.91479399203058,
#    34.405655969641494,
#    35.146098133103486,
#    36.6909416924069,
#    39.100572185096574,
#    39.93627167019361,
#    41.728754481274045,
#    58.33605873970795,
#    60.52036207335989,
#    62.45205316450182,
#    64.00989507910553,
#    81.9407251380904,
#    83.18711266919485,
#    85.68688088105728,
#    87.68478067746489,
#    106.70487390275592,
#    108.31782669627837,
#    110.44219731537852,
#    112.79072513809041,
#    130.36841859775652,
#    133.53983066908128,
#    134.99853434706418,
#    135.62394047758698,
#    136.52624132514993,
#    152.9405476818088,
#    154.7388974314099,
#    156.34374765715785,
#    158.5851399487147,
#    160.85052117648743],
#   'Officer_Station_3_Day_5': [9.568123872883122,
#    11.444168967141225,
#    13.825371984999407,
#    16.320778817040882,
#    34.42788755708148,
#    35.651174989596164,
#    37.75786050946941,
#    40.23467890091738,
#    58.045492182940535,
#    60.689468766776315,
#    62.21924865961811,
#    65.49557790256199,
#    81.5179182954189,
#    83.27414024456432,
#    85.6983042143356,
#    88.3897195547599,
#    106.57232616531702,
#    109.15726040337881,
#    111.92091767032076,
#    130.68121865704515,
#    132.03289212815542,
#    134.26300825786464,
#    135.8167238632726,
#    152.67354018383347,
#    154.41296028268673,
#    156.87138222394412,
#    157.76798532867207,
#    160.25030959913894],
#   'Officer_Station_3_Day_6': [9.927422080389208,
#    12.365632113021459,
#    13.373492622490868,
#    14.283212566332216,
#    33.895020715704696,
#    35.85988264868025,
#    38.64722344829916,
#    39.96370839112993,
#    41.27024265681417,
#    59.455456906547056,
#    60.88129407708087,
#    62.540790119966644,
#    64.94351526959541,
#    82.32142383692712,
#    84.6483042143356,
#    86.90988264868024,
#    88.75743386417844,
#    105.71027248572713,
#    108.37411077536647,
#    112.63502368791116,
#    130.06937335030997,
#    131.92172211324186,
#    134.35441917092118,
#    136.2334243520918,
#    154.45834840038393,
#    155.93872822489627,
#    157.61808854352515,
#    159.62271684640413,
#    161.29268296509815],
#   'Officer_Station_3_Day_7': [9.708968767725521,
#    12.288318523270554,
#    14.088020986591413,
#    34.62554455769044,
#    36.77414024456432,
#    37.90800902799253,
#    39.22166919853232,
#    40.30456132668775,
#    58.43425895885285,
#    60.91457501837751,
#    61.76652145864908,
#    63.24886223308306,
#    83.40160276419596,
#    86.51675215683717,
#    89.1544191709212,
#    106.46373497056366,
#    108.76208742619404,
#    111.18260610309426,
#    130.9869959266537,
#    132.58717648865948,
#    135.59903205992163,
#    137.22320111548316,
#    155.23289212815544,
#    157.16483882460165,
#    159.5512965507052,
#    160.5057157216264],
#   'Officer_Station_3_Day_8': [9.40786050946941,
#    11.03746661774284,
#    12.541850126610358,
#    15.277103199700743,
#    34.51673300236457,
#    36.79789807430075,
#    39.55786050946941,
#    40.57008864563616,
#    58.33572793409638,
#    59.62017912647694,
#    61.340725138090406,
#    63.11457011373043,
#    82.88342029052518,
#    83.88680346028022,
#    86.66822308741335,
#    88.18789454955933,
#    106.30286167506404,
#    109.31242036682899,
#    111.25342827267579,
#    130.40450283934788,
#    131.77744751491556,
#    133.33552680372392,
#    136.2657119923706,
#    155.24964344335973,
#    158.15575188370548,
#    159.90255746978704,
#    161.75017013181332],
#   'Officer_Station_3_Day_9': [9.945518973383388,
#    12.022053700424848,
#    14.39629456145637,
#    35.036076663843,
#    35.720162544750636,
#    37.671154106614615,
#    40.23356421659131,
#    58.14549218294053,
#    61.57626090418628,
#    64.36601744990405,
#    84.17780146551496,
#    86.05441917092121,
#    89.4957012348896,
#    108.00848744778177,
#    110.71238439856451,
#    113.07002182135281,
#    131.10436276523194,
#    133.77332424032411,
#    134.96374147729514,
#    135.98626691405775,
#    153.86789669855239,
#    155.68116410933612,
#    157.3313011459475,
#    159.84102154322053,
#    161.92669536060035],
#   'Officer_Station_3_Day_10': [11.229322622988402,
#    11.823784658134654,
#    13.715853890691257,
#    14.658606739171116,
#    35.01313548937863,
#    36.121646068286836,
#    39.374240861031524,
#    40.696021916431945,
#    58.52207466687372,
#    60.12985999676867,
#    62.582160844331604,
#    64.38821779295347,
#    83.7476532265834,
#    85.12821504616339,
#    88.52484907839055,
#    106.96237850957763,
#    109.73738404568495,
#    111.86925601357298,
#    130.9913356233866,
#    132.08100876861783,
#    133.76155389633325,
#    136.47023288106746,
#    155.11102027646945,
#    158.3788891523241,
#    160.63698128396248],
#   'Officer_Station_3_Day_11': [9.502861675064041,
#    11.108108125561658,
#    11.94357255926143,
#    13.50786050946941,
#    15.236327232102019,
#    35.2808651677579,
#    36.960814434361545,
#    38.932051787058576,
#    41.61625536989719,
#    58.36849328312544,
#    60.86267123297897,
#    63.58521619193017,
#    84.4637921490868,
#    85.69182073514179,
#    87.46375579142217,
#    107.41614596311997,
#    108.73913040650308,
#    112.03068961232951,
#    129.80172432741892,
#    132.19734933161752,
#    135.0097125176981,
#    137.54485503996855,
#    155.2312586685089,
#    157.59438974869,
#    159.3303028250317,
#    161.0881633345011],
#   'Officer_Station_3_Day_12': [9.982892128155429,
#    10.714609985040873,
#    13.767395421872928,
#    15.864889841707651,
#    34.07553851048524,
#    35.59366238336836,
#    37.691222227098706,
#    40.169683636628754,
#    58.17630755736235,
#    60.26333377713633,
#    62.61929869778759,
#    64.94928992265778,
#    83.82760948380387,
#    85.4044191709212,
#    87.94570123488958,
#    108.20516191309878,
#    111.18355146805145,
#    132.0311650719362,
#    134.31659510130953,
#    136.82237023653505,
#    155.04167843283054,
#    157.14681415915632,
#    158.99177453468766,
#    160.83388272489904],
#   'Officer_Station_3_Day_13': [11.230302825031734,
#    13.73165184768389,
#    14.866105251876343,
#    34.575772151022974,
#    35.66203906508072,
#    38.22095359104966,
#    40.09787485992201,
#    58.69613024192034,
#    60.82591190159585,
#    61.954526365700644,
#    62.83482404348984,
#    65.66736323363062,
#    84.31557283914502,
#    86.35162780334343,
#    88.77528032314183,
#    107.76102027646944,
#    108.99659218520142,
#    110.58952175830876,
#    112.87869169155827,
#    130.73617096099082,
#    133.406187498978,
#    135.56642302872933,
#    136.7611191368242,
#    157.549171081944,
#    159.73289212815544,
#    160.33324934903413],
#   'Officer_Station_3_Day_14': [11.63365085176186,
#    13.988981312847855,
#    35.25286167506404,
#    37.766002834659254,
#    40.59284357066065,
#    58.55079626576181,
#    59.742415160972506,
#    60.83260877171629,
#    62.87903354993353,
#    64.05032832527587,
#    84.13318490024761,
#    86.19261387029925,
#    87.92374471426487,
#    108.4222009969004,
#    112.54441887555222,
#    130.90856921684093,
#    132.61487565404485,
#    134.91967393174713,
#    137.18626691405774,
#    157.4217248060997,
#    158.6709658151673,
#    160.61110435071714],
#   'Officer_Station_3_Day_15': [9.569864588752463,
#    10.843924074412678,
#    11.680246601645152,
#    13.34034623404159,
#    15.514558873698768,
#    35.4233055021642,
#    38.129254261484064,
#    40.02404721758193,
#    59.40810812556166,
#    61.43065396155222,
#    63.91538122777275,
#    82.71999119380243,
#    84.53872822697922,
#    87.26545797629252,
#    108.39837567470933,
#    112.64917186003915,
#    131.0684687074177,
#    133.01483882460164,
#    135.8065561444179,
#    137.1103805790018,
#    157.5812586685089,
#    159.25956730337947,
#    161.81048294519738],
#   'Officer_Station_3_Day_16': [9.765034749971537,
#    12.021895742375445,
#    14.07914165351619,
#    35.140512779165256,
#    36.00670409911056,
#    39.42866751953542,
#    41.651974626889505,
#    58.85971994384135,
#    60.113333777136326,
#    61.06785834055352,
#    62.97968832458684,
#    82.77416905556153,
#    84.23714098249114,
#    86.90675483191154,
#    87.90230084756293,
#    109.68406985723213,
#    112.3602116445704,
#    132.58817124101398,
#    135.20051036025205,
#    136.00634969093912,
#    156.4278858402584,
#    158.75390095439093,
#    160.88141107822383],
#   'Officer_Station_3_Day_17': [10.457047867014014,
#    12.543875069536975,
#    13.154087127954714,
#    14.270707083126533,
#    35.40876856762476,
#    37.6778517179136,
#    40.6252004756821,
#    60.38939181630803,
#    63.576171555211225,
#    83.45608640450092,
#    85.63144067615977,
#    88.4514824958293,
#    109.43164499461423,
#    111.96021164457039,
#    132.4626446401973,
#    135.6594143518419,
#    136.3408254300657,
#    156.95698786538736,
#    158.34674682391756,
#    160.97636036471545],
#   'Officer_Station_3_Day_18': [10.170422138048322,
#    10.976720993521777,
#    13.05,
#    14.456106380234328,
#    36.364739503182825,
#    39.08237316384154,
#    41.48799536022683,
#    59.234796908468255,
#    60.34330663688068,
#    63.601070052761735,
#    84.2009336182513,
#    88.04621859036756,
#    109.03431539821423,
#    112.61221863481572,
#    132.4858816760667,
#    134.36058733759393,
#    136.98179418879275,
#    158.3837630433812,
#    159.75513442954033,
#    160.8123265063652],
#   'Officer_Station_3_Day_19': [10.806029940524454,
#    11.782892128155428,
#    13.832447316630699,
#    34.673035919278206,
#    36.95988264868024,
#    37.562435101959885,
#    39.3279703159805,
#    41.78027116354343,
#    59.60653426568424,
#    61.25676004349486,
#    63.022475640591324,
#    85.0137921490868,
#    88.08971955475991,
#    110.48569514104308,
#    112.19214333506072,
#    133.3125954157951,
#    135.4424038506858,
#    137.54071299445928,
#    158.13960795869784,
#    160.03887977007926],
#   'Officer_Station_3_Day_20': [11.196554558146833,
#    12.729235958262537,
#    14.030934524556855,
#    34.841859625106075,
#    35.858314411036424,
#    38.826816799833246,
#    40.73175588471644,
#    59.56164127757491,
#    61.38924855236777,
#    63.20358237103398,
#    85.10893516112496,
#    89.59751472856088,
#    108.92850630438339,
#    112.42457833730869,
#    132.67158950223683,
#    135.08323295003117,
#    136.7122191625666,
#    157.64459026941338,
#    158.81291022899535,
#    160.47600505410836],
#   'Officer_Station_3_Day_21': [9.617727427327544,
#    12.165519948550298,
#    13.419703443815502,
#    15.153549124122408,
#    34.779977950808345,
#    37.31166181265138,
#    39.0792657929227,
#    40.72242622500681,
#    60.03983066908127,
#    62.30515313722575,
#    85.5706167456652,
#    87.9718576501299,
#    111.81437099757778,
#    132.69241161914107,
#    134.9814174677937,
#    136.8800612609078,
#    158.64903205992164,
#    161.26818793172797],
#   'Officer_Station_3_Day_22': [11.17300034603511,
#    12.892737595365643,
#    14.651506162990403,
#    36.270084407445594,
#    38.18125866850889,
#    39.73936679407055,
#    41.23167624885943,
#    59.067395421872924,
#    61.35412213413703,
#    85.9052699394421,
#    88.41681623215297,
#    132.65810812556165,
#    135.5465407130904,
#    136.52715801517948,
#    159.20982383903345,
#    161.19847397815903],
#   'Officer_Station_3_Day_23': [9.712673691779935,
#    10.878642910317327,
#    11.933845680306906,
#    13.811924358060281,
#    36.270084407445594,
#    38.54080061254026,
#    40.01738115997336,
#    60.781900914210006,
#    61.724372109538685,
#    86.1854871095161,
#    89.30876856762477,
#    132.69072513809041,
#    134.5998658954512,
#    135.98232587698712,
#    159.6578605094694,
#    161.6152440918753],
#   'Officer_Station_3_Day_24': [10.060227288050077,
#    11.77039140394315,
#    13.467946790436994,
#    14.22744540625704,
#    34.75950394500659,
#    37.374731795648636,
#    39.81661772701447,
#    41.439935490233765,
#    59.42539646459256,
#    60.15386318722517,
#    63.36913434376035,
#    133.90317660831738,
#    135.80218408105384,
#    137.95758701069414,
#    157.7078605094694,
#    160.271847119276],
#   'Officer_Station_2_Night_0': [17.01039003324964,
#    18.704930629685705,
#    21.11075920189056,
#    23.35567879884933,
#    24.96156968123831,
#    42.52199609624652,
#    45.3826972532641,
#    47.55337749723619,
#    66.2090880049425,
#    68.55265162593123,
#    71.08962214758327,
#    88.78134412569257,
#    91.2202931771946,
#    93.35867660341482,
#    95.25996213485246,
#    113.14643833013068,
#    116.2437572825177,
#    118.7475274673661,
#    121.17394413864633,
#    138.40347103706367,
#    139.88237843129625,
#    141.6654226656942,
#    143.11542266569418,
#    161.11287524096534,
#    163.9685029730844,
#    164.86413819294688,
#    166.4,
#    168.90946814650405],
#   'Officer_Station_2_Night_1': [17.028367127220683,
#    20.502725260355817,
#    22.86023364114532,
#    25.163654564281128,
#    41.36268925957629,
#    44.40970931597556,
#    46.707009286829816,
#    49.25962021624874,
#    64.73578916640884,
#    66.23421285594627,
#    67.66239971858488,
#    69.88330849947795,
#    72.0566059276012,
#    90.52291867327548,
#    92.04640993993681,
#    94.4984632037834,
#    96.80970931597557,
#    114.22964577812549,
#    116.54714321241686,
#    118.79762460336889,
#    121.73331329991937,
#    137.641780538605,
#    139.6483337949853,
#    142.59236615222105,
#    144.94274360936936,
#    161.6315092244591,
#    163.03369583679367,
#    165.51576353868995,
#    168.47791217427144],
#   'Officer_Station_2_Night_2': [17.65834782796171,
#    18.654930629685705,
#    20.115407350683768,
#    23.160544798124914,
#    25.69246741417875,
#    42.184260575054346,
#    44.212689259576294,
#    45.89683539950933,
#    47.05355439050106,
#    64.75758380882185,
#    66.63246448839057,
#    68.5034644324083,
#    70.7367655923768,
#    72.24578984392303,
#    90.37868659880594,
#    91.6253890776234,
#    93.43521358403248,
#    94.62362401745219,
#    96.24817112948679,
#    113.80878709254605,
#    115.05648869153286,
#    117.21107007928924,
#    119.91815794076427,
#    137.7592337697819,
#    140.4154226656942,
#    142.1696092367191,
#    144.73650500931276,
#    161.21391735419763,
#    164.01062085627083,
#    165.9654226656942,
#    167.00470397939264],
#   'Officer_Station_2_Night_3': [19.37950997349142,
#    20.84442811309068,
#    22.288270142052262,
#    23.08510554156159,
#    24.903367600634503,
#    41.71258519512974,
#    43.57027892326444,
#    45.38378958854398,
#    48.243550130513626,
#    65.60280594929462,
#    68.03763416704751,
#    71.54312114768689,
#    89.942241805128,
#    91.50732636315013,
#    93.1796161798043,
#    95.62815492849981,
#    113.2459258543724,
#    115.51564986324362,
#    116.8400370516563,
#    118.77493024523451,
#    120.41355873132103,
#    137.28115745203547,
#    139.32000367049415,
#    142.4654226656942,
#    143.67022761456752,
#    160.8690224468052,
#    162.5252674668223,
#    163.99783766175716,
#    166.35256638434763,
#    169.55642994330262],
#   'Officer_Station_2_Night_4': [17.692753501145663,
#    19.324461601956685,
#    20.972695311002752,
#    22.23827014205226,
#    23.244111876394975,
#    24.952721901171792,
#    40.757884190722066,
#    42.97388070952217,
#    44.003491994590576,
#    45.85,
#    48.58239040067988,
#    65.7617555515706,
#    66.86888511436185,
#    68.55452865471909,
#    70.45758380882185,
#    72.25436647680078,
#    89.64643833013068,
#    92.19510475864756,
#    94.70355439050105,
#    96.18998428845457,
#    113.96892545874027,
#    115.03132098373007,
#    117.86663135629249,
#    120.76593513268206,
#    137.2308190421009,
#    139.1100144550026,
#    141.0416675245731,
#    144.2719960962465,
#    161.42961024281706,
#    164.36554777951196,
#    166.85686777302087,
#    169.0159053676617],
#   'Officer_Station_2_Night_5': [18.788464110249997,
#    21.853073050945444,
#    22.611099355430706,
#    24.11698062252424,
#    41.59822846829573,
#    44.752397558141965,
#    46.73089992651504,
#    49.472851250484474,
#    65.6066059276012,
#    68.28115745203549,
#    70.37878199186085,
#    91.06377918939259,
#    94.19779411030282,
#    97.14072953683717,
#    113.42525865412516,
#    115.36944434051854,
#    116.78057087970633,
#    117.89198276922728,
#    119.11380346316416,
#    136.95207031925747,
#    138.8443458700471,
#    140.7626892595763,
#    142.2922276306431,
#    162.30259008955025,
#    165.09017869395146,
#    167.56330690171816],
#   'Officer_Station_2_Night_6': [19.224509758156053,
#    21.562534516974367,
#    23.829870706471024,
#    25.549836935317764,
#    42.71433343442341,
#    45.261072026442136,
#    47.665341991354616,
#    66.46781769125997,
#    69.13736135318918,
#    72.3073328602014,
#    89.72609586422242,
#    90.90517682622074,
#    93.15699481958285,
#    96.13484368767091,
#    115.14631934960663,
#    117.94404915862596,
#    120.4830245497807,
#    138.57269531100275,
#    141.09224180512803,
#    142.69550860126745,
#    162.17845821772093,
#    163.7583207258299,
#    165.1396435941148,
#    167.37026229754454],
#   'Officer_Station_2_Night_7': [19.085629865989826,
#    21.07350519523917,
#    23.012909510434714,
#    25.46449396929651,
#    41.74260439546489,
#    43.95909799774064,
#    46.31239971858488,
#    49.12195474019357,
#    67.35,
#    69.55355439050106,
#    70.96493924386827,
#    89.70524325938592,
#    91.50436647680078,
#    94.1534209231358,
#    96.06662406219426,
#    115.07540042509301,
#    118.15736002866902,
#    120.95206031637817,
#    136.87897819110336,
#    137.9427426491087,
#    138.8406318768926,
#    140.81195773739802,
#    142.45027767474673,
#    162.25935886110065,
#    164.29179867074393,
#    167.4930900992523],
#   'Officer_Station_2_Night_8': [20.127382241539728,
#    21.86843651490696,
#    24.3075698186324,
#    42.30037721674201,
#    44.39224180512801,
#    46.777024592914856,
#    67.19727934172172,
#    70.20517036318455,
#    90.58450801347371,
#    92.30516286446299,
#    95.0815092244591,
#    113.99640993993681,
#    115.4801129022798,
#    117.91895389429726,
#    120.18215190786985,
#    137.52858917508516,
#    139.25706863528725,
#    140.58436164615424,
#    142.0154226656942,
#    162.41662406219427,
#    164.21054479812491,
#    165.87000367049416,
#    167.9505691251312],
#   'Officer_Station_2_Night_9': [22.354982877301403,
#    23.245070740922603,
#    24.371537699049902,
#    42.898333794985305,
#    44.12705794513015,
#    47.03861426892643,
#    66.68358188107038,
#    69.31943924172718,
#    70.6757819084792,
#    90.30355439050106,
#    92.71662406219427,
#    94.0033596944366,
#    95.94779411030282,
#    114.1545286547191,
#    115.6681362592962,
#    118.0951532159958,
#    120.30260743150443,
#    136.82814738503643,
#    137.76704373662827,
#    140.0,
#    143.32947030446456,
#    160.67782798198058,
#    162.92910509007373,
#    165.5477017372074,
#    167.10266129362603],
#   'Officer_Station_2_Night_10': [22.00615742588894,
#    23.816986612090776,
#    26.39688852929026,
#    42.82748105801243,
#    45.202221306338096,
#    66.63646400262374,
#    68.6283823181804,
#    70.02878199186085,
#    92.4483674245455,
#    95.42753300507599,
#    115.48158118322523,
#    119.5410115465027,
#    139.25962021624872,
#    141.76709214190288,
#    142.83480004164136,
#    161.92000367049414,
#    163.56280917462792,
#    166.36542266569418,
#    168.49215061227176],
#   'Officer_Station_3_Night_0': [18.097248423338023,
#    21.325724693715657,
#    23.365770967414505,
#    25.183311617630352,
#    41.399186121129205,
#    43.067078441376175,
#    45.13986681203257,
#    47.08166776049421,
#    65.29906113062073,
#    67.26052741207982,
#    70.33838330964485,
#    72.46692803214636,
#    89.19588638271378,
#    90.63342029052518,
#    91.88295640946339,
#    92.81487565404485,
#    93.94374765715783,
#    96.13429919993736,
#    114.4907251380904,
#    117.54787216757646,
#    118.94249330818934,
#    120.42636484573039,
#    137.87853082412335,
#    139.27054603687918,
#    142.0765821004176,
#    144.47510543250368,
#    162.43613799678425,
#    164.47704485730628,
#    167.44755057514175],
#   'Officer_Station_3_Night_1': [18.24214333506072,
#    20.710492819676773,
#    22.021353138244745,
#    23.875792283667696,
#    25.161301646094643,
#    41.171154106614615,
#    42.97871876974083,
#    45.45851459681154,
#    46.726542587770076,
#    49.07069697473072,
#    65.92920556263135,
#    67.31021205841773,
#    69.76309577906505,
#    71.75033517084164,
#    90.2407251380904,
#    93.35842295633121,
#    95.96921237902367,
#    112.93371593607945,
#    114.74350136617694,
#    117.61485685029228,
#    118.88880105013564,
#    120.26957737580965,
#    137.28882488158587,
#    140.35980753441422,
#    143.5090801891435,
#    160.64558419792147,
#    163.12483484681985,
#    166.1220563645551,
#    168.46972622917235],
#   'Officer_Station_3_Night_2': [18.52035412600825,
#    22.522706326251505,
#    24.480955509574052,
#    41.60017464795955,
#    44.12476826503387,
#    47.44221635049476,
#    65.20032832527586,
#    67.7482033759658,
#    69.13729781756552,
#    72.36292930789901,
#    89.04904377872391,
#    91.75446124910931,
#    94.56092271691676,
#    96.2516136148374,
#    114.6907251380904,
#    116.77097161234205,
#    117.87657538810728,
#    119.20812743601405,
#    138.50208609124417,
#    141.38116507193618,
#    142.75487753074518,
#    144.6078605094694,
#    162.07010524965554,
#    163.8967007690675,
#    164.87504382102804,
#    166.29308371752455,
#    168.50851459681155],
#   'Officer_Station_3_Night_3': [18.347945947053272,
#    21.94292894195017,
#    23.30866077890228,
#    25.645235577236086,
#    42.04316043208411,
#    43.860306071492836,
#    44.72143958657113,
#    45.654419170921194,
#    47.51841318745141,
#    65.30441917092121,
#    68.34029105859358,
#    69.5777327363375,
#    71.73086516775791,
#    89.03954599359777,
#    92.33521619193017,
#    94.34388088414701,
#    96.13124775996981,
#    115.38549804311916,
#    117.09419710046507,
#    118.86740490782917,
#    120.97424086103152,
#    138.01753912829295,
#    139.73880105013563,
#    141.21571679483895,
#    143.50230084756294,
#    160.89397658383578,
#    162.705330461086,
#    165.21981981708342,
#    166.8854181727042,
#    169.4599706790179],
#   'Officer_Station_3_Night_4': [18.960922716916766,
#    20.768565947671274,
#    22.65019693398259,
#    24.39787818576175,
#    41.28207891918832,
#    43.70253053247919,
#    45.15512329943088,
#    46.8808651677579,
#    48.30436276523194,
#    66.23086516775791,
#    69.16318086218138,
#    72.37342612113203,
#    91.08055892682495,
#    92.6958610384647,
#    95.443880884147,
#    113.80261589552681,
#    115.03573774753978,
#    117.11365920381826,
#    119.93729781756552,
#    139.20079626576182,
#    142.08541041682864,
#    144.4907251380904,
#    161.88297736974485,
#    164.13806875238464,
#    165.96345328082427,
#    167.44022714495586],
#   'Officer_Station_3_Night_5': [21.222998118421014,
#    22.24161709197297,
#    24.67240264223745,
#    41.240725138090404,
#    43.62138222394413,
#    45.20745773104752,
#    47.151483802677255,
#    66.48108267979084,
#    69.06630332981601,
#    70.75533229052405,
#    73.4854393124562,
#    90.42424086103152,
#    92.99825378748064,
#    94.20573675116461,
#    96.40311805678719,
#    113.9123377836227,
#    116.27104598525769,
#    118.15034973500919,
#    120.27654258777008,
#    138.45004020673747,
#    141.03642550214036,
#    143.29700995184365,
#    161.0986307659224,
#    163.52111150320218,
#    164.62693631216294,
#    166.5474713466394,
#    169.47081226147338],
#   'Officer_Station_3_Night_6': [21.33537015846124,
#    23.523061042178114,
#    25.04060169239396,
#    42.19571955522238,
#    44.25230084756293,
#    45.63528915039299,
#    47.45436276523194,
#    65.41438963123498,
#    68.82390727347503,
#    69.74022714495585,
#    72.05506508352552,
#    90.79199442302962,
#    91.80286167506404,
#    94.13865409542161,
#    96.95286167506404,
#    114.75571165123702,
#    115.74452270295663,
#    116.65810812556165,
#    118.02840714985246,
#    121.2566417129737,
#    138.6878306703837,
#    141.63946221519882,
#    142.80763978623582,
#    144.14718690277158,
#    162.5674562595063,
#    164.57704485730628,
#    166.09217948435438,
#    169.3324376601832],
#   'Officer_Station_3_Night_7': [20.842786278934508,
#    21.974333596167295,
#    23.894960855053323,
#    24.826755043846063,
#    42.19079196027078,
#    44.93049619740024,
#    46.79416490043663,
#    48.6329564094634,
#    66.20233770392582,
#    68.85858983487088,
#    71.42539646459255,
#    90.99975920049202,
#    92.73738404568495,
#    95.43443873575853,
#    114.43019377090407,
#    115.73246936391686,
#    118.2623365885475,
#    119.97111671483808,
#    138.91868159382406,
#    140.10159622502553,
#    142.0918008411609,
#    145.27844733958926,
#    160.6837654306125,
#    161.6511457008594,
#    163.84267132259578,
#    164.64162610223627,
#    165.88364616126023,
#    167.72539646459256],
#   'Officer_Station_3_Night_8': [22.525086973035254,
#    24.96324642276345,
#    42.69291854003046,
#    45.38060061751309,
#    47.69660377964375,
#    67.50452636570064,
#    70.48307422909717,
#    72.90692884309041,
#    90.4252004756821,
#    92.3031277851464,
#    94.31129425686663,
#    97.10810812556166,
#    114.03686632351949,
#    116.20169856629431,
#    118.96986458875247,
#    121.58686911700791,
#    138.22448296358266,
#    139.770523066799,
#    141.06783226289923,
#    142.95763978623583,
#    145.1757140876849,
#    162.12221584249136,
#    164.93081303366682,
#    167.55175845279058],
#   'Officer_Station_3_Night_9': [20.990038935946043,
#    22.24739618505766,
#    24.10548831669605,
#    42.178878403270915,
#    44.92270567798079,
#    46.399808169367354,
#    47.60230084756293,
#    67.18173912150667,
#    69.52192223960179,
#    71.16550202142696,
#    91.45824918332254,
#    93.51744339340563,
#    95.3074577310475,
#    115.08649894061462,
#    118.4544191709212,
#    119.75230084756294,
#    138.38067227278216,
#    141.53617757584203,
#    143.2576397862358,
#    161.9598254747587,
#    164.1912222270987,
#    167.76966201956154],
#   'Officer_Station_3_Night_10': [22.71790862951817,
#    25.254591619362227,
#    42.521110447774674,
#    45.52424086103152,
#    67.09881768788657,
#    68.8138181466096,
#    69.84394276412397,
#    71.87796984803983,
#    89.67663518617833,
#    91.81251763932919,
#    92.67410945741246,
#    95.49493114777513,
#    115.42023288106746,
#    117.73055892682495,
#    119.47673846927566,
#    139.06665386211284,
#    142.4765882174725,
#    163.65321209032197,
#    165.74162610223627,
#    167.30286167506407],
#   'Officer_Station_3_Night_11': [22.354362765231944,
#    23.749072949235458,
#    24.53951511269745,
#    42.29903205992164,
#    43.63921945880311,
#    46.243551889404536,
#    66.06959336071462,
#    70.68894155863796,
#    71.90286167506405,
#    90.07424086103153,
#    93.14736712144158,
#    96.01645640091466,
#    114.54151348465061,
#    115.90163934217188,
#    117.74421006895834,
#    120.27181543042919,
#    138.84374115542414,
#    140.80824918332254,
#    142.70311350015513,
#    162.5315089048461,
#    164.32704485730628,
#    168.05286167506407],
#   'Officer_Station_3_Night_12': [22.45197972131287,
#    24.950993381165468,
#    43.51812387288312,
#    46.42102145114326,
#    66.0155488366529,
#    68.75914058907233,
#    70.75824918332255,
#    90.22335436146533,
#    91.77207466687373,
#    95.0950207946659,
#    116.5912222270987,
#    118.93432161822123,
#    121.3233055021642,
#    139.01422411298097,
#    142.10794211319924,
#    162.33862875360865,
#    165.1770448573063,
#    168.67376101965547],
#   'Officer_Station_3_Night_13': [22.807383582405905,
#    24.297610727361757,
#    41.88454338727383,
#    43.88755747242489,
#    46.605618074549305,
#    66.06201271865628,
#    69.564112722025,
#    90.68826091401947,
#    91.71973724933054,
#    95.58314785936493,
#    115.68424143473177,
#    119.00230084756294,
#    139.25286167506405,
#    142.0493380349526,
#    163.3407251380904,
#    164.81363734931398,
#    168.68182593198296],
#   'Officer_Station_3_Night_14': [22.685904363481605,
#    24.78007333062283,
#    42.17207466687372,
#    45.47663518617833,
#    66.5805809946441,
#    71.34906113062074,
#    90.85795588452817,
#    92.77632441014461,
#    94.90038884497262,
#    96.4245063080065,
#    116.37275407395414,
#    117.61733367781828,
#    120.05436276523194,
#    140.5952016532584,
#    142.64986506513324,
#    163.33738404568493,
#    165.07182865966425,
#    167.84350136617692],
#   'Officer_Station_3_Night_15': [21.719149855615107,
#    23.30337352293199,
#    24.750858743788474,
#    43.56857541318165,
#    46.38439030863689,
#    65.58986681203257,
#    70.88030282503173,
#    91.97325226211629,
#    95.48923967490283,
#    115.95835560396668,
#    119.11733367781828,
#    140.19426948677818,
#    141.8136407523556,
#    143.46144936430213,
#    162.4120245370927,
#    163.75441917092118,
#    166.40890331566314,
#    167.67554172749064],
#   'Officer_Station_3_Night_16': [23.5376576617951,
#    24.61421235117403,
#    43.37986385577139,
#    45.187297817565536,
#    65.71115761538347,
#    71.04560403536784,
#    90.78452249430933,
#    92.40148089339098,
#    95.06382253625499,
#    115.49514121559714,
#    119.16962524223786,
#    139.26571679483897,
#    142.3050881650845,
#    162.84720670749903,
#    165.56972622917235,
#    168.60810812556167],
#   'Officer_Station_3_Night_17': [23.117012166777158,
#    23.882532115327457,
#    25.921503442823397,
#    43.85436276523194,
#    46.18630181115725,
#    67.38030282503173,
#    71.59068716207611,
#    91.97483484681985,
#    96.26996093072776,
#    115.18179665226101,
#    119.33792082479371,
#    138.7910141242005,
#    140.00818176374997,
#    143.41754065021584,
#    163.32313582386567,
#    164.91448530722093],
#   'Officer_Station_3_Night_18': [23.03954599359778,
#    24.088259837344825,
#    44.45665586970042,
#    46.73763043328377,
#    66.6678557485114,
#    71.34504791693554,
#    91.41594364766779,
#    96.28228728927628,
#    114.74802244425608,
#    116.95437325269809,
#    118.28158885377496,
#    120.37207466687373,
#    141.0813011459475,
#    163.7508221203319,
#    164.82719018623789],
#   'Officer_Station_3_Night_19': [21.795381507180736,
#    23.378387385274053,
#    24.32154781735816,
#    44.08504507691748,
#    46.49605231139408,
#    67.340442163462,
#    91.30786050946942,
#    95.32178542525597,
#    114.78432026541901,
#    116.61840372610503,
#    119.17409043271526,
#    141.22002909433544,
#    162.88323295003116,
#    164.08960795869785],
#   'Officer_Station_3_Night_20': [22.01603528255484,
#    24.31685512665848,
#    44.170759199648984,
#    47.20461850894121,
#    65.81910580212465,
#    91.25786050946941,
#    95.18289212815543,
#    115.03626691405775,
#    118.96645640091467,
#    119.6907251380904,
#    139.7677254540517,
#    142.96942443164295,
#    162.92392119473928,
#    165.41538122777274],
#   'Officer_Station_3_Night_21': [22.21072421640238,
#    24.72732983724844,
#    44.25743322639653,
#    46.16770812140268,
#    91.33213044322652,
#    94.89496733356125,
#    96.3061309148501,
#    115.2808555810866,
#    119.2172047898719,
#    140.2407251380904,
#    143.0412520811797,
#    163.1575709797507,
#    166.05381786194366],
#   'Officer_Station_3_Night_22': [23.532170982964196,
#    25.465276500156424,
#    43.18051657977413,
#    44.709620213261914,
#    46.37300889641266,
#    91.43880105013565,
#    96.3808651677579,
#    117.27727002422203,
#    119.79342924444006,
#    140.8779872076788,
#    163.22220647687573,
#    164.66267081851223],
#   'Officer_Station_3_Night_23': [22.689268039486258,
#    24.417255247165073,
#    44.080516579774134,
#    45.970060812901394,
#    92.24872591141317,
#    96.53179418879274,
#    116.52654258777008,
#    140.1124351019599,
#    163.91207272307142],
#   'Officer_Station_3_Night_24': [22.759929487094258,
#    25.20507070269139,
#    42.566295679814154,
#    44.842143335060726,
#    92.45230084756292,
#    95.36029268592083,
#    115.78274870863123,
#    140.50604914469682,
#    162.88966711307032,
#    164.51944753977637],
#   'Officer_Station_3_Night_25': [22.517404907829164,
#    23.07982494374621,
#    23.75637963312514,
#    25.81198417893673,
#    44.41859491886148,
#    92.48855453673053,
#    96.34729496764167,
#    116.68986681203256,
#    139.85282189419067,
#    163.3075776255314],
#   'Officer_Station_3_Night_26': [23.567012166777157,
#    25.345229077299916,
#    43.133232950031164,
#    45.659814341959255,
#    93.05042986719488,
#    97.46370345480051],
#   'Officer_Station_3_Night_27': [23.63740640971748,
#    24.647812087172166,
#    43.67710709449877,
#    93.36328450950457],
#   'Officer_Station_3_Night_28': [21.734730547587475,
#    22.302586296098887,
#    24.68644975796055,
#    44.87022415190936,
#    93.1909555438878]},
#  {'Immediate': {'total': 310, 'within_time': 310, 'percentage': 100.0},
#   'Prompt': {'total': 1438,
#    'within_time': 1428,
#    'percentage': 99.30458970792768},
#   'Standard': {'total': 60, 'within_time': 60, 'percentage': 100.0}},
#  False)

# %%
simple_model.resolution_times
# Out:
# {'Immediate': [2.431411402723678,
#   1.4063470779965093,
#   1.400669414937981,
#   7.4629602826867085,
#   9.769585057985267,
#   10.723192815270144,
#   11.229322622988402,
#   9.502861675064041,
#   12.559761806574128,
#   11.877422080389207,
#   13.364899729111952,
#   13.767395421872928,
#   11.680246601645152,
#   13.50786050946941,
#   14.07914165351619,
#   19.37950997349142,
#   17.692753501145663,
#   18.24214333506072,
#   18.52035412600825,
#   18.704930629685705,
#   20.502725260355817,
#   21.325724693715657,
#   21.11075920189056,
#   20.84442811309068,
#   22.021353138244745,
#   22.65019693398259,
#   22.86023364114532,
#   21.974333596167295,
#   23.160544798124914,
#   23.816986612090776,
#   24.31685512665848,
#   23.875792283667696,
#   24.72732983724844,
#   23.244111876394975,
#   24.67240264223745,
#   25.46449396929651,
#   24.088259837344825,
#   23.75637963312514,
#   24.903367600634503,
#   23.882532115327457,
#   26.503357785066402,
#   28.0244757043372,
#   30.108361739381387,
#   34.405655969641494,
#   34.62554455769044,
#   35.41026413751577,
#   35.01415409157706,
#   35.77336236109461,
#   35.85988264868025,
#   35.4233055021642,
#   35.140512779165256,
#   35.40876856762476,
#   36.364739503182825,
#   34.673035919278206,
#   36.77414024456432,
#   36.95988264868024,
#   36.67330438722651,
#   37.52202072028073,
#   37.970465308613534,
#   38.950582270298305,
#   39.100572185096574,
#   37.90800902799253,
#   39.293889048783086,
#   40.316071448499976,
#   40.23467890091738,
#   39.22166919853232,
#   40.23356421659131,
#   40.169683636628754,
#   40.72242622500681,
#   41.399186121129205,
#   41.171154106614615,
#   41.60017464795955,
#   42.97388070952217,
#   43.067078441376175,
#   42.97871876974083,
#   44.12476826503387,
#   44.40970931597556,
#   45.45851459681154,
#   43.860306071492836,
#   45.38378958854398,
#   46.31239971858488,
#   46.707009286829816,
#   47.08166776049421,
#   47.55337749723619,
#   49.07069697473072,
#   50.15286167506404,
#   51.050669414937985,
#   54.05192075826498,
#   54.95300740444938,
#   57.188023842048835,
#   58.33605873970795,
#   58.045492182940535,
#   59.455456906547056,
#   58.43425895885285,
#   59.86339419297177,
#   60.04428762221504,
#   60.22048300898224,
#   61.09241516097251,
#   60.52036207335989,
#   60.91457501837751,
#   62.40412436344312,
#   60.88129407708087,
#   61.340725138090406,
#   62.29654667449982,
#   63.40230084756293,
#   64.54529829287283,
#   63.24886223308306,
#   66.2090880049425,
#   66.20233770392582,
#   67.50452636570064,
#   66.23421285594627,
#   67.26052741207982,
#   67.31021205841773,
#   68.03763416704751,
#   67.7482033759658,
#   68.34029105859358,
#   70.33838330964485,
#   69.76309577906505,
#   71.08962214758327,
#   69.5777327363375,
#   70.7367655923768,
#   71.75033517084164,
#   74.3114083803523,
#   73.99101815058768,
#   73.87700791196515,
#   75.03229992667018,
#   76.64132565809834,
#   75.78041488874759,
#   76.29419710046506,
#   76.88999409897957,
#   77.18644812711612,
#   78.78021060037769,
#   78.26147715527742,
#   77.63496727736026,
#   79.17754672190138,
#   80.22566059328545,
#   82.59126974841244,
#   82.76785574851141,
#   83.18711266919485,
#   83.27414024456432,
#   84.17780146551496,
#   83.7476532265834,
#   84.13245237729123,
#   84.98663031487105,
#   86.61096626291486,
#   85.68688088105728,
#   85.6983042143356,
#   88.45014741389377,
#   88.80954893634244,
#   88.8718576501299,
#   89.19588638271378,
#   91.2202931771946,
#   91.08055892682495,
#   90.42424086103152,
#   90.79199442302962,
#   91.06377918939259,
#   91.50732636315013,
#   92.19510475864756,
#   90.90517682622074,
#   92.04640993993681,
#   91.6253890776234,
#   93.15699481958285,
#   93.35867660341482,
#   92.81487565404485,
#   93.94374765715783,
#   94.34388088414701,
#   95.25996213485246,
#   94.62362401745219,
#   95.62815492849981,
#   96.13484368767091,
#   96.80970931597557,
#   96.2516136148374,
#   96.52331854212957,
#   98.36201952373106,
#   97.52125471958533,
#   99.00308501016168,
#   100.55273532078321,
#   100.2863796296853,
#   100.80795032711336,
#   102.38942972673111,
#   104.41823460360638,
#   107.75810812556166,
#   108.40436276523194,
#   108.70230084756292,
#   108.31782669627837,
#   108.79722344829915,
#   111.02183911052138,
#   110.83141107822382,
#   113.2221730145707,
#   113.14643833013068,
#   114.22964577812549,
#   114.74350136617694,
#   115.14631934960663,
#   115.03573774753978,
#   116.27104598525769,
#   116.5912222270987,
#   115.68424143473177,
#   116.37275407395414,
#   116.2437572825177,
#   116.54714321241686,
#   117.54787216757646,
#   117.61485685029228,
#   115.6681362592962,
#   116.77097161234205,
#   115.74452270295663,
#   117.09419710046507,
#   117.21107007928924,
#   116.8400370516563,
#   118.7475274673661,
#   117.87657538810728,
#   118.15034973500919,
#   118.02840714985246,
#   118.94249330818934,
#   118.88880105013564,
#   120.42636484573039,
#   120.87194718030646,
#   121.1350104218237,
#   121.29540977918793,
#   123.02660562603806,
#   123.03913040650308,
#   124.42082145118434,
#   125.70959083060237,
#   127.0141166283072,
#   128.79689442914747,
#   129.7329956988201,
#   130.7338456803069,
#   131.01428072841856,
#   130.36841859775652,
#   131.89425204124677,
#   133.3150582460697,
#   133.53983066908128,
#   132.93842450026546,
#   134.4777150658123,
#   134.52553851048523,
#   134.35441917092118,
#   134.99589725116962,
#   134.26300825786464,
#   136.31564858219753,
#   134.99853434706418,
#   136.2657119923706,
#   134.96374147729514,
#   137.44372060064967,
#   137.23523562101605,
#   138.40347103706367,
#   137.641780538605,
#   137.7592337697819,
#   138.01753912829295,
#   139.20079626576182,
#   139.27054603687918,
#   140.35980753441422,
#   140.5952016532584,
#   139.6483337949853,
#   141.38116507193618,
#   139.73880105013563,
#   139.88237843129625,
#   141.6654226656942,
#   142.59236615222105,
#   142.4654226656942,
#   142.0765821004176,
#   141.21571679483895,
#   142.08541041682864,
#   142.1696092367191,
#   142.2922276306431,
#   143.11542266569418,
#   142.75487753074518,
#   144.47510543250368,
#   145.57636820696646,
#   147.23634340262015,
#   147.07463161384135,
#   148.20778298635636,
#   151.13441680192514,
#   150.85846972088748,
#   151.928886633674,
#   153.33289212815544,
#   155.5004330414098,
#   155.93253247121902,
#   157.30451607241116,
#   158.1131814685742,
#   158.45230084756292,
#   157.96564858219753,
#   160.02386572748247,
#   160.53302274745838,
#   160.25030959913894,
#   159.62271684640413,
#   161.45117143571457,
#   160.83388272489904,
#   161.11287524096534,
#   161.6315092244591,
#   161.21391735419763,
#   160.8690224468052,
#   162.43613799678425,
#   162.5252674668223,
#   162.92910509007373,
#   163.12483484681985,
#   162.705330461086,
#   161.6511457008594,
#   164.13806875238464,
#   164.47704485730628,
#   163.8967007690675,
#   163.99783766175716,
#   165.21981981708342,
#   165.09017869395146,
#   164.86413819294688,
#   165.51576353868995,
#   166.1220563645551,
#   166.4,
#   168.47791217427144,
#   166.8854181727042,
#   168.46972622917235,
#   168.50851459681155],
#  'Standard': [7.137892333343168,
#   7.348287731891172,
#   6.831935558860615,
#   7.042627490547426,
#   8.068538582284132,
#   7.598177580979235,
#   9.07855300018125,
#   9.284273645391979,
#   8.683198800665226,
#   8.249968610485844,
#   8.731373510347261,
#   8.206595097784334,
#   10.162535364789823,
#   9.927422080389208,
#   9.708968767725521,
#   9.40786050946941,
#   9.945518973383388,
#   10.060227288050077,
#   10.417506315724985,
#   11.03746661774284,
#   10.976720993521777,
#   11.931250954930587,
#   12.543875069536975,
#   13.152690541501713,
#   13.811924358060281,
#   13.821745005434678,
#   15.514558873698768,
#   14.785946945258448,
#   14.283212566332216,
#   15.153549124122408,
#   14.22744540625704,
#   15.236327232102019,
#   14.658606739171116,
#   14.866105251876343,
#   14.862657303898775,
#   15.864889841707651,
#   17.028367127220683,
#   17.65834782796171,
#   18.347945947053272,
#   18.960922716916766,
#   21.222998118421014,
#   21.33537015846124,
#   20.842786278934508,
#   22.525086973035254,
#   20.990038935946043,
#   23.378387385274053,
#   22.611099355430706,
#   24.3075698186324,
#   23.30866077890228,
#   23.894960855053323,
#   26.39688852929026,
#   25.549836935317764,
#   25.161301646094643,
#   24.826755043846063,
#   25.921503442823397,
#   25.860197495068814,
#   24.518717416747855,
#   24.31343044539087,
#   24.61626228180538,
#   26.254142869101443],
#  'Prompt': [0.8641669619491911,
#   1.7503324095778694,
#   1.1770079119651518,
#   1.058912635470806,
#   2.5857279340963863,
#   1.5072329267718751,
#   1.4209524513937886,
#   2.2335887409340094,
#   0.8415918824718713,
#   1.8345433872738264,
#   2.0317941887927384,
#   2.368811470448298,
#   2.7944535575359133,
#   3.4355309533352933,
#   3.205091775112673,
#   3.0276773269031327,
#   2.613365712831186,
#   2.227006914479122,
#   3.430488391732477,
#   2.951728577199466,
#   2.9638155298762268,
#   2.5755828247855135,
#   4.397296210219704,
#   2.8851955785536942,
#   3.788444567500417,
#   4.685340762302959,
#   3.1436983359924007,
#   4.546901379722578,
#   4.165807576121987,
#   3.5311546034780408,
#   3.412577430419036,
#   4.3245816026374415,
#   3.772480459262141,
#   4.031888473638789,
#   5.061461476059029,
#   4.382356757576556,
#   4.427047368145337,
#   4.158638082724623,
#   5.709744421174541,
#   4.8278274817039595,
#   4.325988204292697,
#   5.369339622586788,
#   4.677835534092917,
#   4.780978359662171,
#   4.856844306352925,
#   5.094475503620567,
#   6.523354245321365,
#   5.079345989359101,
#   5.63571454264296,
#   5.156290198874865,
#   6.336657848144921,
#   6.021010701180716,
#   6.136604101717678,
#   6.8519351580185415,
#   6.822657999168481,
#   5.719987491178395,
#   6.466487978047679,
#   7.680178332121855,
#   6.787737481714767,
#   6.058591046437792,
#   7.8534736955546975,
#   8.128500765186603,
#   8.351434617098436,
#   8.36867327296464,
#   7.131491448959578,
#   8.38725900583981,
#   7.957626776253839,
#   9.066875518876142,
#   8.063642970582865,
#   8.792548103936198,
#   9.496907093597864,
#   9.711104350717134,
#   9.243644797352964,
#   8.788644048254309,
#   9.568123872883122,
#   9.982892128155429,
#   11.230302825031734,
#   11.63365085176186,
#   9.569864588752463,
#   9.765034749971537,
#   10.457047867014014,
#   10.170422138048322,
#   10.806029940524454,
#   11.196554558146833,
#   9.617727427327544,
#   11.17300034603511,
#   9.712673691779935,
#   12.22539932491383,
#   11.444168967141225,
#   12.365632113021459,
#   12.288318523270554,
#   12.022053700424848,
#   11.108108125561658,
#   10.714609985040873,
#   10.843924074412678,
#   12.021895742375445,
#   12.165519948550298,
#   10.878642910317327,
#   11.77039140394315,
#   13.05,
#   11.782892128155428,
#   11.933845680306906,
#   12.541850126610358,
#   11.94357255926143,
#   12.892737595365643,
#   12.729235958262537,
#   11.823784658134654,
#   13.73165184768389,
#   13.825371984999407,
#   13.988981312847855,
#   13.34034623404159,
#   13.467946790436994,
#   13.832447316630699,
#   13.735282589858617,
#   13.715853890691257,
#   14.39629456145637,
#   13.419703443815502,
#   13.184897940733878,
#   14.088020986591413,
#   13.373492622490868,
#   15.277103199700743,
#   13.154087127954714,
#   14.748834499524838,
#   14.030934524556855,
#   14.651506162990403,
#   14.456106380234328,
#   14.771644602250253,
#   14.270707083126533,
#   16.352075560320053,
#   16.320778817040882,
#   15.555597222575031,
#   16.836559880328622,
#   16.746020155082928,
#   18.097248423338023,
#   17.01039003324964,
#   18.788464110249997,
#   19.224509758156053,
#   19.085629865989826,
#   18.654930629685705,
#   19.324461601956685,
#   20.127382241539728,
#   20.115407350683768,
#   20.710492819676773,
#   20.972695311002752,
#   21.853073050945444,
#   22.522706326251505,
#   21.562534516974367,
#   21.94292894195017,
#   21.07350519523917,
#   20.768565947671274,
#   22.354982877301403,
#   22.00615742588894,
#   22.24739618505766,
#   22.71790862951817,
#   22.354362765231944,
#   22.288270142052262,
#   22.45197972131287,
#   22.23827014205226,
#   21.86843651490696,
#   22.807383582405905,
#   22.685904363481605,
#   21.719149855615107,
#   23.5376576617951,
#   23.117012166777158,
#   23.03954599359778,
#   21.795381507180736,
#   22.01603528255484,
#   22.21072421640238,
#   23.532170982964196,
#   22.689268039486258,
#   22.759929487094258,
#   22.517404907829164,
#   23.567012166777157,
#   23.63740640971748,
#   21.734730547587475,
#   23.012909510434714,
#   23.35567879884933,
#   22.24161709197297,
#   23.365770967414505,
#   23.523061042178114,
#   23.829870706471024,
#   23.30337352293199,
#   22.302586296098887,
#   24.10548831669605,
#   23.08510554156159,
#   24.68644975796055,
#   23.749072949235458,
#   23.245070740922603,
#   24.950993381165468,
#   23.07982494374621,
#   24.480955509574052,
#   24.96324642276345,
#   24.11698062252424,
#   24.39787818576175,
#   24.78007333062283,
#   24.417255247165073,
#   25.254591619362227,
#   25.20507070269139,
#   24.297610727361757,
#   25.163654564281128,
#   25.69246741417875,
#   24.952721901171792,
#   24.371537699049902,
#   24.750858743788474,
#   25.645235577236086,
#   24.96156968123831,
#   25.183311617630352,
#   24.32154781735816,
#   25.04060169239396,
#   25.465276500156424,
#   24.61421235117403,
#   25.345229077299916,
#   24.647812087172166,
#   24.53951511269745,
#   25.81198417893673,
#   26.340552165325242,
#   24.69946715559873,
#   24.897997187128375,
#   25.622046574912435,
#   26.24635706081028,
#   24.946343708725692,
#   26.624162261539144,
#   24.710281291907613,
#   25.68251841010388,
#   26.138673032630393,
#   26.907499863210827,
#   26.641508764554676,
#   26.82715565212711,
#   27.74062802600757,
#   26.6,
#   28.11607172214924,
#   27.730052731281866,
#   29.340048798061698,
#   29.525466189928398,
#   27.84809168339055,
#   29.53465670124564,
#   29.6081545533639,
#   29.084586091369015,
#   30.196111955881516,
#   28.7073116253087,
#   30.212141965881013,
#   31.173950325955104,
#   29.621584430312385,
#   30.857159048384236,
#   30.680257075758195,
#   31.19173990429785,
#   31.809935477858485,
#   32.56112327256202,
#   32.2159951053262,
#   33.427203600783955,
#   32.94134416952894,
#   33.0971247188626,
#   33.42883886510814,
#   32.70004020673749,
#   32.25646198178731,
#   31.717302450899894,
#   33.91322715686491,
#   33.48983539164397,
#   34.369737249330534,
#   33.01045019469072,
#   32.91479399203058,
#   34.42788755708148,
#   33.895020715704696,
#   34.51673300236457,
#   35.036076663843,
#   35.01313548937863,
#   35.2808651677579,
#   34.07553851048524,
#   34.575772151022974,
#   35.25286167506404,
#   34.841859625106075,
#   34.779977950808345,
#   36.270084407445594,
#   36.270084407445594,
#   34.75950394500659,
#   35.59366238336836,
#   35.59309961042515,
#   35.146098133103486,
#   35.651174989596164,
#   36.79789807430075,
#   35.66203906508072,
#   35.858314411036424,
#   37.31166181265138,
#   37.374731795648636,
#   36.121646068286836,
#   36.57609358046785,
#   35.720162544750636,
#   36.00670409911056,
#   36.6909416924069,
#   38.17439786267776,
#   37.75786050946941,
#   38.64722344829916,
#   37.671154106614615,
#   36.960814434361545,
#   37.691222227098706,
#   38.22095359104966,
#   37.766002834659254,
#   38.129254261484064,
#   39.55786050946941,
#   39.374240861031524,
#   38.932051787058576,
#   39.42866751953542,
#   37.6778517179136,
#   39.08237316384154,
#   37.562435101959885,
#   38.826816799833246,
#   38.18125866850889,
#   38.54080061254026,
#   39.0792657929227,
#   39.81661772701447,
#   40.59284357066065,
#   40.6252004756821,
#   39.3279703159805,
#   40.02404721758193,
#   40.651314314916696,
#   39.73936679407055,
#   40.09787485992201,
#   40.01738115997336,
#   39.96370839112993,
#   40.73175588471644,
#   41.61625536989719,
#   40.94176166807327,
#   41.48799536022683,
#   39.93627167019361,
#   40.30456132668775,
#   40.678279357419974,
#   41.78027116354343,
#   40.696021916431945,
#   41.651974626889505,
#   40.57008864563616,
#   41.23167624885943,
#   41.439935490233765,
#   41.728754481274045,
#   41.27024265681417,
#   42.04316043208411,
#   41.28207891918832,
#   42.52199609624652,
#   41.36268925957629,
#   41.240725138090404,
#   42.184260575054346,
#   42.19571955522238,
#   41.71258519512974,
#   40.757884190722066,
#   41.59822846829573,
#   42.19079196027078,
#   42.69291854003046,
#   42.71433343442341,
#   41.74260439546489,
#   42.178878403270915,
#   42.30037721674201,
#   42.898333794985305,
#   42.521110447774674,
#   42.82748105801243,
#   42.29903205992164,
#   43.51812387288312,
#   41.88454338727383,
#   42.17207466687372,
#   43.56857541318165,
#   43.57027892326444,
#   43.70253053247919,
#   44.752397558141965,
#   43.62138222394413,
#   43.95909799774064,
#   43.88755747242489,
#   43.37986385577139,
#   43.85436276523194,
#   44.45665586970042,
#   44.08504507691748,
#   44.170759199648984,
#   44.25743322639653,
#   43.18051657977413,
#   44.080516579774134,
#   42.566295679814154,
#   44.41859491886148,
#   43.133232950031164,
#   43.67710709449877,
#   45.3826972532641,
#   44.212689259576294,
#   44.25230084756293,
#   44.93049619740024,
#   45.38060061751309,
#   44.003491994590576,
#   44.92270567798079,
#   45.52424086103152,
#   43.63921945880311,
#   45.261072026442136,
#   44.39224180512801,
#   44.12705794513015,
#   45.202221306338096,
#   45.47663518617833,
#   44.842143335060726,
#   44.87022415190936,
#   45.13986681203257,
#   44.72143958657113,
#   45.15512329943088,
#   45.20745773104752,
#   46.243551889404536,
#   46.42102145114326,
#   46.605618074549305,
#   46.38439030863689,
#   45.187297817565536,
#   46.18630181115725,
#   44.709620213261914,
#   45.659814341959255,
#   45.89683539950933,
#   47.44221635049476,
#   45.654419170921194,
#   45.85,
#   46.73089992651504,
#   46.777024592914856,
#   45.63528915039299,
#   46.79416490043663,
#   46.399808169367354,
#   46.73763043328377,
#   47.03861426892643,
#   46.49605231139408,
#   47.20461850894121,
#   46.16770812140268,
#   46.37300889641266,
#   45.970060812901394,
#   46.726542587770076,
#   47.51841318745141,
#   47.05355439050106,
#   46.8808651677579,
#   47.151483802677255,
#   48.243550130513626,
#   47.45436276523194,
#   49.25962021624874,
#   48.58239040067988,
#   49.472851250484474,
#   48.30436276523194,
#   48.6329564094634,
#   47.665341991354616,
#   49.12195474019357,
#   47.69660377964375,
#   47.60230084756293,
#   50.03762745810811,
#   48.8431486746854,
#   49.34373666176212,
#   48.772940417102646,
#   50.16607144849998,
#   50.06363208774613,
#   48.75201875577969,
#   50.66887785457276,
#   50.37478623311367,
#   50.2850104218237,
#   50.61068333406593,
#   51.55976180657413,
#   51.77875850678947,
#   51.41778684073656,
#   51.68252259383441,
#   53.208193396484624,
#   53.05221419777245,
#   52.18610043475662,
#   53.11669111655968,
#   52.871955593032666,
#   54.478665436355165,
#   54.236100434756615,
#   53.056101699693045,
#   54.65876856762476,
#   54.17286444315521,
#   54.508153292944044,
#   56.17108997555481,
#   55.294389086585504,
#   56.5230206930737,
#   55.81573362528404,
#   57.21722295451024,
#   56.99316017403788,
#   58.4931941714479,
#   58.396698575282066,
#   57.00933905844369,
#   57.468412505283446,
#   58.33572793409638,
#   58.14549218294053,
#   58.52207466687372,
#   58.36849328312544,
#   58.17630755736235,
#   58.69613024192034,
#   58.55079626576181,
#   59.40810812556166,
#   58.85971994384135,
#   60.38939181630803,
#   59.234796908468255,
#   59.60653426568424,
#   59.56164127757491,
#   60.03983066908127,
#   59.067395421872924,
#   60.781900914210006,
#   59.42539646459256,
#   60.689468766776315,
#   59.62017912647694,
#   61.57626090418628,
#   60.12985999676867,
#   60.86267123297897,
#   60.26333377713633,
#   60.82591190159585,
#   59.742415160972506,
#   60.113333777136326,
#   61.35412213413703,
#   60.34330663688068,
#   61.43065396155222,
#   60.15386318722517,
#   60.83260877171629,
#   61.25676004349486,
#   61.38924855236777,
#   62.30515313722575,
#   60.742493845843335,
#   61.06785834055352,
#   62.582160844331604,
#   62.45205316450182,
#   62.21924865961811,
#   62.540790119966644,
#   61.76652145864908,
#   63.58521619193017,
#   62.61929869778759,
#   61.954526365700644,
#   62.87903354993353,
#   63.576171555211225,
#   63.601070052761735,
#   61.724372109538685,
#   63.36913434376035,
#   63.11457011373043,
#   64.36601744990405,
#   62.83482404348984,
#   63.91538122777275,
#   62.97968832458684,
#   63.022475640591324,
#   63.20358237103398,
#   64.09544635822289,
#   64.85842295633121,
#   64.00989507910553,
#   65.49557790256199,
#   64.94351526959541,
#   64.38821779295347,
#   64.94928992265778,
#   65.66736323363062,
#   64.05032832527587,
#   64.73578916640884,
#   65.29906113062073,
#   64.75758380882185,
#   65.60280594929462,
#   65.92920556263135,
#   65.20032832527586,
#   65.7617555515706,
#   65.30441917092121,
#   66.23086516775791,
#   66.48108267979084,
#   65.41438963123498,
#   65.6066059276012,
#   66.46781769125997,
#   67.18173912150667,
#   67.09881768788657,
#   66.06959336071462,
#   66.63246448839057,
#   67.35,
#   66.0155488366529,
#   67.19727934172172,
#   66.68358188107038,
#   66.63646400262374,
#   66.06201271865628,
#   66.5805809946441,
#   65.58986681203257,
#   65.71115761538347,
#   67.38030282503173,
#   66.6678557485114,
#   67.340442163462,
#   65.81910580212465,
#   66.86888511436185,
#   68.55265162593123,
#   69.16318086218138,
#   67.66239971858488,
#   68.5034644324083,
#   68.55452865471909,
#   68.28115745203549,
#   69.06630332981601,
#   68.82390727347503,
#   68.85858983487088,
#   69.13736135318918,
#   69.31943924172718,
#   68.6283823181804,
#   69.88330849947795,
#   69.13729781756552,
#   70.48307422909717,
#   69.55355439050106,
#   70.20517036318455,
#   69.52192223960179,
#   68.8138181466096,
#   70.68894155863796,
#   68.75914058907233,
#   69.564112722025,
#   69.74022714495585,
#   71.54312114768689,
#   71.42539646459255,
#   69.84394276412397,
#   70.75824918332255,
#   71.34906113062074,
#   70.45758380882185,
#   70.37878199186085,
#   70.88030282503173,
#   70.02878199186085,
#   71.04560403536784,
#   71.59068716207611,
#   71.34504791693554,
#   72.0566059276012,
#   72.36292930789901,
#   72.3073328602014,
#   70.96493924386827,
#   71.73086516775791,
#   72.37342612113203,
#   70.75533229052405,
#   72.05506508352552,
#   71.16550202142696,
#   70.6757819084792,
#   72.46692803214636,
#   72.24578984392303,
#   73.4854393124562,
#   72.25436647680078,
#   72.90692884309041,
#   71.87796984803983,
#   71.90286167506405,
#   73.25818866407457,
#   73.21228693326873,
#   74.40822271287459,
#   72.88777671103504,
#   74.23576099192347,
#   73.79904377872391,
#   74.2044191709212,
#   74.44431214758724,
#   74.34410575103423,
#   72.95399712044998,
#   73.84612419221256,
#   74.15162765388804,
#   74.70749986321083,
#   74.19530767296418,
#   74.62239854146942,
#   75.22280332570676,
#   74.66602366443561,
#   75.20741241517304,
#   76.0639909017991,
#   75.5873035088699,
#   76.11276890388862,
#   75.55052388005895,
#   76.14300660263667,
#   76.3234504611235,
#   76.17754672190138,
#   76.09392407441268,
#   76.3341018548264,
#   76.78718969211097,
#   76.30940457727131,
#   77.1871251316235,
#   77.24973673220441,
#   77.72375909191774,
#   77.27820171562806,
#   77.9899799452359,
#   77.87969514358421,
#   77.57482245908153,
#   78.66035871831055,
#   78.10993166259246,
#   78.89226324470697,
#   80.22798028669567,
#   80.47866792749858,
#   79.99378470720025,
#   80.12827112950747,
#   81.54906113062073,
#   82.16365920381827,
#   82.16896141635718,
#   81.9407251380904,
#   81.5179182954189,
#   82.32142383692712,
#   83.40160276419596,
#   82.88342029052518,
#   84.4637921490868,
#   83.82760948380387,
#   84.31557283914502,
#   84.13318490024761,
#   82.71999119380243,
#   82.77416905556153,
#   83.45608640450092,
#   84.2009336182513,
#   83.66967393174711,
#   85.48191674441176,
#   84.6483042143356,
#   83.88680346028022,
#   84.53872822697922,
#   84.23714098249114,
#   85.0137921490868,
#   85.10893516112496,
#   86.51675215683717,
#   86.66822308741335,
#   85.12821504616339,
#   85.4044191709212,
#   85.63144067615977,
#   85.5706167456652,
#   85.9052699394421,
#   86.1854871095161,
#   86.74965430155117,
#   86.26967393174712,
#   86.90988264868024,
#   86.05441917092121,
#   85.69182073514179,
#   86.35162780334343,
#   86.19261387029925,
#   87.68478067746489,
#   88.3897195547599,
#   88.52484907839055,
#   87.46375579142217,
#   87.94570123488958,
#   87.26545797629252,
#   86.90675483191154,
#   88.4514824958293,
#   88.04621859036756,
#   88.08971955475991,
#   88.80191186792014,
#   88.75743386417844,
#   89.1544191709212,
#   88.18789454955933,
#   89.4957012348896,
#   88.77528032314183,
#   87.92374471426487,
#   87.90230084756293,
#   89.59751472856088,
#   87.9718576501299,
#   88.41681623215297,
#   89.30876856762477,
#   90.2407251380904,
#   89.04904377872391,
#   88.78134412569257,
#   90.52291867327548,
#   89.03954599359777,
#   90.37868659880594,
#   89.942241805128,
#   89.64643833013068,
#   90.99975920049202,
#   90.4252004756821,
#   89.72609586422242,
#   89.70524325938592,
#   91.45824918332254,
#   90.58450801347371,
#   89.67663518617833,
#   90.30355439050106,
#   90.07424086103153,
#   90.22335436146533,
#   90.68826091401947,
#   90.85795588452817,
#   91.50436647680078,
#   92.4483674245455,
#   90.63342029052518,
#   91.75446124910931,
#   92.33521619193017,
#   91.81251763932919,
#   91.97325226211629,
#   90.78452249430933,
#   91.97483484681985,
#   91.41594364766779,
#   91.30786050946942,
#   91.25786050946941,
#   91.33213044322652,
#   91.43880105013565,
#   92.24872591141317,
#   92.45230084756292,
#   92.48855453673053,
#   92.30516286446299,
#   91.88295640946339,
#   93.35842295633121,
#   92.99825378748064,
#   91.80286167506404,
#   92.71662406219427,
#   92.73738404568495,
#   92.3031277851464,
#   93.14736712144158,
#   91.77207466687373,
#   91.71973724933054,
#   92.77632441014461,
#   92.40148089339098,
#   93.05042986719488,
#   93.36328450950457,
#   93.1909555438878,
#   94.56092271691676,
#   92.6958610384647,
#   93.43521358403248,
#   94.13865409542161,
#   93.1796161798043,
#   93.51744339340563,
#   92.67410945741246,
#   94.19779411030282,
#   94.4984632037834,
#   94.70355439050105,
#   94.1534209231358,
#   95.0815092244591,
#   94.0033596944366,
#   95.443880884147,
#   95.42753300507599,
#   94.20573675116461,
#   95.43443873575853,
#   94.31129425686663,
#   95.49493114777513,
#   96.13429919993736,
#   95.96921237902367,
#   95.3074577310475,
#   96.01645640091466,
#   95.0950207946659,
#   95.58314785936493,
#   94.90038884497262,
#   95.48923967490283,
#   95.06382253625499,
#   96.26996093072776,
#   96.28228728927628,
#   95.32178542525597,
#   95.18289212815543,
#   94.89496733356125,
#   96.3808651677579,
#   96.53179418879274,
#   95.36029268592083,
#   96.34729496764167,
#   96.24817112948679,
#   96.13124775996981,
#   96.18998428845457,
#   96.40311805678719,
#   97.14072953683717,
#   96.06662406219426,
#   95.94779411030282,
#   96.95286167506404,
#   97.10810812556166,
#   96.4245063080065,
#   96.3061309148501,
#   97.46370345480051,
#   98.07636316552,
#   96.66578826029854,
#   96.77329878044655,
#   97.42593042198338,
#   97.78591107496128,
#   97.02554455769045,
#   97.91393802418656,
#   96.72221885042913,
#   98.08486896725434,
#   97.85809213163839,
#   98.40822271287459,
#   96.94621859036755,
#   98.1441385734329,
#   98.39964575742502,
#   97.46035021664804,
#   99.05252167546087,
#   98.89106450624075,
#   99.09417308462008,
#   98.57059853648494,
#   99.69042746186182,
#   100.23406884131008,
#   99.94903583442267,
#   99.87291197007634,
#   98.85034617903734,
#   99.1755094847244,
#   100.9506380512824,
#   99.15315386064972,
#   100.07134080552704,
#   100.47366484647142,
#   100.46628459593465,
#   101.08754034571383,
#   100.16963927454849,
#   100.86036221949264,
#   101.19021331639362,
#   101.05586043633393,
#   102.20526345739837,
#   102.05205249626093,
#   101.83523264542653,
#   101.83657397055637,
#   102.25034561901376,
#   103.10198026602198,
#   101.97652652153546,
#   102.18183864041605,
#   101.57755156298398,
#   102.67869072188054,
#   103.10687547714551,
#   103.07435371945937,
#   102.9212323083102,
#   103.44978661427692,
#   102.22570932933279,
#   102.34939626896242,
#   102.78332569116978,
#   104.14230618701552,
#   104.47281156712,
#   104.50136163315211,
#   104.74976623775298,
#   104.56783587132122,
#   104.49685581486062,
#   103.71953602806516,
#   103.14243035520077,
#   104.83859643427874,
#   104.87166277859478,
#   104.57912168691587,
#   104.43608711609535,
#   104.87515334999925,
#   104.61723698654518,
#   105.87603663548411,
#   105.31213077878068,
#   107.36079583412628,
#   105.72188281162111,
#   106.70487390275592,
#   106.57232616531702,
#   105.71027248572713,
#   106.46373497056366,
#   106.30286167506404,
#   106.814993936457,
#   108.37411077536647,
#   108.00848744778177,
#   106.96237850957763,
#   107.41614596311997,
#   108.20516191309878,
#   107.76102027646944,
#   108.4222009969004,
#   108.39837567470933,
#   109.15726040337881,
#   108.76208742619404,
#   109.31242036682899,
#   109.73738404568495,
#   109.68406985723213,
#   109.6726034903048,
#   108.73913040650308,
#   108.99659218520142,
#   109.43164499461423,
#   109.03431539821423,
#   110.48569514104308,
#   108.92850630438339,
#   109.66443166121644,
#   110.76399076959,
#   110.49032535292822,
#   110.44219731537852,
#   111.92091767032076,
#   112.63502368791116,
#   111.18260610309426,
#   111.25342827267579,
#   110.71238439856451,
#   111.86925601357298,
#   112.03068961232951,
#   111.18355146805145,
#   110.58952175830876,
#   112.54441887555222,
#   112.64917186003915,
#   113.07330438722651,
#   112.4701354184243,
#   112.79072513809041,
#   113.07002182135281,
#   112.87869169155827,
#   112.3602116445704,
#   111.96021164457039,
#   112.61221863481572,
#   112.19214333506072,
#   112.42457833730869,
#   111.81437099757778,
#   113.80878709254605,
#   114.4907251380904,
#   113.2459258543724,
#   113.96892545874027,
#   113.42525865412516,
#   112.93371593607945,
#   114.6907251380904,
#   115.38549804311916,
#   113.80261589552681,
#   113.9123377836227,
#   115.07540042509301,
#   113.99640993993681,
#   114.75571165123702,
#   114.43019377090407,
#   114.03686632351949,
#   114.1545286547191,
#   115.48158118322523,
#   115.08649894061462,
#   115.42023288106746,
#   114.54151348465061,
#   115.05648869153286,
#   115.95835560396668,
#   115.49514121559714,
#   115.18179665226101,
#   114.74802244425608,
#   114.78432026541901,
#   115.03626691405775,
#   115.51564986324362,
#   115.03132098373007,
#   115.36944434051854,
#   115.4801129022798,
#   115.2808555810866,
#   115.73246936391686,
#   116.20169856629431,
#   115.90163934217188,
#   116.95437325269809,
#   116.61840372610503,
#   117.27727002422203,
#   116.52654258777008,
#   115.78274870863123,
#   116.68986681203256,
#   117.86663135629249,
#   116.78057087970633,
#   117.94404915862596,
#   118.15736002866902,
#   117.11365920381826,
#   116.65810812556165,
#   118.2623365885475,
#   118.4544191709212,
#   117.73055892682495,
#   117.74421006895834,
#   117.91895389429726,
#   ...]}

# %%
calculate_simulation_performance(simulation.analyze_simulation_results())
# Out:
# 0.7588668671263857

# %%
simulation.run(bayesian_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 simulation.run(bayesian_model)
#
# NameError: name 'bayesian_model' is not defined

# %%
calculate_simulation_performance(simulation.analyze_simulation_results())
# Out:
# 0.8209696554210693

# %%
9943266723146396

# %%
def calculate_simulation_performance(results_dict):
    # Information from the results analysis
    immediate_completion_pct = results_dict["Completion Percentages"]["Immediate"]
    immediate_threshold_pct = results_dict["Threshold Compliance"]["Immediate"]

    prompt_completion_pct = results_dict["Completion Percentages"]["Prompt"]
    prompt_threshold_pct = results_dict["Threshold Compliance"]["Prompt"]

    standard_completion_pct = results_dict["Completion Percentages"]["Standard"]
    standard_threshold_pct = results_dict["Threshold Compliance"]["Standard"]

    mean_officer_hours  = results_dict["Mean Officer Hours"]

    # Rescaling these values
    immediate_completion_pct /= 100
    prompt_completion_pct /= 100
    standard_completion_pct /= 100

    immediate_threshold_pct /= 100
    prompt_threshold_pct /= 100
    standard_threshold_pct /= 100

    immediate_incompletion_pct = 1 - immediate_completion_pct
    prompt_incompletion_pct = 1- prompt_completion_pct
    standard_incompletion_pct = 1 - standard_completion_pct

    # Calculating the score

    # First factor - Incident resolved within threshold (Scale - 0 to 1)
    incident_within_threshold = (2*immediate_threshold_pct + 1.5*prompt_threshold_pct + 1*standard_threshold_pct)/(4.5)

    # Second factor - Officer utilisation
    # 8 hours per shift, 7 days in the simulation (Scale - 0 to 1)
    # Least officer utilisation
    officer_utilisation = (8*7 - mean_officer_hours)/(8*7)

    # Third factor - Unresolved Incidents (Scale - 0 to 1)
    unresolved_incidents = ((6*immediate_incompletion_pct)+ 2*(prompt_incompletion_pct) + 1*(standard_incompletion_pct))/9

    print(f"{incident_within_threshold=}")
    print(f"{officer_utilisation=}")
    print(f"{unresolved_incidents=}")
    
    # Total scale, (0 to 1)
    performance_metric = 0.8*incident_within_threshold + 0.2*officer_utilisation - unresolved_incidents*0.3
    return performance_metric

# %%
bayesian_model.incidents_history
# Out:
# defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>()>,
#             {6: defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {1: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Immediate': 1,
#                                        'Standard': 3}),
#                           2: defaultdict(int,
#                                       {'Standard': 3,
#                                        'Prompt': 3,
#                                        'Immediate': 1}),
#                           3: defaultdict(int,
#                                       {'Prompt': 2,
#                                        'Standard': 0,
#                                        'Immediate': 1}),
#                           4: defaultdict(int, {'Prompt': 3, 'Standard': 0}),
#                           5: defaultdict(int,
#                                       {'Standard': 2,
#                                        'Prompt': 4,
#                                        'Immediate': 1}),
#                           6: defaultdict(int,
#                                       {'Prompt': 4,
#                                        'Standard': 0,
#                                        'Immediate': 1}),
#                           7: defaultdict(int,
#                                       {'Prompt': 1,
#                                        'Immediate': 0,
#                                        'Standard': 0}),
#                           8: defaultdict(int,
#                                       {'Prompt': 1,
#                                        'Standard': 5,
#                                        'Immediate': 2}),
#                           9: defaultdict(int,
#                                       {'Standard': 1,
#                                        'Prompt': 7,
#                                        'Immediate': 3}),
#                           10: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Immediate': 1,
#                                        'Standard': 5}),
#                           11: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Prompt': 9,
#                                        'Standard': 3}),
#                           12: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Standard': 4,
#                                        'Immediate': 4}),
#                           13: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Standard': 4,
#                                        'Immediate': 2}),
#                           14: defaultdict(int,
#                                       {'Prompt': 11,
#                                        'Standard': 5,
#                                        'Immediate': 4}),
#                           15: defaultdict(int,
#                                       {'Prompt': 18,
#                                        'Standard': 4,
#                                        'Immediate': 2}),
#                           16: defaultdict(int,
#                                       {'Prompt': 10,
#                                        'Standard': 7,
#                                        'Immediate': 3}),
#                           17: defaultdict(int,
#                                       {'Standard': 8,
#                                        'Prompt': 13,
#                                        'Immediate': 2}),
#                           18: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Immediate': 4,
#                                        'Standard': 3}),
#                           19: defaultdict(int,
#                                       {'Immediate': 3,
#                                        'Prompt': 19,
#                                        'Standard': 4}),
#                           20: defaultdict(int,
#                                       {'Immediate': 6,
#                                        'Prompt': 7,
#                                        'Standard': 3}),
#                           21: defaultdict(int,
#                                       {'Standard': 3,
#                                        'Prompt': 12,
#                                        'Immediate': 2}),
#                           22: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Immediate': 2,
#                                        'Standard': 2}),
#                           23: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Immediate': 1,
#                                        'Standard': 4}),
#                           0: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Standard': 3,
#                                        'Immediate': 3})}),
#              1: defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {0: defaultdict(int,
#                                       {'Prompt': 24,
#                                        'Immediate': 3,
#                                        'Standard': 3}),
#                           1: defaultdict(int,
#                                       {'Prompt': 16,
#                                        'Standard': 4,
#                                        'Immediate': 0}),
#                           2: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Standard': 0,
#                                        'Immediate': 0}),
#                           3: defaultdict(int, {'Prompt': 5, 'Standard': 0}),
#                           4: defaultdict(int, {'Standard': 3, 'Prompt': 6}),
#                           5: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Immediate': 1,
#                                        'Standard': 2}),
#                           6: defaultdict(int,
#                                       {'Standard': 2,
#                                        'Prompt': 5,
#                                        'Immediate': 0}),
#                           7: defaultdict(int, {'Prompt': 3, 'Standard': 2}),
#                           8: defaultdict(int,
#                                       {'Standard': 1,
#                                        'Prompt': 6,
#                                        'Immediate': 0}),
#                           9: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Immediate': 4,
#                                        'Standard': 3}),
#                           10: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Prompt': 12,
#                                        'Standard': 3}),
#                           11: defaultdict(int,
#                                       {'Prompt': 16,
#                                        'Standard': 5,
#                                        'Immediate': 3}),
#                           12: defaultdict(int,
#                                       {'Prompt': 10,
#                                        'Standard': 6,
#                                        'Immediate': 2}),
#                           13: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           14: defaultdict(int,
#                                       {'Prompt': 2,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           15: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 0,
#                                        'Immediate': 0}),
#                           16: defaultdict(int, {'Standard': 2, 'Prompt': 2}),
#                           17: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Immediate': 4,
#                                        'Standard': 2}),
#                           18: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Prompt': 3,
#                                        'Standard': 0}),
#                           19: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Prompt': 1,
#                                        'Standard': 0}),
#                           20: defaultdict(int,
#                                       {'Standard': 5,
#                                        'Prompt': 10,
#                                        'Immediate': 1}),
#                           21: defaultdict(int,
#                                       {'Prompt': 31,
#                                        'Immediate': 5,
#                                        'Standard': 5}),
#                           22: defaultdict(int,
#                                       {'Immediate': 6,
#                                        'Standard': 11,
#                                        'Prompt': 21}),
#                           23: defaultdict(int,
#                                       {'Standard': 9,
#                                        'Immediate': 5,
#                                        'Prompt': 11})}),
#              0: defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {1: defaultdict(int,
#                                       {'Standard': 5,
#                                        'Prompt': 9,
#                                        'Immediate': 3}),
#                           2: defaultdict(int,
#                                       {'Prompt': 6,
#                                        'Immediate': 1,
#                                        'Standard': 2}),
#                           3: defaultdict(int, {'Standard': 1, 'Prompt': 3}),
#                           4: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 2,
#                                        'Immediate': 0}),
#                           5: defaultdict(int, {'Prompt': 1, 'Standard': 2}),
#                           6: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Standard': 3,
#                                        'Prompt': 1}),
#                           7: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 1,
#                                        'Immediate': 1}),
#                           8: defaultdict(int,
#                                       {'Prompt': 5,
#                                        'Standard': 3,
#                                        'Immediate': 1}),
#                           9: defaultdict(int,
#                                       {'Standard': 0,
#                                        'Prompt': 8,
#                                        'Immediate': 1}),
#                           10: defaultdict(int,
#                                       {'Prompt': 4,
#                                        'Immediate': 1,
#                                        'Standard': 2}),
#                           11: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Standard': 4,
#                                        'Immediate': 1}),
#                           12: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Standard': 7,
#                                        'Prompt': 12}),
#                           13: defaultdict(int,
#                                       {'Standard': 5,
#                                        'Prompt': 10,
#                                        'Immediate': 1}),
#                           14: defaultdict(int,
#                                       {'Standard': 2,
#                                        'Prompt': 15,
#                                        'Immediate': 4}),
#                           15: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Standard': 6,
#                                        'Prompt': 16}),
#                           16: defaultdict(int,
#                                       {'Immediate': 5,
#                                        'Prompt': 14,
#                                        'Standard': 6}),
#                           17: defaultdict(int,
#                                       {'Standard': 4,
#                                        'Prompt': 8,
#                                        'Immediate': 5}),
#                           18: defaultdict(int,
#                                       {'Prompt': 17,
#                                        'Standard': 3,
#                                        'Immediate': 1}),
#                           19: defaultdict(int,
#                                       {'Prompt': 13,
#                                        'Immediate': 5,
#                                        'Standard': 8}),
#                           20: defaultdict(int,
#                                       {'Prompt': 14,
#                                        'Immediate': 3,
#                                        'Standard': 5}),
#                           21: defaultdict(int,
#                                       {'Prompt': 11,
#                                        'Standard': 3,
#                                        'Immediate': 1}),
#                           22: defaultdict(int,
#                                       {'Prompt': 10,
#                                        'Standard': 4,
#                                        'Immediate': 2}),
#                           23: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Immediate': 2,
#                                        'Standard': 2}),
#                           0: defaultdict(int,
#                                       {'Prompt': 1,
#                                        'Standard': 5,
#                                        'Immediate': 0})}),
#              2: defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {0: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Standard': 3,
#                                        'Immediate': 1}),
#                           1: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 3,
#                                        'Immediate': 0}),
#                           2: defaultdict(int,
#                                       {'Prompt': 5,
#                                        'Standard': 5,
#                                        'Immediate': 0}),
#                           3: defaultdict(int,
#                                       {'Prompt': 6,
#                                        'Standard': 2,
#                                        'Immediate': 1}),
#                           4: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Immediate': 0,
#                                        'Standard': 0}),
#                           5: defaultdict(int,
#                                       {'Immediate': 1,
#                                        'Standard': 1,
#                                        'Prompt': 5}),
#                           6: defaultdict(int,
#                                       {'Prompt': 1,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           7: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Standard': 2,
#                                        'Immediate': 0}),
#                           8: defaultdict(int, {'Standard': 2, 'Prompt': 7}),
#                           9: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Immediate': 2,
#                                        'Standard': 0}),
#                           10: defaultdict(int,
#                                       {'Prompt': 11,
#                                        'Standard': 6,
#                                        'Immediate': 9}),
#                           11: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Standard': 1,
#                                        'Prompt': 8}),
#                           12: defaultdict(int,
#                                       {'Standard': 6,
#                                        'Prompt': 9,
#                                        'Immediate': 2}),
#                           13: defaultdict(int,
#                                       {'Standard': 4,
#                                        'Prompt': 12,
#                                        'Immediate': 4}),
#                           14: defaultdict(int,
#                                       {'Immediate': 6,
#                                        'Standard': 4,
#                                        'Prompt': 18}),
#                           15: defaultdict(int,
#                                       {'Standard': 5,
#                                        'Prompt': 9,
#                                        'Immediate': 1}),
#                           16: defaultdict(int,
#                                       {'Standard': 8,
#                                        'Prompt': 8,
#                                        'Immediate': 3}),
#                           17: defaultdict(int,
#                                       {'Prompt': 13,
#                                        'Standard': 5,
#                                        'Immediate': 1}),
#                           18: defaultdict(int,
#                                       {'Prompt': 18,
#                                        'Immediate': 4,
#                                        'Standard': 3}),
#                           19: defaultdict(int,
#                                       {'Prompt': 16,
#                                        'Immediate': 2,
#                                        'Standard': 1}),
#                           20: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Standard': 2,
#                                        'Immediate': 2}),
#                           21: defaultdict(int,
#                                       {'Prompt': 16,
#                                        'Standard': 8,
#                                        'Immediate': 1}),
#                           22: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Immediate': 2,
#                                        'Standard': 5}),
#                           23: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Standard': 3,
#                                        'Immediate': 1})}),
#              3: defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {0: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Immediate': 1,
#                                        'Standard': 3}),
#                           1: defaultdict(int,
#                                       {'Standard': 6,
#                                        'Prompt': 4,
#                                        'Immediate': 1}),
#                           2: defaultdict(int, {'Prompt': 4, 'Standard': 2}),
#                           3: defaultdict(int,
#                                       {'Prompt': 4,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           4: defaultdict(int,
#                                       {'Prompt': 4,
#                                        'Standard': 4,
#                                        'Immediate': 1}),
#                           5: defaultdict(int,
#                                       {'Standard': 2,
#                                        'Immediate': 1,
#                                        'Prompt': 3}),
#                           6: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           7: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 1,
#                                        'Immediate': 1}),
#                           8: defaultdict(int,
#                                       {'Prompt': 4,
#                                        'Standard': 2,
#                                        'Immediate': 0}),
#                           9: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Immediate': 4,
#                                        'Standard': 1}),
#                           10: defaultdict(int,
#                                       {'Prompt': 10,
#                                        'Immediate': 2,
#                                        'Standard': 0}),
#                           11: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Standard': 1,
#                                        'Immediate': 4}),
#                           12: defaultdict(int,
#                                       {'Standard': 4,
#                                        'Immediate': 3,
#                                        'Prompt': 7}),
#                           13: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Immediate': 2,
#                                        'Standard': 1}),
#                           14: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Standard': 3,
#                                        'Immediate': 2}),
#                           15: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Standard': 3,
#                                        'Immediate': 0}),
#                           16: defaultdict(int,
#                                       {'Standard': 4,
#                                        'Immediate': 1,
#                                        'Prompt': 13}),
#                           17: defaultdict(int,
#                                       {'Prompt': 17,
#                                        'Immediate': 3,
#                                        'Standard': 3}),
#                           18: defaultdict(int,
#                                       {'Prompt': 1,
#                                        'Immediate': 4,
#                                        'Standard': 5}),
#                           19: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Standard': 5,
#                                        'Immediate': 1}),
#                           20: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Standard': 6,
#                                        'Prompt': 10}),
#                           21: defaultdict(int,
#                                       {'Prompt': 13,
#                                        'Standard': 3,
#                                        'Immediate': 3}),
#                           22: defaultdict(int,
#                                       {'Prompt': 10,
#                                        'Immediate': 1,
#                                        'Standard': 3}),
#                           23: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Standard': 3,
#                                        'Immediate': 0})}),
#              4: defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {0: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Immediate': 3,
#                                        'Standard': 3}),
#                           1: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           2: defaultdict(int,
#                                       {'Prompt': 4,
#                                        'Standard': 2,
#                                        'Immediate': 3}),
#                           3: defaultdict(int,
#                                       {'Prompt': 10,
#                                        'Standard': 3,
#                                        'Immediate': 2}),
#                           4: defaultdict(int,
#                                       {'Immediate': 3,
#                                        'Prompt': 2,
#                                        'Standard': 1}),
#                           5: defaultdict(int, {'Prompt': 3, 'Immediate': 1}),
#                           6: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Prompt': 1,
#                                        'Standard': 1}),
#                           7: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           8: defaultdict(int,
#                                       {'Prompt': 5,
#                                        'Immediate': 1,
#                                        'Standard': 1}),
#                           9: defaultdict(int,
#                                       {'Prompt': 3,
#                                        'Standard': 1,
#                                        'Immediate': 0}),
#                           10: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Standard': 3,
#                                        'Immediate': 5}),
#                           11: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Standard': 6,
#                                        'Immediate': 2}),
#                           12: defaultdict(int,
#                                       {'Immediate': 3,
#                                        'Prompt': 8,
#                                        'Standard': 1}),
#                           13: defaultdict(int,
#                                       {'Standard': 6,
#                                        'Prompt': 7,
#                                        'Immediate': 0}),
#                           14: defaultdict(int,
#                                       {'Prompt': 10,
#                                        'Immediate': 1,
#                                        'Standard': 1}),
#                           15: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Immediate': 2,
#                                        'Standard': 1}),
#                           16: defaultdict(int,
#                                       {'Immediate': 1,
#                                        'Standard': 3,
#                                        'Prompt': 8}),
#                           17: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Immediate': 5,
#                                        'Standard': 2}),
#                           18: defaultdict(int,
#                                       {'Standard': 9,
#                                        'Immediate': 3,
#                                        'Prompt': 17}),
#                           19: defaultdict(int,
#                                       {'Prompt': 16,
#                                        'Immediate': 3,
#                                        'Standard': 6}),
#                           20: defaultdict(int,
#                                       {'Prompt': 8,
#                                        'Standard': 5,
#                                        'Immediate': 2}),
#                           21: defaultdict(int,
#                                       {'Standard': 1,
#                                        'Prompt': 11,
#                                        'Immediate': 2}),
#                           22: defaultdict(int,
#                                       {'Prompt': 18,
#                                        'Standard': 6,
#                                        'Immediate': 4}),
#                           23: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Standard': 3,
#                                        'Immediate': 2})}),
#              5: defaultdict(<function __main__.BayesianOptimizationModel.__init__.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {0: defaultdict(int,
#                                       {'Prompt': 16,
#                                        'Standard': 6,
#                                        'Immediate': 2}),
#                           1: defaultdict(int,
#                                       {'Prompt': 20,
#                                        'Standard': 3,
#                                        'Immediate': 2}),
#                           2: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Standard': 3,
#                                        'Immediate': 2}),
#                           3: defaultdict(int,
#                                       {'Standard': 3,
#                                        'Prompt': 10,
#                                        'Immediate': 1}),
#                           4: defaultdict(int,
#                                       {'Prompt': 4,
#                                        'Immediate': 1,
#                                        'Standard': 2}),
#                           5: defaultdict(int, {'Standard': 3, 'Prompt': 2}),
#                           6: defaultdict(int, {'Prompt': 1, 'Standard': 0}),
#                           7: defaultdict(int,
#                                       {'Prompt': 1,
#                                        'Standard': 1,
#                                        'Immediate': 1}),
#                           8: defaultdict(int,
#                                       {'Standard': 2,
#                                        'Prompt': 2,
#                                        'Immediate': 0}),
#                           9: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Standard': 2,
#                                        'Immediate': 0}),
#                           10: defaultdict(int,
#                                       {'Standard': 3,
#                                        'Prompt': 9,
#                                        'Immediate': 2}),
#                           11: defaultdict(int,
#                                       {'Prompt': 5,
#                                        'Immediate': 2,
#                                        'Standard': 5}),
#                           12: defaultdict(int,
#                                       {'Prompt': 7,
#                                        'Standard': 2,
#                                        'Immediate': 1}),
#                           13: defaultdict(int,
#                                       {'Standard': 7,
#                                        'Prompt': 4,
#                                        'Immediate': 0}),
#                           14: defaultdict(int,
#                                       {'Prompt': 11,
#                                        'Immediate': 2,
#                                        'Standard': 2}),
#                           15: defaultdict(int,
#                                       {'Prompt': 11,
#                                        'Standard': 4,
#                                        'Immediate': 1}),
#                           16: defaultdict(int,
#                                       {'Immediate': 2,
#                                        'Prompt': 6,
#                                        'Standard': 0}),
#                           17: defaultdict(int,
#                                       {'Prompt': 14,
#                                        'Standard': 1,
#                                        'Immediate': 2}),
#                           18: defaultdict(int,
#                                       {'Prompt': 12,
#                                        'Immediate': 6,
#                                        'Standard': 3}),
#                           19: defaultdict(int,
#                                       {'Prompt': 9,
#                                        'Standard': 6,
#                                        'Immediate': 6}),
#                           20: defaultdict(int,
#                                       {'Standard': 6,
#                                        'Prompt': 11,
#                                        'Immediate': 3}),
#                           21: defaultdict(int,
#                                       {'Standard': 7,
#                                        'Immediate': 4,
#                                        'Prompt': 14}),
#                           22: defaultdict(int,
#                                       {'Prompt': 14,
#                                        'Standard': 4,
#                                        'Immediate': 2}),
#                           23: defaultdict(int,
#                                       {'Standard': 4,
#                                        'Prompt': 15,
#                                        'Immediate': 1})})})

# %%
class SimplifiedModel(NaiveModel):

    SPEED_MPH = 30
    
    def __init__(self, shift_distribution, police_stations_dict):
        super().__init__()
        self.shift_distribution = shift_distribution
        self.incident_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
        self.resolution_times = {"Immediate":[], "Standard":[], "Prompt":[]}
        self.processed_incidents = set()
        self.police_stations_dict = police_stations_dict
        
    def update_incident_count(self, incidents):
        """
        Update the count of incidents for each hour of each day.
        Only update for new incidents.
        """
        for incident in incidents:
            if incident.urn not in self.processed_incidents:
                day = incident.day
                hour = incident.hour
                priority = incident.priority
                self.incident_counts[day][hour][priority] += 1
                self.processed_incidents.add(incident.urn)

    def calculate_distance(self, lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between two points
        on the earth (specified in decimal degrees)
        """
        # Convert decimal degrees to radians
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

        # Haversine formula
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a))
        r = 3956  # Radius of Earth in miles. Use 6371 for kilometers
        return c * r

    
    def get_incident_resolution_time(self, incident, officer, current_time):
        officer_police_station_location = self.police_stations_dict[officer.station] 
        distance_to_incident = self.calculate_distance(officer_police_station_location.x, 
                                                  officer_police_station_location.y,
                                                  incident.latitude, 
                                                  incident.longitude
                                                 )
        travel_time = distance_to_incident / self.SPEED_MPH
        deployment_time = incident.deployment_time
        resolution_time = current_time + travel_time + deployment_time
        return resolution_time

    def get_incident_priority_count(self, incidents):
        counts = defaultdict(int)
        for inc in incidents:
            if not inc.resolved:
                counts[inc.priority] += 1
        return counts

    def get_no_available_officers_next_hour(self, officers, current_time):
        next_hour = ceil(current_time)
        no_available_officers = 0
        for station in officers.values():
            for officer in station:
                if officer.available:
                    no_available_officers += 1
                else:
                    if officer.return_time <= next_hour:
                        no_available_officers += 1
        return no_available_officers
            

    def get_mean_resolution_time(self):
        return {
            "Immediate":np.mean(self.resolution_times["Immediate"]), 
            "Prompt":np.mean(self.resolution_times["Prompt"]),
            "Standard": np.mean(self.resolution_times["Standard"])
        }

    def predict_peak_time_adjustments(self, weights_dict, current_time):
        # Initialize weights

        # Adjust weights based on peak hours and days
        if current_time % 24 in [8, 9, 10]:
            # Adjust the weight for Immediate incidents during peak hours
            weights_dict['Immediate'] *= 1.2  # Adjust the weight as needed
    
        if current_time // 24 + 1 in [1, 2]:
            # Adjust the weight for Prompt incidents on peak days
            weights_dict['Prompt'] *= 1.2
    
        if current_time % 24 in [15, 16]:
            # Adjust the weight for Standard incidents during peak hours
            weights_dict['Standard'] *= 1.2
    
        return self.normalise_weights(weights_dict)

    def normalise_weights(self, weights_dict):
        total_weight = sum(weights_dict.values())
        normalized_weights_dict = {incident_type: weight / total_weight for incident_type, weight in weights_dict.items()}
        return normalized_weights_dict
    
    def make_allocation(self, incidents, officers, current_time):
        self.update_incident_count(incidents)
    
        # Define thresholds and priority weights for each priority
        thresholds = {'Immediate': 1, 'Prompt': 3, 'Standard': 6}
        
        time_remaining_factor = 1.0  # Adjust the weight for time remaining
        priority_weights = {'Immediate': 8.7, 'Prompt': 5, 'Standard': 1}  # Adjusted weights
        priority_weights = self.normalise_weights(priority_weights)
        
        # Adjust priority weights based on predicted peak times
        priority_weights = self.predict_peak_time_adjustments(priority_weights, current_time)
        
        # Function to calculate the score based on distance and priority
        def calculate_score(travel_time, time_since_reported, priority):
            time_remaining = thresholds[priority] - time_since_reported - travel_time
            urgency = time_remaining_factor/time_remaining
            #urgency = (time_since_reported + travel_time) / thresholds[priority]
            return urgency * priority_weights[priority]

        # Get all available officers
        available_officers = [off for station_officers in officers.values() for off in station_officers if off.available]
    
        allocations = {}
    
        for officer in available_officers:
            officer_station = officer.station
            officer_station_location = self.police_stations_dict[officer_station]
            incident_queue = []
    
            for inc in incidents:
                if inc.urn not in allocations:  # Only consider unallocated incidents
                    travel_time = self.calculate_distance(
                        officer_station_location.x, officer_station_location.y, 
                        inc.latitude, inc.longitude) / self.SPEED_MPH
                    time_since_reported = current_time - inc.global_time
                    score = calculate_score(travel_time, time_since_reported, inc.priority)
                    heapq.heappush(incident_queue, (-score, inc.urn, inc))  # Using negative score for max heap
    
            # Allocate this officer to the most urgent incident
            if incident_queue:
                _, _, most_urgent_incident = heapq.heappop(incident_queue)
                allocations[most_urgent_incident.urn] = officer.name
                travel_time = self.calculate_distance(
                    officer_station_location.x, officer_station_location.y, 
                    most_urgent_incident.latitude, most_urgent_incident.longitude) / self.SPEED_MPH
                resolution_time = current_time + travel_time + most_urgent_incident.deployment_time
                self.resolution_times[most_urgent_incident.priority].append(resolution_time)
    
        # Mark unallocated incidents
        for inc in incidents:
            if inc.urn not in allocations:
                allocations[inc.urn] = None
    
        return allocations

        

# Note: The rest of the SimplifiedModel class remains unchanged.

# Explanation:
# The calculate_score function considers both the travel time and the time since the incident was reported,
# and combines them with the adjusted priority weights.
# A higher score indicates a higher priority for allocation.
# This should improve the allocation of officers by balancing the urgency of incidents with their distance from available officers.

# %%
shift_distribution = {'Early': {'Station_1': 7, 'Station_2': 0, 'Station_3': 8},
  'Day': {'Station_1': 0, 'Station_2': 0, 'Station_3': 25},
  'Night': {'Station_1': 0, 'Station_2': 11, 'Station_3': 29}
}

ps_coords = [ (p.x, p.y) for p in 
                [police_stations.one, 
                 police_stations.two, 
                 police_stations.three]]

simulation = SimulationWithMaxUtilisation(data, ps_coords, shift_distribution, 
                        verbose=0)

# %%
simple_model = SimplifiedModel({'Early': {'Station_1': 7, 'Station_2': 0, 'Station_3': 8},
  'Day': {'Station_1': 0, 'Station_2': 0, 'Station_3': 25},
  'Night': {'Station_1': 0, 'Station_2': 11, 'Station_3': 29}
}, police_stations_dict)

# %%
simulation.run(simple_model)

# %%
simulation.analyze_simulation_results()
calculate_simulation_performance(simulation.analyze_simulation_results())
# Out:
# 0.9997734697914059

# %%
simulation.analyze_simulation_results()
# Out:
# {'Completion Percentages': {'Immediate': 100.0,
#   'Prompt': 100.0,
#   'Standard': 100.0},
#  'Mean Response Times': {'Immediate': 88.3651432074921,
#   'Prompt': 84.69570707365737,
#   'Standard': 88.47573385463207},
#  'Mean Deployment Times': {'Immediate': 1.5403225806451613,
#   'Prompt': 1.5061196105702366,
#   'Standard': 1.4796755725190842},
#  'Threshold Compliance': {'Immediate': 100.0,
#   'Prompt': 99.44367176634215,
#   'Standard': 99.23664122137404},
#  'Mean Officer Hours': 56.73194632586308,
#  'Unresolved Incident Percentage': 0.0}

# %%
simulation.check_simulation()
# Out:
# ({'Officer_Station_1_Early_0': [1.400669414937981,
#    2.5776773269031326,
#    4.220916185916003,
#    5.186215610780068,
#    6.818637195966397,
#    8.027708569388667,
#    26.503357785066402,
#    27.19322459709898,
#    29.610253919403295,
#    31.7842042453584,
#    32.82026716721389,
#    50.241643958985016,
#    51.116614559470094,
#    54.05192075826498,
#    57.24358030657091,
#    73.87700791196515,
#    74.72524664972254,
#    76.60225456168769,
#    77.86767244349791,
#    79.17754672190138,
#    98.36201952373106,
#    99.91541704958631,
#    101.5179221788326,
#    103.97508021479536,
#    105.82546605682496,
#    120.87194718030646,
#    123.06608714484271,
#    125.08609081533685,
#    127.0141166283072,
#    146.0398404019603,
#    148.24762338831667,
#    150.31311880619154,
#    151.95360467796758],
#   'Officer_Station_1_Early_1': [2.431411402723678,
#    3.58431388304084,
#    4.957166908478815,
#    6.362193410467465,
#    7.198664695104181,
#    8.01578951969228,
#    26.549770425939496,
#    28.22688322585073,
#    30.097713359437783,
#    31.907648837296268,
#    33.86303492071751,
#    50.103883125088096,
#    51.92919876777483,
#    53.05640900023941,
#    56.2224707846542,
#    73.99101815058768,
#    75.5873035088699,
#    77.47110752647808,
#    78.91079491217204,
#    80.12827112950747,
#    96.52331854212957,
#    98.68649377370063,
#    100.69006684713193,
#    102.47794692610037,
#    104.81404736085699,
#    121.1350104218237,
#    123.7276670787608,
#    125.23737777955398,
#    128.56284392564584,
#    145.87936896315298,
#    147.55054316333658,
#    149.3630175948921,
#    150.85846972088748,
#    152.42086714706457],
#   'Officer_Station_1_Early_2': [1.4063470779965093,
#    3.6227516590477506,
#    4.844707252080415,
#    7.445539594843169,
#    8.565893500834822,
#    24.69946715559873,
#    25.505046638573088,
#    26.64371967120348,
#    28.442464266004603,
#    30.336618609869806,
#    31.309738567801052,
#    33.27902449032182,
#    48.75201875577969,
#    51.050669414937985,
#    54.236100434756615,
#    56.99316017403788,
#    74.3114083803523,
#    75.64286989910545,
#    77.27251718574733,
#    77.8971086993508,
#    80.22566059328545,
#    97.78591107496128,
#    98.55077879500791,
#    100.70931024028414,
#    102.33841355991697,
#    104.42675064734198,
#    121.29540977918793,
#    122.33775759693519,
#    124.43251142058207,
#    125.79916170439556,
#    127.86233615791065,
#    146.3730669171859,
#    148.84955087540112,
#    149.93327881074438,
#    151.13441680192514],
#   'Officer_Station_1_Early_3': [0.9004078609872136,
#    2.2023353767795713,
#    3.6157362017316452,
#    4.1876917947643095,
#    4.936195566655792,
#    5.790993799686192,
#    7.2931715903864,
#    9.699679156306539,
#    24.68514755438341,
#    27.265454291547204,
#    29.800110992792845,
#    31.30712097037908,
#    33.06220792809702,
#    49.34373666176212,
#    50.62563387020473,
#    53.20215283682421,
#    56.5230206930737,
#    74.48165236563842,
#    75.72076786534507,
#    76.89831458724645,
#    78.50414665684482,
#    80.51529942486407,
#    98.46054013499044,
#    100.79009021690909,
#    102.45568358778714,
#    104.16250725726727,
#    122.55790478165811,
#    123.55901005632238,
#    126.33141140272367,
#    127.86118872618657,
#    146.08634340262014,
#    148.59185219826782,
#    150.99391526251108,
#    153.41301365632978],
#   'Officer_Station_1_Early_4': [1.7637742967006411,
#    3.9099534363425086,
#    5.506812599667156,
#    6.628417231907693,
#    7.147690477133754,
#    9.083074547050318,
#    25.622046574912435,
#    27.932606134936247,
#    29.065845428802337,
#    30.89966040015231,
#    32.2159951053262,
#    48.78785312079235,
#    50.37478623311367,
#    53.05221419777245,
#    53.69268549019209,
#    55.294389086585504,
#    74.38454853713552,
#    76.10464295569203,
#    78.25335120708083,
#    79.99378470720025,
#    98.07636316552,
#    100.55273532078321,
#    102.14437927976823,
#    103.51451903887097,
#    104.16788652093076,
#    121.50537142234474,
#    123.2209847826443,
#    126.47970793194918,
#    146.52241204346373,
#    147.21131030504463,
#    149.31004897363792,
#    150.73992677389816,
#    153.009014617802],
#   'Officer_Station_1_Early_5': [1.212696297893205,
#    3.2543402568782205,
#    5.533596286320284,
#    7.172139597036915,
#    8.087138882743327,
#    26.340552165325242,
#    28.167805340808812,
#    30.62464951024814,
#    31.337015230034282,
#    33.434139948896885,
#    50.21088928910567,
#    51.774688644740685,
#    54.478665436355165,
#    57.306892301182415,
#    73.83380420198071,
#    75.05361196558009,
#    76.39021321714463,
#    77.64160618112716,
#    78.82579282172539,
#    80.53763607581044,
#    98.0666701989406,
#    100.28867753092463,
#    101.05827876679525,
#    103.31785206467855,
#    104.79265869602295,
#    122.24934213316028,
#    123.11822525485013,
#    124.7025689665964,
#    126.84512344440779,
#    146.46256496887847,
#    148.9349770123422,
#    151.45158121232853],
#   'Officer_Station_1_Early_6': [1.058912635470806,
#    3.7042947648035507,
#    4.620519933241564,
#    6.184045339204751,
#    6.978878940019408,
#    7.925750637239696,
#    10.234812306474822,
#    25.682732525903035,
#    27.52320381832268,
#    29.900744738051554,
#    31.687948951060445,
#    33.24907222362246,
#    48.8431486746854,
#    50.2850104218237,
#    51.530028554972304,
#    52.871955593032666,
#    54.95300740444938,
#    55.81573362528404,
#    74.23576099192347,
#    76.20037565355567,
#    77.26499031518786,
#    78.7700883302952,
#    96.7945619563495,
#    97.5201546824049,
#    98.09972550690738,
#    100.14625946410206,
#    102.82391547230333,
#    104.69561409921145,
#    120.67010639398114,
#    123.05394385050668,
#    124.47476530169102,
#    127.29150876455468,
#    147.23634340262015,
#    148.13508207121345,
#    150.57636827058727,
#    152.28724472037234],
#   'Officer_Station_3_Early_0': [0.6745063080065021,
#    1.5160981904783735,
#    3.5478923792711123,
#    4.332733081590951,
#    5.091727070246112,
#    7.55468735293282,
#    8.118140633757085,
#    24.970179126476943,
#    26.869912808023816,
#    28.085775078421367,
#    30.29791704430238,
#    31.078552458538983,
#    31.795854909438876,
#    50.03762745810811,
#    51.46350570324827,
#    54.6745063080065,
#    56.52772803642998,
#    72.95005252013718,
#    74.22308270409425,
#    75.79907842192064,
#    77.5443838403988,
#    78.8341033951587,
#    97.85809213163839,
#    98.9993143587371,
#    100.58191469896776,
#    102.82432134362828,
#    104.55842819370166,
#    121.76428072841857,
#    124.39989337401451,
#    126.91599395339149,
#    147.09903205992163,
#    149.52008774870248,
#    152.24700251245338],
#   'Officer_Station_3_Early_1': [2.571363991386102,
#    4.542682546323166,
#    6.46974838691269,
#    8.458506396359294,
#    26.311269092514117,
#    28.427340814663356,
#    30.382066875850025,
#    32.75036772233492,
#    49.53599243304551,
#    51.497654245696886,
#    52.919996044025254,
#    54.508153292944044,
#    73.2745063080065,
#    75.05633223998946,
#    77.02364797806396,
#    77.65861525542422,
#    79.45037604168448,
#    96.94621859036755,
#    99.54791715666187,
#    101.41343710521217,
#    103.65994730105903,
#    106.10771053703535,
#    120.79542495725754,
#    122.30809213163839,
#    124.866378871282,
#    127.36586227039754,
#    145.63130861670052,
#    147.0524190644752,
#    147.74208617754553,
#    149.91102895493324,
#    151.2285074681727],
#   'Officer_Station_3_Early_2': [1.460460786976214,
#    2.99395557670075,
#    3.9277627152131895,
#    4.676852601236572,
#    6.843446996952155,
#    9.075516168199117,
#    24.956462577016538,
#    27.454225812992842,
#    29.538811904361857,
#    31.219068980120053,
#    32.47553096190736,
#    50.041994423029614,
#    51.81315462381344,
#    54.29794594705327,
#    74.2044191709212,
#    75.08509144370333,
#    76.12928854416839,
#    77.19709931428862,
#    78.30703097688108,
#    98.33030282503174,
#    100.06365015985118,
#    102.39095939977379,
#    104.04884877837947,
#    120.78939181630803,
#    122.440442163462,
#    124.23943486467995,
#    126.17546689436054,
#    147.09416490043662,
#    148.51386889702897,
#    149.40560613286164,
#    150.91226749906022],
#   'Officer_Station_3_Early_3': [0.9046641818735297,
#    1.645703619385217,
#    3.1146650357424024,
#    4.372914219064949,
#    5.163639357155351,
#    6.622407924780113,
#    8.869025366100747,
#    26.026542587770074,
#    27.840325889201253,
#    29.256167891636235,
#    31.447907795934086,
#    33.96527102956472,
#    49.91841619785311,
#    51.16390838079364,
#    54.61175487701156,
#    74.40822271287459,
#    76.3234504611235,
#    78.21875587960166,
#    79.22996610153578,
#    97.02554455769045,
#    99.11516260287934,
#    101.00219674944485,
#    103.4109600890623,
#    104.24284335701233,
#    122.47800955388931,
#    123.27989413744,
#    126.24047548087563,
#    146.99214333506072,
#    149.44918818389908],
#   'Officer_Station_3_Early_4': [1.8921433350607209,
#    3.888858643153638,
#    6.1629988877179605,
#    8.270488951723848,
#    26.103817861943675,
#    26.930973514070786,
#    28.0244757043372,
#    30.29847128997069,
#    31.944605965462028,
#    50.6871784868258,
#    52.254419170921196,
#    54.217262469777666,
#    72.95399712044998,
#    74.76674180197537,
#    75.56015395775049,
#    77.15435105821555,
#    79.04661430292252,
#    96.72221885042913,
#    97.53923101720629,
#    98.9046639916784,
#    100.61187235052132,
#    102.44556431311769,
#    103.77967116319105,
#    105.06138118234517,
#    122.51812387288312,
#    123.56882863183219,
#    128.2184185977565,
#    146.2631808621814,
#    148.10919884731558,
#    149.99805911951964],
#   'Officer_Station_3_Early_5': [2.091988472004357,
#    3.6468442985707648,
#    4.516113721314523,
#    5.806838859404925,
#    8.314546974008865,
#    25.285509362426946,
#    27.26733529440991,
#    28.11542697780046,
#    28.90317202901207,
#    30.18247003371063,
#    32.2718603757249,
#    50.682215677365406,
#    53.281794188792745,
#    55.01908629466615,
#    73.84612419221256,
#    76.0832368614074,
#    78.7695233873724,
#    97.91460998504087,
#    99.42292439607729,
#    101.49846290656254,
#    104.04296568691714,
#    121.76999298063386,
#    122.69352272422812,
#    123.93974131459566,
#    127.21202453709267,
#    147.56016411589306,
#    148.9355692786282,
#    151.02483484681986],
#   'Officer_Station_3_Early_6': [1.8345433872738264,
#    4.2033548577221245,
#    4.949636323709529,
#    6.951997425943336,
#    8.276765690977207,
#    25.733005878093316,
#    27.15488462292819,
#    29.746106850026894,
#    30.416549393059697,
#    32.48806457474076,
#    50.24981442837549,
#    52.652055452170686,
#    54.65876856762476,
#    73.28484070231984,
#    74.75876189705912,
#    77.16188968220551,
#    78.85790686582968,
#    97.91393802418656,
#    98.7918255516048,
#    101.30247677510677,
#    102.01312799860874,
#    104.17303371100694,
#    122.17456924655303,
#    123.21369965305611,
#    124.37662512364403,
#    146.60824918332256,
#    148.33218966090953,
#    149.67291479899993],
#   'Officer_Station_3_Early_7': [2.3655020214269653,
#    3.1115626737325526,
#    5.428091965587214,
#    6.330392813150141,
#    8.623236383810784,
#    24.93179418879274,
#    25.488845001058472,
#    27.17111135350775,
#    29.846731132987443,
#    30.987953360086145,
#    33.51534591871409,
#    51.04410575103423,
#    52.64837069248331,
#    54.28095036216886,
#    74.15162765388804,
#    76.5976456390222,
#    77.73284075201359,
#    80.2887673697426,
#    96.72415071013911,
#    98.19015354479838,
#    98.93508469257351,
#    100.17912165960664,
#    102.19761494273207,
#    102.88585898584034,
#    104.34388088414701,
#    122.45286167506404,
#    123.94358681315444,
#    145.7784309405417,
#    147.69907913752672,
#    148.9277671514566],
#   'Officer_Station_3_Day_0': [9.496907093597864,
#    12.559761806574128,
#    13.169973864991867,
#    14.286593820163686,
#    16.746020155082928,
#    33.48983539164397,
#    35.41026413751577,
#    36.955107696819184,
#    37.970465308613534,
#    39.286401619077374,
#    41.738702466640305,
#    57.00933905844369,
#    60.04428762221504,
#    62.49658846977797,
#    64.09544635822289,
#    82.59126974841244,
#    84.13245237729123,
#    86.80067546470458,
#    88.80954893634244,
#    105.31213077878068,
#    107.17500156302656,
#    109.69522571493593,
#    110.83141107822382,
#    113.2221730145707,
#    129.7329956988201,
#    131.89425204124677,
#    134.4777150658123,
#    135.9201189164981,
#    136.82241976406104,
#    153.33289212815544,
#    155.93253247121902,
#    158.1131814685742,
#    160.13704719605667],
#   'Officer_Station_3_Day_1': [8.788644048254309,
#    11.229322622988402,
#    12.949059872318935,
#    14.170499458890061,
#    16.836559880328622,
#    33.01045019469072,
#    35.77336236109461,
#    36.67330438722651,
#    37.90800902799253,
#    38.815869537461936,
#    40.7106624935598,
#    58.4931941714479,
#    61.09241516097251,
#    62.7117138587601,
#    65.66736323363062,
#    81.54906113062073,
#    83.27414024456432,
#    84.8494364068547,
#    86.19261387029925,
#    87.71868653262938,
#    105.87603663548411,
#    108.40436276523194,
#    110.76399076959,
#    112.4701354184243,
#    128.79689442914747,
#    131.01428072841856,
#    132.84414072518723,
#    134.99589725116962,
#    136.3556091833316,
#    152.7205158153519,
#    155.5004330414098,
#    158.45230084756292,
#    160.71039297920132],
#   'Officer_Station_3_Day_2': [9.711104350717134,
#    11.877422080389207,
#    14.2327525414752,
#    15.555597222575031,
#    33.895020715704696,
#    36.364739503182825,
#    38.70784949222617,
#    40.18443003965927,
#    58.396698575282066,
#    60.91457501837751,
#    63.40230084756293,
#    81.9407251380904,
#    84.17780146551496,
#    86.08307140495707,
#    87.54682719637924,
#    89.30426106055768,
#    105.75169856629431,
#    107.75810812556166,
#    108.79722344829915,
#    110.44219731537852,
#    112.61221863481572,
#    129.16840372610503,
#    130.73617096099082,
#    133.3150582460697,
#    134.2983155483026,
#    136.76854842937007,
#    152.67354018383347,
#    155.11102027646945,
#    158.3837630433812,
#    159.49824835060213,
#    161.25610886007152],
#   'Officer_Station_3_Day_3': [8.792548103936198,
#    9.769585057985267,
#    10.878642910317327,
#    13.767395421872928,
#    14.894770135913086,
#    34.42788755708148,
#    35.26974718218756,
#    37.58140899483894,
#    39.663782158680476,
#    41.221890284242136,
#    57.468412505283446,
#    59.86339419297177,
#    62.40412436344312,
#    64.05032832527587,
#    81.5179182954189,
#    83.7476532265834,
#    86.61096626291486,
#    88.8718576501299,
#    105.8907251380904,
#    106.96237850957763,
#    108.31782669627837,
#    109.05695710278145,
#    109.87576857322975,
#    111.02183911052138,
#    112.90053080207966,
#    129.3393001016746,
#    131.0248927163463,
#    134.35441917092118,
#    136.156603251975,
#    153.41818793172797,
#    155.04167843283054,
#    158.15575188370548,
#    160.78536542450337],
#   'Officer_Station_3_Day_4': [9.568123872883122,
#    12.22539932491383,
#    13.184897940733878,
#    14.803852001482419,
#    34.369737249330534,
#    35.45600416338828,
#    36.37906211514449,
#    37.66035619222536,
#    40.03459705325688,
#    57.34549218294053,
#    59.234796908468255,
#    60.498130685604586,
#    62.65637986892713,
#    64.94928992265778,
#    82.16896141635718,
#    84.98663031487105,
#    86.90988264868024,
#    88.80191186792014,
#    105.93691900912792,
#    107.76102027646944,
#    108.92850630438339,
#    110.49032535292822,
#    112.19214333506072,
#    129.90667568705175,
#    132.4626446401973,
#    134.10478797525803,
#    135.65132868834843,
#    138.1864712106189,
#    152.9405476818088,
#    154.45834840038393,
#    157.30451607241116,
#    158.01237658188057,
#    159.6350934282847,
#    161.24619777900185],
#   'Officer_Station_3_Day_5': [9.243644797352964,
#    10.417506315724985,
#    11.22380517119844,
#    12.059269604898212,
#    14.109269604898213,
#    32.91479399203058,
#    34.405655969641494,
#    35.92377984252462,
#    37.52202072028073,
#    39.06282133282099,
#    40.7059817649051,
#    58.12192223960178,
#    59.54731870419434,
#    60.59961001368689,
#    62.29654667449982,
#    63.07918333805565,
#    65.2332017030395,
#    82.16365920381827,
#    85.10893516112496,
#    86.12719159147962,
#    87.8119722689445,
#    105.6407251380904,
#    108.20516191309878,
#    109.63680690771301,
#    111.18260610309426,
#    113.00186211666724,
#    130.01222194763182,
#    132.1289130641915,
#    133.46443986791542,
#    134.96374147729514,
#    136.98578445506288,
#    152.9251265136694,
#    154.41296028268673,
#    157.549171081944,
#    159.30307203633492,
#    161.13695476123397],
#   'Officer_Station_3_Day_6': [9.927422080389208,
#    12.022053700424848,
#    14.079299611565594,
#    33.91322715686491,
#    35.85988264868025,
#    37.691222227098706,
#    38.872480895607595,
#    40.86366029338256,
#    58.33605873970795,
#    60.22048300898224,
#    60.91868923261054,
#    62.87903354993353,
#    65.49557790256199,
#    80.85993166259246,
#    83.40160276419596,
#    84.56354225308674,
#    86.05441917092121,
#    88.57926824931175,
#    106.00635020040889,
#    106.82134413686589,
#    108.70230084756292,
#    109.66443166121644,
#    112.64917186003915,
#    130.4516393421719,
#    133.53983066908128,
#    134.99853434706418,
#    136.73425813756342,
#    153.48762266778962,
#    155.68116410933612,
#    157.64459026941338,
#    159.42374739687364,
#    160.12170706334874],
#   'Officer_Station_3_Day_7': [9.708968767725521,
#    12.021895742375445,
#    13.529756251844855,
#    14.439476195686202,
#    34.09680181992855,
#    36.366886227374145,
#    38.20984540216871,
#    40.379529038797465,
#    58.045492182940535,
#    59.652026448624774,
#    61.340725138090406,
#    63.24886223308306,
#    82.88342029052518,
#    83.88680346028022,
#    85.6983042143356,
#    88.45014741389377,
#    104.99240385068579,
#    106.46373497056366,
#    109.73738404568495,
#    111.86925601357298,
#    128.74796513592347,
#    130.36841859775652,
#    132.58717648865948,
#    134.14540697222358,
#    135.1268244400173,
#    136.10744174210637,
#    154.01315857715764,
#    157.4217248060997,
#    158.18971013477176,
#    159.44927743815123,
#    161.53495125553104],
#   'Officer_Station_3_Day_8': [9.40786050946941,
#    10.468087797519487,
#    11.981832436725089,
#    12.576294471871341,
#    14.3350630394961,
#    32.99777145768438,
#    34.62554455769044,
#    36.56057192515658,
#    37.96045166900363,
#    40.202043551475505,
#    58.43425895885285,
#    60.52036207335989,
#    61.91022888539246,
#    64.54529829287283,
#    82.32142383692712,
#    84.6483042143356,
#    86.74965430155117,
#    88.77528032314183,
#    106.31345328082426,
#    109.68406985723213,
#    111.25342827267579,
#    113.75725270725968,
#    130.7338456803069,
#    133.406187498978,
#    135.8748067711854,
#    137.7548680320932,
#    152.76379214908678,
#    155.24964344335973,
#    158.13960795869784,
#    160.6726307061562],
#   'Officer_Station_3_Day_9': [9.945518973383388,
#    12.365632113021459,
#    13.667330679315777,
#    14.80178408350823,
#    34.575772151022974,
#    35.799059583537655,
#    38.64722344829916,
#    41.33142703113777,
#    59.455456906547056,
#    60.58531690331573,
#    62.540790119966644,
#    64.94351526959541,
#    82.61238120201783,
#    84.53872822697922,
#    85.69182073514179,
#    87.26545797629252,
#    89.57422654391729,
#    105.8462025192968,
#    108.39837567470933,
#    110.65825832338956,
#    112.79072513809041,
#    130.40450283934788,
#    133.3125954157951,
#    135.9324915681276,
#    137.12718767622246,
#    154.7388974314099,
#    156.87138222394412,
#    158.39739418467718,
#    159.21030441367253,
#    161.6614758493871],
#   'Officer_Station_3_Day_10': [10.723192815270144,
#    11.680246601645152,
#    14.061449619503335,
#    15.926339461210986,
#    34.51673300236457,
#    36.79789807430075,
#    39.100572185096574,
#    41.50619438148187,
#    58.36849328312544,
#    59.742415160972506,
#    60.88129407708087,
#    61.76652145864908,
#    64.36601744990405,
#    83.18711266919485,
#    85.32252777843861,
#    85.88817636063615,
#    86.90675483191154,
#    89.1544191709212,
#    105.7407251380904,
#    108.37411077536647,
#    110.28638170039132,
#    112.42457833730869,
#    130.06937335030997,
#    132.03289212815542,
#    134.31832215752877,
#    136.12487830194667,
#    155.23289212815544,
#    157.59438974869,
#    159.43935012422133,
#    161.2869627862476],
#   'Officer_Station_3_Day_11': [9.502861675064041,
#    10.714609985040873,
#    13.364899729111952,
#    14.124398344931999,
#    35.036076663843,
#    36.14458724275121,
#    37.91059007741046,
#    39.62983873702857,
#    41.50676000590092,
#    58.69613024192034,
#    61.286726712264105,
#    63.655861056024456,
#    82.76785574851141,
#    84.23714098249114,
#    85.36535602865453,
#    86.81002449332308,
#    89.59751472856088,
#    106.36578397039355,
#    108.76208742619404,
#    110.42473378860093,
#    113.07330438722651,
#    130.68121865704515,
#    132.08100876861783,
#    133.85433300894195,
#    136.2657119923706,
#    153.86789669855239,
#    155.2312586685089,
#    157.3313011459475,
#    158.98033320586913,
#    160.87960501725055],
#   'Officer_Station_3_Day_12': [10.806029940524454,
#    12.532681400115704,
#    13.786864895380909,
#    16.352075560320053,
#    35.2808651677579,
#    36.1470564877032,
#    37.81821059431782,
#    38.3806456962777,
#    39.67453474506079,
#    41.579473829943986,
#    58.17630755736235,
#    60.86267123297897,
#    61.954526365700644,
#    62.83482404348984,
#    64.38821779295347,
#    84.13318490024761,
#    86.64993705708478,
#    87.92374471426487,
#    104.93819862250442,
#    105.71027248572713,
#    108.4222009969004,
#    111.18388272489902,
#    113.4056362589895,
#    130.9913356233866,
#    131.92172211324186,
#    132.93842450026546,
#    134.26300825786464,
#    136.14201343903525,
#    154.54619620214348,
#    156.4278858402584,
#    158.34625243818465,
#    160.0930580242662],
#   'Officer_Station_3_Day_13': [11.63365085176186,
#    12.416542979917288,
#    14.79078384094881,
#    34.07553851048524,
#    36.34562291793083,
#    37.31898527902545,
#    39.76087121039128,
#    41.14526151902817,
#    58.52207466687372,
#    59.72846672263261,
#    60.83260877171629,
#    63.601070052761735,
#    84.2009336182513,
#    86.3864207277674,
#    88.41681623215297,
#    104.55989507910553,
#    106.57232616531702,
#    109.15726040337881,
#    112.54441887555222,
#    130.9869959266537,
#    132.67158950223683,
#    135.20051036025205,
#    136.00634969093912,
#    155.62069234214655,
#    157.61808854352515,
#    159.38296221035765,
#    161.64834343813038],
#   'Officer_Station_3_Day_14': [9.765034749971537,
#    11.710164115893072,
#    13.37026374828951,
#    15.098730470922119,
#    35.01313548937863,
#    36.78727573394295,
#    38.950582270298305,
#    40.27236332569873,
#    58.14549218294053,
#    59.707133460515436,
#    60.954524563417195,
#    63.58521619193017,
#    83.82760948380387,
#    85.68688088105728,
#    88.04621859036756,
#    105.03378805817238,
#    106.90120260206277,
#    109.31242036682899,
#    112.63502368791116,
#    131.10436276523194,
#    134.52553851048523,
#    136.4004198039752,
#    155.5348152945733,
#    156.95698786538736,
#    158.86230454333122,
#    160.19260736836293],
#   'Officer_Station_3_Day_15': [11.17300034603511,
#    13.674349368687267,
#    15.408195048994173,
#    35.25286167506404,
#    37.627593470712675,
#    39.55964525777125,
#    40.88761557375175,
#    58.33572793409638,
#    61.57626090418628,
#    62.97968832458684,
#    64.00989507910553,
#    84.31557283914502,
#    86.29587566417675,
#    87.90230084756293,
#    106.47416563712865,
#    109.16624053790825,
#    111.92091767032076,
#    129.80172432741892,
#    132.19734933161752,
#    132.85545745717917,
#    133.76155389633325,
#    136.31564858219753,
#    155.8183497987384,
#    156.63289212815545,
#    157.58075389419497,
#    158.92750071811253,
#    161.19934783738853],
#   'Officer_Station_3_Day_16': [10.170422138048322,
#    11.27853026360998,
#    13.32808545208525,
#    14.27083830056511,
#    35.4233055021642,
#    36.4215117257925,
#    38.184011972100365,
#    40.417576188691676,
#    59.40810812556166,
#    60.52144190269799,
#    61.5898581005511,
#    63.022475640591324,
#    65.21017350688474,
#    83.45608640450092,
#    84.3484902551867,
#    86.26967393174712,
#    89.4957012348896,
#    106.16917274227649,
#    108.55489783789255,
#    110.91399076959,
#    111.81437099757778,
#    129.73852208951516,
#    132.58817124101398,
#    133.42835998778915,
#    134.3900446337382,
#    134.9899105291894,
#    137.1840567008978,
#    156.34374765715785,
#    157.87266813268863,
#    159.53052864215803,
#    160.48494781307923],
#   'Officer_Station_3_Day_17': [11.230302825031734,
#    12.734686333899251,
#    14.612765011652627,
#    34.673035919278206,
#    35.60806328674435,
#    36.960814434361545,
#    38.826816799833246,
#    41.419660370493894,
#    58.55079626576181,
#    61.022545835990556,
#    61.74691794552924,
#    63.20358237103398,
#    84.4637921490868,
#    86.35162780334343,
#    88.18789454955933,
#    106.10301666183825,
#    108.51126243252314,
#    111.4824903844283,
#    131.0684687074177,
#    132.69241161914107,
#    135.6594143518419,
#    136.641740228829,
#    155.93872822489627,
#    157.14681415915632,
#    158.11246274135385,
#    160.3627723404928],
#   'Officer_Station_3_Day_18': [9.712673691779935,
#    11.444168967141225,
#    12.378014647448131,
#    14.17771711076899,
#    35.140512779165256,
#    35.99882719020168,
#    37.75786050946941,
#    38.43571222738301,
#    40.912628679621946,
#    58.87458088133094,
#    59.62017912647694,
#    62.26532246814448,
#    64.56680627082174,
#    82.77416905556153,
#    83.66967393174711,
#    85.63144067615977,
#    88.4514824958293,
#    105.96396598932846,
#    108.00848744778177,
#    109.0050796329832,
#    109.73649071120703,
#    112.03068961232951,
#    132.4858816760667,
#    133.44087231434443,
#    135.56642302872933,
#    137.97153490522552,
#    157.5812586685089,
#    159.96771639461244,
#    161.84912747283627],
#   'Officer_Station_3_Day_19': [10.457047867014014,
#    12.543875069536975,
#    14.732947762487685,
#    35.40876856762476,
#    36.97070805651555,
#    39.42866751953542,
#    40.51155964769085,
#    60.781900914210006,
#    63.576171555211225,
#    82.71999119380243,
#    85.0137921490868,
#    87.67587957528085,
#    104.9573835824059,
#    105.72188281162111,
#    107.41614596311997,
#    109.6726034903048,
#    110.71238439856451,
#    112.3602116445704,
#    130.90856921684093,
#    131.77744751491556,
#    133.90317660831738,
#    136.50577513522552,
#    156.8220746668737,
#    157.81366654934558,
#    159.92816612239525,
#    161.91681626152084],
#   'Officer_Station_3_Day_20': [11.196554558146833,
#    13.034986368448882,
#    14.441092748683209,
#    35.01415409157706,
#    36.974036740257304,
#    38.76760398027132,
#    41.39280445595342,
#    59.067395421872924,
#    60.893307323468775,
#    62.21924865961811,
#    63.914858380791095,
#    83.35435296420872,
#    85.76669074783142,
#    87.94570123488958,
#    104.58094154177597,
#    107.36079583412628,
#    110.48569514104308,
#    111.96021164457039,
#    132.0311650719362,
#    132.7218902100266,
#    135.59903205992163,
#    137.69734120369512,
#    156.4629602826867,
#    158.57594712468082,
#    160.41696866790136],
#   'Officer_Station_3_Day_21': [9.982892128155429,
#    10.843924074412678,
#    12.697555386493844,
#    14.11860260264034,
#    35.223362361094615,
#    35.90744824200225,
#    38.17439786267776,
#    39.396067061210076,
#    40.231766546307114,
#    60.64397658383578,
#    62.45205316450182,
#    64.85842295633121,
#    84.19520215093402,
#    85.59962132185522,
#    87.55248299691927,
#    89.71264073531178,
#    106.16577966548006,
#    108.05471517765524,
#    109.08903057586947,
#    110.58952175830876,
#    113.07002182135281,
#    131.0046515777846,
#    132.80393004655062,
#    134.36058733759393,
#    135.9143029430019,
#    137.54328915553734,
#    157.37554541724506,
#    158.96068536595976,
#    159.63165118112707,
#    161.57237631921748],
#   'Officer_Station_3_Day_22': [9.617727427327544,
#    12.288318523270554,
#    13.296179032739964,
#    13.933026097440765,
#    16.320778817040882,
#    34.75950394500659,
#    35.811804792569525,
#    38.22095359104966,
#    40.53702503954963,
#    60.03983066908127,
#    61.296590712576126,
#    63.70469883813779,
#    84.11188993935201,
#    85.68250668501722,
#    88.3897195547599,
#    106.30544887372562,
#    109.3883848964712,
#    111.18355146805145,
#    112.24958676585213,
#    130.76378850744808,
#    132.61487565404485,
#    135.0097125176981,
#    137.45343311834776,
#    157.26253374145247,
#    159.92039425092187,
#    160.52075147180057],
#   'Officer_Station_3_Day_23': [9.569864588752463,
#    12.165519948550298,
#    14.900773021640681,
#    34.74044216346199,
#    37.10353794252706,
#    39.66139845199647,
#    40.97788339482724,
#    60.38939181630803,
#    61.51854894376828,
#    63.91538122777275,
#    85.48191674441176,
#    86.62534598885182,
#    87.9718576501299,
#    106.70487390275592,
#    109.51845743033871,
#    111.51947516424349,
#    130.8802570757582,
#    133.1237447142649,
#    135.04341864601201,
#    137.27865426702806,
#    158.3788891523241,
#    159.75026053848322,
#    161.7076441208891],
#   'Officer_Station_3_Day_24': [10.62960610827343,
#    12.85786050946941,
#    15.032073149126587,
#    34.779977950808345,
#    36.04633001275655,
#    38.17558427424061,
#    40.41026317515799,
#    58.85971994384135,
#    60.10850972841243,
#    61.4977582807802,
#    63.11457011373043,
#    65.40831740840687,
#    85.67879055015702,
#    88.08971955475991,
#    106.30286167506404,
#    108.83144467178215,
#    109.88289212815543,
#    111.95314802668341,
#    132.2184185977565,
#    133.23325742235815,
#    135.31649037238932,
#    137.47189330202963,
#    157.16483882460165,
#    159.3746626636351,
#    161.10755479179053],
#   'Officer_Station_2_Night_0': [18.143505293477652,
#    21.11075920189056,
#    22.617471092200656,
#    25.149393708254493,
#    41.60652799561756,
#    43.03552494752775,
#    45.55331630373066,
#    47.128470262446214,
#    66.2090880049425,
#    68.36732397363522,
#    70.7367655923768,
#    72.95961900341354,
#    89.22995331677642,
#    91.50732636315013,
#    93.86215837108742,
#    95.62815492849981,
#    113.14643833013068,
#    116.59448046455795,
#    118.2083864221898,
#    119.34386610511177,
#    138.40347103706367,
#    139.88237843129625,
#    142.09682863269572,
#    144.51539337626227,
#    162.47350893875517,
#    163.9551377426502,
#    165.51576353868995,
#    166.90387609280637,
#    168.4744261250065],
#   'Officer_Station_2_Night_1': [17.01039003324964,
#    20.502725260355817,
#    22.70867868482792,
#    25.212410222151785,
#    41.4062845212055,
#    42.55105813624577,
#    45.462010062812695,
#    47.55337749723619,
#    65.3523533788169,
#    67.3671388604317,
#    69.79580956375538,
#    71.75494976734029,
#    89.10258157634718,
#    90.90517682622074,
#    91.6253890776234,
#    92.86622827350848,
#    94.40250387035512,
#    96.25935411206171,
#    114.22964577812549,
#    117.6734345457413,
#    118.94493973541549,
#    120.44133512919797,
#    137.641780538605,
#    139.32687860271707,
#    140.53218729570708,
#    142.2922276306431,
#    144.73650500931276,
#    160.8690224468052,
#    162.5252674668223,
#    164.51115498278932,
#    166.4,
#    168.5120100628127],
#   'Officer_Station_2_Night_2': [17.028367127220683,
#    18.704930629685705,
#    21.384474168430152,
#    23.613115922620665,
#    25.65860611450452,
#    41.21526084614946,
#    42.78908935773673,
#    43.87354899787718,
#    46.31239971858488,
#    49.076065639655255,
#    65.9879610412646,
#    67.30589509202564,
#    70.34696014099376,
#    73.52662238470438,
#    89.04925837385694,
#    92.19510475864756,
#    93.27593336736933,
#    96.13484368767091,
#    112.93889589937962,
#    115.14631934960663,
#    117.21107007928924,
#    119.59096472114256,
#    137.7592337697819,
#    140.4150428018957,
#    142.1696092367191,
#    145.17600964996615,
#    161.11287524096534,
#    163.47300682839392,
#    165.02330717905994,
#    168.47791217427144],
#   'Officer_Station_2_Night_3': [17.65834782796171,
#    20.127382241539728,
#    22.053220979964138,
#    24.56134225072412,
#    42.09960017005127,
#    43.77923039104447,
#    45.38378958854398,
#    47.57067243326441,
#    65.4730820838555,
#    68.03763416704751,
#    69.59910752631903,
#    70.75770857785773,
#    71.90465522433237,
#    90.2601315874286,
#    91.56447227743115,
#    93.35867660341482,
#    95.25996213485246,
#    113.42525865412516,
#    115.6946400507238,
#    117.14968963791605,
#    118.19931199487341,
#    120.7181952558239,
#    137.00849638639218,
#    139.32012603524814,
#    139.93063330534392,
#    141.270144687977,
#    143.11542266569418,
#    161.6315092244591,
#    162.7370261865229,
#    165.09017869395146,
#    167.4470520260467],
#   'Officer_Station_2_Night_4': [18.25926818825457,
#    20.115407350683768,
#    22.86023364114532,
#    24.349590194485398,
#    41.79868655268183,
#    44.166921991144385,
#    46.11950356749156,
#    48.58239040067988,
#    65.23190297477015,
#    67.77729504519418,
#    68.7481104870696,
#    71.08962214758327,
#    89.64643833013068,
#    91.98466050186163,
#    93.52967523404875,
#    94.62362401745219,
#    96.80970931597557,
#    114.5101315874286,
#    117.58484736417772,
#    118.93563153497026,
#    121.73331329991937,
#    138.20849638639217,
#    139.78563153497026,
#    141.6654226656942,
#    142.77131963708916,
#    144.62928380772587,
#    161.21391735419763,
#    162.58931777929064,
#    165.23948620635247,
#    167.00470397939264],
#   'Officer_Station_2_Night_5': [17.692753501145663,
#    19.324461601956685,
#    20.84442811309068,
#    22.001643974281723,
#    24.35700076542604,
#    41.58494742453695,
#    42.51687004059079,
#    45.38088036210768,
#    47.19622307655425,
#    65.30450451698263,
#    66.86888511436185,
#    68.55265162593123,
#    71.40235337881691,
#    88.78134412569257,
#    90.47323689258134,
#    92.26869994189275,
#    92.96869994189275,
#    94.00214754508092,
#    95.35539369583907,
#    113.2459258543724,
#    115.0770656158777,
#    117.05773552275643,
#    118.94029828923061,
#    120.41355873132103,
#    137.34481664648504,
#    139.60606966799853,
#    142.4654226656942,
#    144.5101315874286,
#    162.5950107513503,
#    163.99783766175716,
#    166.1651586594534,
#    168.49215061227176],
#   'Officer_Station_2_Night_6': [19.37950997349142,
#    21.853073050945444,
#    24.29220635467088,
#    40.978186125372225,
#    42.97388070952217,
#    44.12705794513015,
#    46.569092777403256,
#    47.63192261605384,
#    66.28949853811895,
#    69.07748900370449,
#    71.22011087434619,
#    90.52291867327548,
#    91.38936031981599,
#    92.25098996867195,
#    93.74195703747424,
#    96.26239016191265,
#    113.96892545874027,
#    116.28934249145273,
#    118.7475274673661,
#    120.28126615615005,
#    137.96506473633315,
#    140.60191188825033,
#    141.76709214190288,
#    143.30734029849646,
#    160.6829816593284,
#    162.7512707991545,
#    164.14529025512627,
#    164.78591922159353,
#    166.14396966153186,
#    168.67748175838972],
#   'Officer_Station_2_Night_7': [18.569693014778647,
#    21.99855211576864,
#    22.756578420253902,
#    24.551184547024043,
#    42.52199609624652,
#    45.57323689258134,
#    46.93949853811894,
#    48.33028523080624,
#    66.51406385750312,
#    68.55452865471909,
#    71.54312114768689,
#    89.942241805128,
#    90.68029918592308,
#    93.15699481958285,
#    95.43228761722558,
#    113.80878709254605,
#    116.42707187718037,
#    118.06648490875361,
#    119.85023844848783,
#    136.6592337697819,
#    139.24845651832305,
#    140.71701664616631,
#    143.09719227729687,
#    162.27666880147186,
#    163.46272481069468,
#    165.1946474267485,
#    167.77738423772036],
#   'Officer_Station_2_Night_8': [19.085629865989826,
#    21.07350519523917,
#    22.641935354445156,
#    24.05726473270384,
#    42.270683464777775,
#    44.731065014385806,
#    46.707009286829816,
#    49.472851250484474,
#    64.73578916640884,
#    67.55747150968293,
#    70.54183912524803,
#    72.47045541114252,
#    90.37868659880594,
#    92.52020671918524,
#    95.50394023187808,
#    114.7439764427957,
#    116.75689325455247,
#    117.91924017523533,
#    120.76593513268206,
#    136.60900742152072,
#    138.04560953248193,
#    140.6856654596319,
#    142.0154226656942,
#    145.3343423124591,
#    161.4598218703413,
#    163.00977073738886,
#    165.2209257201782,
#    167.82375299584393],
#   'Officer_Station_2_Night_9': [18.788464110249997,
#    20.972695311002752,
#    23.160544798124914,
#    23.91755408495473,
#    41.31584227129425,
#    43.214176066279556,
#    44.42686532585585,
#    46.79209239360814,
#    47.665341991354616,
#    66.46781769125997,
#    69.31943924172718,
#    72.11335357611043,
#    90.09529025512627,
#    91.13175425775002,
#    93.18130676667566,
#    95.31890998882855,
#    113.80287633946526,
#    116.2437572825177,
#    118.34034350910424,
#    121.02323689258134,
#    137.63860662166314,
#    139.6483337949853,
#    142.59236615222105,
#    144.18715750598716,
#    161.64412897207387,
#    164.14791877346195,
#    165.8885477399292,
#    167.37026229754454],
#   'Officer_Station_2_Night_10': [19.224509758156053,
#    22.55714217644852,
#    25.152569763540157,
#    41.2900370516563,
#    43.797620860478155,
#    45.21890998882856,
#    47.46426470580188,
#    65.7617555515706,
#    67.24548884867652,
#    70.63150612114954,
#    71.96162964885596,
#    90.45412843830788,
#    91.32147237622165,
#    92.66416728615548,
#    95.50250387035511,
#    114.1545286547191,
#    115.77181504398284,
#    116.8400370516563,
#    119.33801822924855,
#    137.2308190421009,
#    139.91911281980467,
#    142.122856697648,
#    143.67022761456752,
#    161.02172561335985,
#    162.87834288076243,
#    165.57442612500648,
#    167.9505691251312],
#   'Officer_Station_3_Night_0': [18.347945947053272,
#    22.373829557720285,
#    24.872843217572882,
#    41.49230945478888,
#    43.568481010000106,
#    44.709620213261914,
#    45.970060812901394,
#    47.10169856629432,
#    65.62333439305645,
#    68.41225220931965,
#    69.74022714495585,
#    70.71345196423069,
#    72.263637349314,
#    88.62154709115258,
#    91.08740640971749,
#    91.80714365904802,
#    93.22436944141153,
#    96.01645640091466,
#    114.54151348465061,
#    115.71145831838709,
#    117.94111503950366,
#    118.96645640091467,
#    121.58686911700791,
#    138.62414024456433,
#    141.38116507193618,
#    144.31501700535281,
#    162.5674562595063,
#    164.51944753977637,
#    166.01473950318282,
#    168.96739597636437],
#   'Officer_Station_3_Night_1': [18.960922716916766,
#    20.768565947671274,
#    23.04004627369885,
#    23.716600963077777,
#    25.55516398022936,
#    42.24208741185403,
#    44.32713248877151,
#    46.16770812140268,
#    47.69660377964375,
#    64.76812387288312,
#    66.28186324989933,
#    68.67970029582689,
#    71.04560403536784,
#    91.27626058043738,
#    92.59001637185955,
#    94.75169856629431,
#    96.4245063080065,
#    114.75571165123702,
#    116.55825899713336,
#    119.59501484676676,
#    137.87853082412335,
#    140.4647395031828,
#    142.64986506513324,
#    144.95989304341796,
#    161.0986307659224,
#    162.43725951953104,
#    163.81114109033268,
#    164.89463178976047,
#    167.55175845279058],
#   'Officer_Station_3_Night_2': [18.712293759371335,
#    21.607096915698897,
#    22.868221843400633,
#    24.384875705513476,
#    41.723425237071936,
#    43.067078441376175,
#    44.93730259328554,
#    46.79416490043663,
#    49.17190371021277,
#    65.61532690560851,
#    67.21829605816774,
#    69.60169856629432,
#    72.32626090418627,
#    90.79199442302962,
#    92.07505075198742,
#    92.74916020939988,
#    94.54264655701333,
#    96.23095036216885,
#    114.6907251380904,
#    116.95437325269809,
#    118.93432161822123,
#    121.22785812255745,
#    138.50208609124417,
#    140.10159622502553,
#    141.94985001250618,
#    142.7080921316384,
#    143.86849328312545,
#    160.89397658383578,
#    161.6511457008594,
#    163.61849328312545,
#    166.4147395031828,
#    167.67554172749064],
#   'Officer_Station_3_Night_3': [22.017535289670878,
#    23.838124045491735,
#    26.174698843825542,
#    40.76365152419932,
#    42.31029449070553,
#    44.76695036040595,
#    47.44221635049476,
#    66.34495923617413,
#    68.51017502807123,
#    71.34504791693554,
#    91.08055892682495,
#    91.85263359369868,
#    93.4709614986001,
#    95.96921237902367,
#    115.08649894061462,
#    116.61791001883844,
#    119.16962524223786,
#    121.55378257733139,
#    137.5749154582924,
#    139.80729102738817,
#    141.0653459187141,
#    142.80763978623582,
#    145.4147395031828,
#    161.48530304710388,
#    163.30379633022935,
#    164.98981776803913,
#    167.44755057514175],
#   'Officer_Station_3_Night_4': [20.710492819676773,
#    21.925772151022976,
#    23.508778029116293,
#    24.299220192578286,
#    42.19571955522238,
#    44.05008232045432,
#    45.205205619885206,
#    46.82508220995351,
#    49.2718576501299,
#    64.82554278891949,
#    66.20233770392582,
#    68.82390727347503,
#    70.88030282503173,
#    72.26138979750641,
#    90.58600610068582,
#    92.73738404568495,
#    95.1368648877291,
#    96.77441675335913,
#    114.43019377090407,
#    116.20169856629431,
#    117.9184364656727,
#    119.20812743601405,
#    121.21345789710004,
#    136.87084283277983,
#    138.84374115542414,
#    140.00818176374997,
#    141.4964729866122,
#    142.95763978623583,
#    144.5824376601832,
#    160.6837654306125,
#    163.12483484681985,
#    165.5402160745926,
#    167.62207466687371],
#   'Officer_Station_3_Night_5': [21.222998118421014,
#    23.340010285198172,
#    24.945204871786892,
#    42.19079196027078,
#    43.86789905476955,
#    46.605618074549305,
#    48.6329564094634,
#    64.7805809946441,
#    66.68604038051446,
#    69.16318086218138,
#    71.02052306679902,
#    90.4252004756821,
#    92.43742242331392,
#    94.02152502447017,
#    94.97594419539136,
#    97.46370345480051,
#    114.02505075198742,
#    115.90163934217188,
#    118.20559118701297,
#    119.34042816126521,
#    136.99871384374705,
#    137.80670851351556,
#    138.88707201474568,
#    140.2407251380904,
#    143.34198847200435,
#    162.2304753197301,
#    164.64618858479074,
#    166.5474713466394,
#    169.3324376601832],
#   'Officer_Station_3_Night_6': [20.990038935946043,
#    22.21072421640238,
#    24.06516336182533,
#    41.240725138090404,
#    42.41279980496412,
#    44.184333366344745,
#    44.903657557371936,
#    47.20461850894121,
#    64.85151144997468,
#    67.09881768788657,
#    70.2233043872265,
#    72.89262991461483,
#    90.85795588452817,
#    93.14736712144158,
#    95.06382253625499,
#    96.36995345110509,
#    115.42023288106746,
#    118.2623365885475,
#    119.84413077734024,
#    137.28712231868738,
#    139.95327393182896,
#    142.3050881650845,
#    144.13565630596267,
#    162.12221584249136,
#    164.1482690148213,
#    164.96190636413527,
#    166.29308371752455,
#    169.47081226147338],
#   'Officer_Station_3_Night_7': [20.842786278934508,
#    22.759929487094258,
#    23.888646028138123,
#    25.612786272702447,
#    41.65542030440006,
#    44.41967450200581,
#    45.654419170921194,
#    46.726542587770076,
#    48.48817226555117,
#    66.06959336071462,
#    67.71296028268671,
#    68.8138181466096,
#    70.42302668773925,
#    72.9263244101446,
#    90.35169856629432,
#    91.34391491678907,
#    92.22687132625246,
#    94.21936024921926,
#    94.94878834956647,
#    96.00475221331162,
#    115.11202453709268,
#    115.97294725400944,
#    117.86814995627545,
#    120.27181543042919,
#    136.8842136592827,
#    139.01422411298097,
#    140.7833584567413,
#    142.46490792247494,
#    160.7196884470731,
#    162.98352974444566,
#    165.60027438820788,
#    167.13364616126023],
#   'Officer_Station_3_Night_8': [21.33537015846124,
#    23.9023823252384,
#    24.76226497391864,
#    41.36913434376035,
#    42.612635787940974,
#    44.842143335060726,
#    46.49605231139408,
#    47.99058872567364,
#    66.0155488366529,
#    68.85858983487088,
#    70.07302668773926,
#    72.51888891250886,
#    90.68826091401947,
#    93.36328450950457,
#    94.89496733356125,
#    96.13124775996981,
#    114.03686632351949,
#    115.78274870863123,
#    118.4544191709212,
#    119.97111671483808,
#    137.28882488158587,
#    139.46106098360238,
#    142.4765882174725,
#    162.31451511221286,
#    164.1057373393116,
#    164.7684081578238,
#    165.88986681203258,
#    167.30286167506407],
#   'Officer_Station_3_Night_9': [22.525086973035254,
#    24.29118760002992,
#    41.10477439936005,
#    42.877082611278865,
#    44.93049619740024,
#    46.78513994871472,
#    48.70286167506404,
#    66.06201271865628,
#    68.28712231868741,
#    70.75824918332255,
#    89.7842090696944,
#    92.50189903683551,
#    94.20573675116461,
#    95.67625991735406,
#    113.9123377836227,
#    115.51991362167178,
#    116.79621859036756,
#    117.61733367781828,
#    120.53347321821383,
#    137.50267224326478,
#    138.09426412573666,
#    141.63946221519882,
#    143.2576397862358,
#    161.93986681203256,
#    164.1912222270987,
#    165.26305088676295,
#    168.05286167506407],
#   'Officer_Station_3_Night_10': [23.03954599359778,
#    24.088259837344825,
#    42.29674154727117,
#    44.46750074692015,
#    47.05663720982282,
#    67.25029618374279,
#    69.13729781756552,
#    71.73086516775791,
#    90.07424086103153,
#    91.51304191116718,
#    93.37181032641098,
#    95.0950207946659,
#    97.04788246972994,
#    115.51097772137359,
#    117.9811473484917,
#    119.2172047898719,
#    137.75139184466408,
#    139.1177737698705,
#    140.2302088718304,
#    141.8136407523556,
#    143.50230084756294,
#    161.88297736974485,
#    162.92392119473928,
#    163.75441917092118,
#    166.40890331566314,
#    169.062141965881],
#   'Officer_Station_3_Night_11': [23.18928065454814,
#    25.052081843685862,
#    42.168366597926244,
#    43.34888317770037,
#    44.364819488164215,
#    46.399808169367354,
#    67.340442163462,
#    69.93046912770679,
#    72.07333439305646,
#    90.22335436146533,
#    91.14533894593966,
#    92.54681983933064,
#    95.43443873575853,
#    115.38549804311916,
#    117.73055892682495,
#    120.05436276523194,
#    137.87982924300346,
#    139.26571679483897,
#    140.32448536246372,
#    143.5090801891435,
#    162.4743721095387,
#    164.34060355688803,
#    165.16551901518042,
#    167.58222994223394],
#   'Officer_Station_3_Night_12': [22.689268039486258,
#    25.127427489214455,
#    41.72088049998867,
#    44.81070139733387,
#    45.63528915039299,
#    47.45436276523194,
#    66.5805809946441,
#    69.14246656045896,
#    72.36292930789901,
#    91.45824918332254,
#    93.36023060814537,
#    96.13429919993736,
#    115.60261589552681,
#    116.65810812556165,
#    119.11733367781828,
#    121.59768507239468,
#    137.15,
#    138.05414091303288,
#    141.53617757584203,
#    142.88445340419247,
#    162.07010524965554,
#    164.11214935769635,
#    166.16596721964,
#    169.4599706790179],
#   'Officer_Station_3_Night_13': [21.734730547587475,
#    22.453880403202582,
#    24.181867610881397,
#    40.930251453992135,
#    41.794825295082916,
#    43.62587554783026,
#    46.243551889404536,
#    67.38030282503173,
#    69.52192223960179,
#    72.37342612113203,
#    89.7119659028862,
#    91.30786050946942,
#    93.66628346580063,
#    95.58314785936493,
#    114.78432026541901,
#    117.27727002422203,
#    119.55278060255263,
#    138.0628339610188,
#    141.0813011459475,
#    143.46144936430213,
#    162.31859820427928,
#    163.05554926700214,
#    164.27512977867187,
#    166.26496044775314,
#    169.55971994384134],
#   'Officer_Station_3_Night_14': [22.71790862951817,
#    25.101772091379832,
#    42.39419710046507,
#    43.527430050496235,
#    45.937529682892674,
#    48.244303672945215,
#    65.81910580212465,
#    68.6234319529481,
#    71.59068716207611,
#    90.99975920049202,
#    93.1909555438878,
#    95.18289212815543,
#    96.21129927800789,
#    115.53383057327432,
#    117.74421006895834,
#    120.20227396756238,
#    137.09536236678147,
#    137.81785487940786,
#    140.19426948677818,
#    142.70311350015513,
#    162.27495358122903,
#    164.18702630430045,
#    164.81396261646339,
#    165.88364616126023,
#    168.2399261145253],
#   'Officer_Station_3_Night_15': [23.5376576617951,
#    24.548063339249786,
#    42.64334420317016,
#    44.92270567798079,
#    46.829868351511095,
#    65.71115761538347,
#    66.60748342272855,
#    67.80924690773139,
#    69.564112722025,
#    71.69422569869641,
#    89.67663518617833,
#    91.25786050946941,
#    93.0322326190081,
#    96.53179418879274,
#    115.18179665226101,
#    117.11365920381826,
#    118.5092632391861,
#    121.2566417129737,
#    138.63490432496903,
#    140.8779872076788,
#    142.0918008411609,
#    161.516192991632,
#    162.79462522961273,
#    164.93081303366682,
#    165.96345328082427,
#    167.13179418879275],
#   'Officer_Station_3_Night_16': [23.63740640971748,
#    25.41562332024024,
#    41.03924855236777,
#    41.9237919396416,
#    43.96703974023326,
#    44.72143958657113,
#    46.37300889641266,
#    66.70336145834847,
#    68.05540292964031,
#    71.42539646459255,
#    91.47081226147338,
#    92.5556785806076,
#    95.42887606842987,
#    115.2808555810866,
#    116.90387647604662,
#    119.00230084756294,
#    120.3157541283872,
#    137.63432161822124,
#    139.33986681203257,
#    142.10794211319924,
#    162.2754397688895,
#    163.5830173944209,
#    165.19347407973927,
#    167.41188536965296],
#   'Officer_Station_3_Night_17': [22.01603528255484,
#    24.44682083281932,
#    41.663453280824264,
#    44.25743322639653,
#    45.90876856762476,
#    47.844579069945006,
#    66.65056865582781,
#    68.28360525765476,
#    70.46812387288313,
#    91.42797031598049,
#    92.54822460604704,
#    94.17088049998867,
#    95.51160563807908,
#    115.07574280774031,
#    117.3347933374774,
#    119.93729781756552,
#    137.87962988260512,
#    139.31583698431174,
#    140.52149295395324,
#    142.96942443164295,
#    161.30685646306173,
#    162.26668193782044,
#    163.3500879201697,
#    164.70178648646402,
#    167.5061703116564],
#   'Officer_Station_3_Night_18': [22.807383582405905,
#    25.128264082394573,
#    40.75516191309877,
#    42.178878403270915,
#    44.25939498304505,
#    45.90731004901827,
#    48.394386964759676,
#    65.58986681203257,
#    69.01882531756091,
#    72.08347321821383,
#    92.48855453673053,
#    94.31129425686663,
#    96.12437210953868,
#    115.4196536712833,
#    117.8069608759946,
#    119.93211013636189,
#    138.05311350015512,
#    140.06656678097937,
#    140.78317240182542,
#    143.41754065021584,
#    161.6346291271991,
#    163.7508221203319,
#    164.87504382102804,
#    166.90205238086102,
#    167.84350136617692],
#   'Officer_Station_3_Night_19': [22.354362765231944,
#    24.212454896870334,
#    42.44976456494809,
#    43.247042072770604,
#    45.46513583038409,
#    47.889872887905334,
#    66.6678557485114,
#    67.74469610809487,
#    69.60878729288427,
#    71.80230084756293,
#    92.33521619193017,
#    95.2500402067375,
#    97.36437615382705,
#    115.95835560396668,
#    116.99253312016957,
#    118.84416896714123,
#    119.6907251380904,
#    138.05230084756292,
#    140.1572382588053,
#    142.91825643035466,
#    162.3323087468993,
#    164.37729405029074,
#    165.24936871716446,
#    168.67376101965547],
#   'Officer_Station_3_Night_20': [22.94889600651572,
#    23.861284660669835,
#    25.227016497621943,
#    42.18679765052011,
#    43.5666615062915,
#    44.92664186862699,
#    47.21849328312544,
#    67.40876856762476,
#    69.86274468152538,
#    90.78452249430933,
#    92.77632441014461,
#    96.3808651677579,
#    115.1041773215358,
#    117.3232352325277,
#    119.47673846927566,
#    138.00075301456206,
#    138.79176713876257,
#    139.770523066799,
#    140.59931379035973,
#    142.63468163705792,
#    161.55381786194366,
#    162.78907112038783,
#    164.57704485730628,
#    165.74761751359654,
#    168.60810812556167],
#   'Officer_Station_3_Night_21': [22.24739618505766,
#    23.737623330013513,
#    25.25516398022936,
#    42.135430029373346,
#    43.83796056185253,
#    45.659814341959255,
#    47.9457421979386,
#    67.18173912150667,
#    69.89573805839528,
#    91.33213044322652,
#    93.3825603104214,
#    96.26996093072776,
#    115.03626691405775,
#    116.10302481126303,
#    118.83056669796919,
#    120.98823942278062,
#    138.45004020673747,
#    140.80824918332254,
#    142.3590801891435,
#    162.13086516775792,
#    163.4540009916236,
#    164.47031010846956,
#    166.4109777213736,
#    169.02748376173062],
#   'Officer_Station_3_Night_22': [21.795381507180736,
#    23.716008766066764,
#    24.79256345544569,
#    41.52968424948622,
#    42.496612281632586,
#    44.25230084756293,
#    47.32893315854685,
#    67.05071898631027,
#    69.04785188835024,
#    91.97483484681985,
#    94.25475221331162,
#    95.08022192627631,
#    96.4833399830635,
#    114.74802244425608,
#    116.52654258777008,
#    119.17409043271526,
#    121.39820120808173,
#    138.6878306703837,
#    139.85282189419067,
#    141.06783226289923,
#    143.72760948380386,
#    161.7799108543854,
#    162.88966711307032,
#    164.32704485730628,
#    166.2071098906664,
#    169.50699085914778],
#   'Officer_Station_3_Night_23': [22.685904363481605,
#    24.78007333062283,
#    41.61092271691677,
#    43.88755747242489,
#    45.13986681203257,
#    47.73538578541596,
#    66.4209940752765,
#    69.13289212815543,
#    91.41594364766779,
#    92.80666878575819,
#    95.36029268592083,
#    115.49514121559714,
#    117.02840714985246,
#    118.88316886977357,
#    120.27654258777008,
#    138.38067227278216,
#    141.03642550214036,
#    143.75401836498384,
#    162.29208741185403,
#    163.17532036188518,
#    164.5767962741185,
#    166.4572961678288],
#   'Officer_Station_3_Night_24': [22.584223667316884,
#    24.54247285063943,
#    42.442330526569584,
#    43.86069712449583,
#    45.187297817565536,
#    45.9756163408361,
#    46.92985999676867,
#    66.37870318175858,
#    68.66758410533109,
#    69.84394276412397,
#    91.81251763932919,
#    94.13865409542161,
#    95.94240323966697,
#    115.14566637490701,
#    118.28495077711419,
#    121.3233055021642,
#    139.2718576501299,
#    141.01109732503272,
#    161.6520149681895,
#    163.22220647687573,
#    164.2309979560597,
#    165.70457894537063],
#   'Officer_Station_3_Night_25': [23.233496368008513,
#    24.040806417026786,
#    40.7329564094634,
#    42.69291854003046,
#    43.63921945880311,
#    46.18630181115725,
#    70.31345328082426,
#    92.45230084756292,
#    94.90038884497262,
#    96.26919872893365,
#    114.81784864331092,
#    116.68986681203256,
#    118.11212497912365,
#    119.26253742788818,
#    139.06665386211284,
#    139.83437931616456,
#    142.0493380349526,
#    160.7451619032105,
#    163.33738404568493,
#    164.44215844504498],
#   'Officer_Station_3_Night_26': [23.532170982964196,
#    25.465276500156424,
#    43.56857541318165,
#    46.42102145114326,
#    70.40989507910552,
#    92.24872591141317,
#    94.29103256856116,
#    97.10810812556166,
#    115.49752714265534,
#    117.95876856762477,
#    118.86740490782917,
#    120.37207466687373,
#    138.84754847814605,
#    141.13289212815545,
#    162.14120418157705,
#    163.66231568477923,
#    164.91448530722093],
#   'Officer_Station_3_Night_27': [22.018618973551956,
#    23.035822252374395,
#    25.487514485492287,
#    42.85617797918007,
#    44.43289212815543,
#    47.26630332981602,
#    70.19499756684596,
#    91.513637349314,
#    94.56092271691676,
#    97.15638478745564,
#    115.73246936391686,
#    118.96986458875247,
#    119.75230084756294,
#    138.22448296358266,
#    140.83164499461424,
#    160.83611875993032,
#    163.65321209032197,
#    166.40782177156902],
#   'Officer_Station_3_Night_28': [21.567855748511413,
#    22.87898067621315,
#    23.441400712130196,
#    24.384561144214302,
#    42.29903205992164,
#    42.8653277397358,
#    45.276554689378926,
#    46.33019732227394,
#    91.75446124910931,
#    92.6958610384647,
#    96.34729496764167,
#    116.61840372610503,
#    119.42730923992261,
#    138.91868159382406,
#    141.22002909433544,
#    162.055330461086,
#    163.89800178368176,
#    164.82719018623789]},
#  {'Immediate': {'total': 310, 'within_time': 310, 'percentage': 100.0},
#   'Prompt': {'total': 1438,
#    'within_time': 1430,
#    'percentage': 99.44367176634215},
#   'Standard': {'total': 524,
#    'within_time': 520,
#    'percentage': 99.23664122137404}},
#  False)

# %%
naive_model = NaiveModel()
simulation.run(naive_model)

# %%
calculate_simulation_performance(simulation.analyze_simulation_results())
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 calculate_simulation_performance(simulation.analyze_simulation_results())
#
# File ~/Desktop/EdinburghChallenge/edinburgh-challenge/edinburgh_challenge/simulation.py:545, in SimulationWithMaxUtilisation.analyze_simulation_results(self)
#     536 threshold_compliance = {p: (within_threshold_counts[p] / incident_counts[p]) * 100 if resolved_counts[p] > 0 else 0 for p in incident_counts}
#     538 # Calculate officer utilization
#     539 #for station in simulation.officers.values():
#     540 #    for officer in station:
#    (...)
#     543
#     544 #officer_utilization = sum(total_officer_hours.values()) / (len(total_officer_hours) * simulation.current_time) * 100
# --> 545 mean_total_office_hours = sum(total_officer_hours.values())/len(total_officer_hours.values())
#     546 unresolved_incident_percentage = (unresolved_incidents / len(simulation.cumulative_incidents)) * 100 if simulation.cumulative_incidents else 0
#     548 return {
#     549     "Completion Percentages": completion_percentages,
#     550     "Mean Response Times": mean_response_times,
#    (...)
#     555     "Unresolved Incident Percentage": unresolved_incident_percentage
#     556 }
#
# ZeroDivisionError: division by zero

# %%
## Grid searching for best optimisation

shift_distribution = {
    'Early': {'Station_1': 5, 'Station_2': 5, 'Station_3':5},
    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}
}

ps_coords = [ (p.x, p.y) for p in 
                [police_stations.one, 
                 police_stations.two, 
                 police_stations.three]]

# %%
greedy_model = GreedyModel({'Early': {'Station_1': 7, 'Station_2': 0, 'Station_3': 8},
  'Day': {'Station_1': 0, 'Station_2': 0, 'Station_3': 25},
  'Night': {'Station_1': 0, 'Station_2': 11, 'Station_3': 29}
}, police_stations_dict)

simulation = SimulationWithMaxUtilisation(data, ps_coords, {'Early': {'Station_1': 7, 'Station_2': 0, 'Station_3': 8},
  'Day': {'Station_1': 0, 'Station_2': 0, 'Station_3': 25},
  'Night': {'Station_1': 0, 'Station_2': 11, 'Station_3': 29}
}, verbose=1)

# %%
simulation.run(greedy_model)
calculate_simulation_performance(simulation.analyze_simulation_results())
# Out:
# 0.9997734697914059

# %% [markdown]
# ### Best Early Shift

# %%
early_shift_dist = generate_early_shift_distributions(15)
simulation_results = []
for dist in early_shift_dist:
    new_shift_distribution = dict(shift_distribution)
    new_shift_distribution["Early"] = {'Station_1': dist[0], 'Station_2':dist[1], 'Station_3':dist[2]}
    greedy_model = GreedyModel(new_shift_distribution, police_stations_dict)
    simulation = SimulationWithMaxUtilisation(data, ps_coords, new_shift_distribution, verbose=1)
    simulation.run(greedy_model)
    res = simulation.analyze_simulation_results()
    result = calculate_simulation_performance(res)
    simulation_results.append((new_shift_distribution, result))

# %%
sorted_early_simulations = sorted(simulation_results, reverse=True, key=lambda x: x[1])
sorted_early_simulations[0]
# Out:
# ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#   'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#   'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#  0.9995939038366147)

# %%
sorted_early_simulations[0]
# Out:
# ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#   'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
#   'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#  0.9995939038366147)

# %% [markdown]
# ## Best Day Shift

# %%
shift_distribution = {
    'Early': sorted_early_simulations[0][0]["Early"],
    'Day': {'Station_1': 8, 'Station_2': 8, 'Station_3': 9},
    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}
}

# %%
early_shift_dist = generate_early_shift_distributions(25)
simulation_results = []
for dist in early_shift_dist:
    
    new_shift_distribution = dict(shift_distribution)
    new_shift_distribution["Day"] = {'Station_1': dist[0], 'Station_2': dist[1], 'Station_3': dist[2]}
    
    greedy_model = GreedyModel(new_shift_distribution, police_stations_dict)
    
    simulation = SimulationWithMaxUtilisation(data, ps_coords, new_shift_distribution, verbose=1)
    simulation.run(greedy_model)
    
    res = simulation.analyze_simulation_results()
    result = calculate_simulation_performance(res)
    simulation_results.append((new_shift_distribution, result))

# %%
sorted_day_simulations = sorted(simulation_results, reverse=True, key=lambda x: x[1])
sorted_day_simulations[0]
# Out:
# ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#   'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#   'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}},
#  1.000069816584044)

# %% [markdown]
# ## Best Night Shift

# %%
shift_distribution = {
    'Early': sorted_early_simulations[0][0]["Early"],
    'Day': sorted_day_simulations[0][0]["Day"],
    'Night': {'Station_1': 13, 'Station_2': 13, 'Station_3': 14}
}

# %%
early_shift_dist = generate_early_shift_distributions(40)
simulation_results = []
for dist in early_shift_dist:
    
    new_shift_distribution = dict(shift_distribution)
    new_shift_distribution["Night"] = {'Station_1': dist[0], 'Station_2': dist[1], 'Station_3': dist[2]}
    
    greedy_model = GreedyModel(new_shift_distribution, police_stations_dict)
    
    simulation = SimulationWithMaxUtilisation(data, ps_coords, new_shift_distribution, verbose=1)
    simulation.run(greedy_model)
    
    res = simulation.analyze_simulation_results()
    result = calculate_simulation_performance(res)
    simulation_results.append((new_shift_distribution, result))

# %%
sorted_night_simulations = sorted(simulation_results, reverse=True, key=lambda x: x[1])
sorted_night_simulations[0]
# Out:
# ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#   'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#   'Night': {'Station_1': 9, 'Station_2': 3, 'Station_3': 28}},
#  1.0009387771629663)

# %%
sorted_night_simulations
# Out:
# [({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 3, 'Station_3': 28}},
#   1.0009387771629663),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 2, 'Station_3': 29}},
#   1.0009325008659358),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 4, 'Station_3': 27}},
#   1.0009182745659633),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 5, 'Station_3': 26}},
#   1.0009177377699996),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 2, 'Station_3': 28}},
#   1.0009149692008457),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 1, 'Station_3': 30}},
#   1.0009117150068707),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 13, 'Station_3': 27}},
#   1.0009075754894896),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 1, 'Station_3': 29}},
#   1.0009060642538312),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 12, 'Station_3': 28}},
#   1.0008951512098545),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 3, 'Station_3': 27}},
#   1.0008824892546673),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 4, 'Station_3': 26}},
#   1.0008799825690688),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 11, 'Station_3': 29}},
#   1.0008721351214587),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 10, 'Station_3': 30}},
#   1.000859514547518),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 9, 'Station_3': 31}},
#   1.0008556730666176),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 6, 'Station_3': 32}},
#   1.000835004759724),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 7, 'Station_3': 32}},
#   1.0008188149405588),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 6, 'Station_3': 33}},
#   1.000818676094492),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 5, 'Station_3': 34}},
#   1.0008140743737581),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 26, 'Station_3': 3}},
#   1.0007942234491354),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 4, 'Station_3': 23}},
#   1.0007928654641867),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 27, 'Station_3': 2}},
#   1.000780260359961),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 4, 'Station_3': 35}},
#   1.0007762090399024),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 25, 'Station_3': 3}},
#   1.0007740595786947),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 26, 'Station_3': 2}},
#   1.0007596233880518),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 28, 'Station_3': 1}},
#   1.000757007747753),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 27, 'Station_3': 1}},
#   1.0007363707758439),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 24, 'Station_3': 3}},
#   1.000730092183277),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 25, 'Station_3': 2}},
#   1.000719212872168),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 23, 'Station_3': 3}},
#   1.0007015981261573),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 26, 'Station_3': 1}},
#   1.000696136143927),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 24, 'Station_3': 2}},
#   1.000691141054876),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 25, 'Station_3': 1}},
#   1.000668064326635),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 22, 'Station_3': 3}},
#   1.0006670052074846),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 16, 'Station_2': 21, 'Station_3': 3}},
#   1.000658652740256),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 23, 'Station_3': 2}},
#   1.000656216605809),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 15, 'Station_3': 23}},
#   1.0006518250230207),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 16, 'Station_2': 22, 'Station_3': 2}},
#   1.0006478641385805),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 14, 'Station_3': 23}},
#   1.000640106250816),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 24, 'Station_3': 1}},
#   1.0006331398775679),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 1, 'Station_3': 28}},
#   1.0006280541051467),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 20, 'Station_3': 3}},
#   1.000627744608383),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 14, 'Station_3': 21}},
#   1.0006226943299366),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 21, 'Station_3': 2}},
#   1.0006169560067075),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 0, 'Station_3': 29}},
#   1.000614690063353),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 16, 'Station_2': 23, 'Station_3': 1}},
#   1.0006137117784462),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 13, 'Station_3': 23}},
#   1.0006110997895024),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 2, 'Station_3': 27}},
#   1.000605790479388),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 13, 'Station_3': 22}},
#   1.0006045611748802),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 18, 'Station_2': 19, 'Station_3': 3}},
#   1.0006035879771153),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 13, 'Station_3': 21}},
#   1.000599325171362),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 3, 'Station_3': 26}},
#   1.0005989810775202),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 18, 'Station_2': 20, 'Station_3': 2}},
#   1.000595969567329),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 2, 'Station_3': 26}},
#   1.0005830897332015),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 22, 'Station_3': 1}},
#   1.0005828036465731),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 5, 'Station_3': 22}},
#   1.000582654668222),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 0, 'Station_3': 28}},
#   1.0005823650358703),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 1, 'Station_3': 27}},
#   1.0005815892477374),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 12, 'Station_3': 21}},
#   1.000572996684947),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 12, 'Station_3': 22}},
#   1.0005718726020105),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 3, 'Station_3': 24}},
#   1.0005691722999068),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 11, 'Station_3': 19}},
#   1.0005688156834904),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 16, 'Station_3': 22}},
#   1.0005662968269586),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 35, 'Station_3': 3}},
#   1.000561871704863),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 18, 'Station_2': 21, 'Station_3': 1}},
#   1.0005618172071946),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 2, 'Station_3': 25}},
#   1.0005585588987225),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 12, 'Station_3': 18}},
#   1.0005564700146556),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 17, 'Station_3': 23}},
#   1.0005553398779725),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 12, 'Station_3': 23}},
#   1.0005548844386332),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 14, 'Station_3': 26}},
#   1.0005538435149353),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 0, 'Station_3': 27}},
#   1.0005537351711415),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 11, 'Station_3': 21}},
#   1.000552370267413),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 16, 'Station_3': 24}},
#   1.0005506663690196),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 15, 'Station_3': 20}},
#   1.0005498781574944),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 1, 'Station_3': 26}},
#   1.0005490713447243),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 15, 'Station_3': 22}},
#   1.0005483607500387),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 34, 'Station_3': 3}},
#   1.0005468675403095),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 11, 'Station_3': 22}},
#   1.0005461719827038),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 15, 'Station_3': 25}},
#   1.0005444707585487),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 9, 'Station_3': 20}},
#   1.0005292345370025),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 14, 'Station_3': 22}},
#   1.0005275828322242),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 11, 'Station_3': 23}},
#   1.0005261429495345),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 2, 'Station_3': 24}},
#   1.000525140117919),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 33, 'Station_3': 3}},
#   1.0005229800618973),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 10, 'Station_3': 22}},
#   1.000521737112742),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 1, 'Station_3': 25}},
#   1.0005165618304774),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 10, 'Station_3': 21}},
#   1.0005144499070728),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 12, 'Station_3': 27}},
#   1.0005131309082231),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 0, 'Station_3': 26}},
#   1.0005121209432608),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 8, 'Station_3': 20}},
#   1.000511813179835),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 3, 'Station_3': 23}},
#   1.0005089200219501),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 11, 'Station_3': 27}},
#   1.0005083741347225),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 10, 'Station_3': 23}},
#   1.0005064314685375),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 16, 'Station_2': 0, 'Station_3': 24}},
#   1.0005041793499043),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 11, 'Station_3': 28}},
#   1.0005037533882482),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 13, 'Station_3': 20}},
#   1.000503234366491),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 10, 'Station_3': 28}},
#   1.0004996985146533),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 10, 'Station_3': 27}},
#   1.0004971197265342),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 7, 'Station_3': 20}},
#   1.0004910903266764),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 1, 'Station_3': 24}},
#   1.0004872764888177),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 9, 'Station_3': 22}},
#   1.0004867981506926),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 9, 'Station_3': 29}},
#   1.000486640064098),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 12, 'Station_3': 20}},
#   1.0004856286638972),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 9, 'Station_3': 21}},
#   1.000484126871272),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 9, 'Station_3': 28}},
#   1.0004835303590696),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 7, 'Station_3': 31}},
#   1.0004804229004938),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 0, 'Station_3': 25}},
#   1.000479972615447),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 10, 'Station_3': 29}},
#   1.0004793873161737),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 8, 'Station_3': 31}},
#   1.0004777258835786),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 9, 'Station_3': 18}},
#   1.0004762990445861),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 8, 'Station_3': 19}},
#   1.000475816442235),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 9, 'Station_3': 30}},
#   1.0004752717187504),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 9, 'Station_3': 23}},
#   1.00047304755605),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 7, 'Station_3': 29}},
#   1.0004727705782632),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 2, 'Station_3': 23}},
#   1.0004719433113713),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 8, 'Station_3': 30}},
#   1.0004712958932778),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 11, 'Station_3': 20}},
#   1.0004705198598542),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 8, 'Station_3': 28}},
#   1.000469254587172),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 8, 'Station_3': 29}},
#   1.0004691989282224),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 16, 'Station_2': 1, 'Station_3': 23}},
#   1.0004691110978639),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 6, 'Station_3': 30}},
#   1.00046693889025),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 7, 'Station_3': 30}},
#   1.0004668501584786),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 5, 'Station_3': 33}},
#   1.000464099388445),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 9, 'Station_3': 27}},
#   1.000460882741667),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 8, 'Station_3': 22}},
#   1.0004546800602916),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 12, 'Station_3': 19}},
#   1.0004522615624825),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 4, 'Station_3': 32}},
#   1.0004518012491768),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 5, 'Station_3': 31}},
#   1.0004510651704075),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 6, 'Station_3': 31}},
#   1.0004501049518466),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 5, 'Station_3': 32}},
#   1.0004486344521457),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 4, 'Station_3': 34}},
#   1.0004458030870997),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 10, 'Station_3': 20}},
#   1.000444462136225),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 3, 'Station_3': 33}},
#   1.0004429994917257),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 18, 'Station_2': 0, 'Station_3': 22}},
#   1.0004418859114328),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 4, 'Station_3': 33}},
#   1.0004358019145427),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 13, 'Station_3': 18}},
#   1.0004356938669456),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 0, 'Station_3': 23}},
#   1.0004349837672968),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 5, 'Station_3': 35}},
#   1.0004329653217485),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 6, 'Station_3': 20}},
#   1.0004232580385972),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 5, 'Station_3': 30}},
#   1.0004225071743844),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 3, 'Station_3': 34}},
#   1.0004210019710504),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 2, 'Station_3': 34}},
#   1.0004165921517032),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 1, 'Station_3': 35}},
#   1.00041510408014),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 3, 'Station_3': 32}},
#   1.0004112821710867),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 3, 'Station_3': 35}},
#   1.0004104266718998),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 3, 'Station_3': 36}},
#   1.0004099452176565),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 2, 'Station_3': 35}},
#   1.0004080494912024),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 7, 'Station_3': 19}},
#   1.000405805289107),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 8, 'Station_3': 18}},
#   1.0004042526707646),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 2, 'Station_3': 33}},
#   1.0004037740463114),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 19, 'Station_2': 0, 'Station_3': 21}},
#   1.0004019481030095),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 2, 'Station_3': 37}},
#   1.0004010953198408),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 19, 'Station_2': 1, 'Station_3': 20}},
#   1.000398157422829),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 22, 'Station_3': 7}},
#   1.0003981226804188),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 23, 'Station_3': 6}},
#   1.0003954536140245),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 21, 'Station_3': 8}},
#   1.0003945149217384),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 2, 'Station_3': 32}},
#   1.0003942120895195),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 4, 'Station_3': 31}},
#   1.0003929009812156),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 4, 'Station_3': 30}},
#   1.0003910807411496),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 5, 'Station_3': 20}},
#   1.0003903179259934),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 24, 'Station_3': 5}},
#   1.0003892566316255),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 19, 'Station_2': 6, 'Station_3': 15}},
#   1.0003856716097892),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 20, 'Station_3': 8}},
#   1.0003823659961157),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 19, 'Station_2': 5, 'Station_3': 16}},
#   1.0003808462535084),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 1, 'Station_3': 33}},
#   1.0003773597781291),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 21, 'Station_3': 7}},
#   1.0003763361085338),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 3, 'Station_3': 31}},
#   1.0003756676861282),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 19, 'Station_2': 2, 'Station_3': 19}},
#   1.0003755247799462),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 27, 'Station_3': 3}},
#   1.0003748625980373),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 19, 'Station_2': 3, 'Station_3': 18}},
#   1.0003725758600532),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 22, 'Station_3': 6}},
#   1.000372296780408),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 19, 'Station_2': 4, 'Station_3': 17}},
#   1.0003700381671419),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 25, 'Station_3': 4}},
#   1.0003671766345885),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 3, 'Station_3': 30}},
#   1.0003665410447968),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 23, 'Station_3': 5}},
#   1.000366099798009),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 1, 'Station_3': 32}},
#   1.0003660256330151),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 3, 'Station_3': 29}},
#   1.0003657528055032),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 0, 'Station_3': 34}},
#   1.0003641568207868),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 19, 'Station_3': 8}},
#   1.0003633811761934),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 28, 'Station_3': 2}},
#   1.0003608995088629),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 5, 'Station_3': 23}},
#   1.0003592955694331),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 2, 'Station_3': 30}},
#   1.0003591221253916),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 4, 'Station_3': 28}},
#   1.0003568709492623),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 20, 'Station_3': 7}},
#   1.0003481027773233),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 5, 'Station_3': 27}},
#   1.000344801661835),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 12, 'Station_2': 24, 'Station_3': 4}},
#   1.000344019800972),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 2, 'Station_3': 31}},
#   1.0003436821524534),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 1, 'Station_3': 31}},
#   1.0003431154921647),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 21, 'Station_3': 6}},
#   1.0003421291089452),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 17, 'Station_3': 21}},
#   1.000341153781354),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 29, 'Station_3': 1}},
#   1.0003387514941688),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 0, 'Station_3': 33}},
#   1.0003382743242248),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 8, 'Station_2': 0, 'Station_3': 32}},
#   1.0003332583922344),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 9, 'Station_2': 0, 'Station_3': 31}},
#   1.0003282768740784),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 22, 'Station_3': 5}},
#   1.0003196504374585),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 18, 'Station_3': 8}},
#   1.0003194695331723),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 16, 'Station_3': 21}},
#   1.0003171855276867),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 17, 'Station_3': 18}},
#   1.0003158328522936),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 16, 'Station_3': 19}},
#   1.000312720783173),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 20, 'Station_3': 6}},
#   1.000311218072766),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 4, 'Station_2': 15, 'Station_3': 21}},
#   1.0003076257767343),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 5, 'Station_2': 18, 'Station_3': 17}},
#   1.0003068007129434),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 10, 'Station_2': 0, 'Station_3': 30}},
#   1.0003037180475944),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 12, 'Station_3': 11}},
#   1.0003001844717676),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 19, 'Station_3': 7}},
#   1.0002993992896787),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 13, 'Station_2': 23, 'Station_3': 4}},
#   1.0002989961849242),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 13, 'Station_3': 26}},
#   1.0002935732553369),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 13, 'Station_3': 25}},
#   1.000291809656639),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 16, 'Station_3': 23}},
#   1.000291375735678),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 14, 'Station_3': 24}},
#   1.0002912412557206),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 15, 'Station_3': 24}},
#   1.0002894107591367),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 1, 'Station_2': 14, 'Station_3': 25}},
#   1.0002889019757033),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 2, 'Station_2': 12, 'Station_3': 26}},
#   1.000286854533631),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 23, 'Station_3': 11}},
#   1.000286477608418),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 13, 'Station_3': 10}},
#   1.000285681474887),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 14, 'Station_2': 21, 'Station_3': 5}},
#   1.0002851736869827),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 11, 'Station_2': 8, 'Station_3': 21}},
#   1.0002843284967302),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 11, 'Station_3': 12}},
#   1.0002837360677346),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 15, 'Station_2': 17, 'Station_3': 8}},
#   1.0002822433905005),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 22, 'Station_3': 12}},
#   1.00027998940796),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 21, 'Station_3': 12}},
#   1.0002787558794688),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 16, 'Station_2': 16, 'Station_3': 8}},
#   1.0002774649417825),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 13, 'Station_3': 24}},
#   1.0002768139511042),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 17, 'Station_2': 14, 'Station_3': 9}},
#   1.0002742736638575),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 7, 'Station_2': 22, 'Station_3': 11}},
#   1.000273795199804),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 12, 'Station_3': 25}},
#   1.000271695524985),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 6, 'Station_2': 20, 'Station_3': 14}},
#   1.0002716362843649),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 3, 'Station_2': 11, 'Station_3': 26}},
# ...
#    'Night': {'Station_1': 21, 'Station_2': 1, 'Station_3': 18}},
#   0.9993086655444535),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 0, 'Station_2': 0, 'Station_3': 40}},
#   0.9992986902785939),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 21, 'Station_2': 0, 'Station_3': 19}},
#   0.9992985294112099),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 7, 'Station_3': 11}},
#   0.9992858069552386),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 6, 'Station_3': 12}},
#   0.9992818274195988),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 0, 'Station_3': 18}},
#   0.9992755820765702),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 31, 'Station_2': 7, 'Station_3': 2}},
#   0.9992691054798456),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 2, 'Station_3': 16}},
#   0.9992627340913094),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 4, 'Station_3': 14}},
#   0.9992624350356685),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 1, 'Station_3': 17}},
#   0.9992624342747086),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 5, 'Station_3': 13}},
#   0.9992602836192611),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 3, 'Station_3': 15}},
#   0.9992581922590631),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 31, 'Station_2': 8, 'Station_3': 1}},
#   0.99925020717645),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 32, 'Station_2': 6, 'Station_3': 2}},
#   0.9992328833019912),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 23, 'Station_2': 6, 'Station_3': 11}},
#   0.9992227541373682),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 23, 'Station_2': 0, 'Station_3': 17}},
#   0.9992179149644865),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 23, 'Station_2': 5, 'Station_3': 12}},
#   0.9992161231837531),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 32, 'Station_2': 7, 'Station_3': 1}},
#   0.9992139849985955),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 5, 'Station_3': 11}},
#   0.9991952742332356),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 23, 'Station_2': 4, 'Station_3': 13}},
#   0.9991952591553696),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 2, 'Station_3': 14}},
#   0.9991938825802631),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 4, 'Station_3': 12}},
#   0.999191424704033),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 0, 'Station_3': 16}},
#   0.9991811217862304),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 33, 'Station_2': 5, 'Station_3': 2}},
#   0.9991780765947895),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 3, 'Station_3': 13}},
#   0.9991731227919025),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 1, 'Station_3': 15}},
#   0.9991708798409432),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 33, 'Station_2': 6, 'Station_3': 1}},
#   0.9991577078912959),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 25, 'Station_2': 4, 'Station_3': 11}},
#   0.9991461505366901),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 25, 'Station_2': 3, 'Station_3': 12}},
#   0.9991419351336949),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 25, 'Station_2': 1, 'Station_3': 14}},
#   0.999136266934685),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 20, 'Station_2': 10, 'Station_3': 10}},
#   0.9991280463257428),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 25, 'Station_2': 0, 'Station_3': 15}},
#   0.9991175508779685),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 25, 'Station_2': 2, 'Station_3': 13}},
#   0.9991154286980648),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 21, 'Station_2': 9, 'Station_3': 10}},
#   0.9991129687367774),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 35, 'Station_2': 1, 'Station_3': 4}},
#   0.9991048082571172),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 26, 'Station_2': 0, 'Station_3': 14}},
#   0.9990867893422447),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 35, 'Station_2': 2, 'Station_3': 3}},
#   0.9990832193042882),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 35, 'Station_2': 3, 'Station_3': 2}},
#   0.999080675853409),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 26, 'Station_2': 1, 'Station_3': 13}},
#   0.999079453071523),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 23, 'Station_2': 16, 'Station_3': 1}},
#   0.9990680235442018),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 22, 'Station_2': 8, 'Station_3': 10}},
#   0.9990525693888095),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 35, 'Station_2': 0, 'Station_3': 5}},
#   0.9990519960010872),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 26, 'Station_2': 3, 'Station_3': 11}},
#   0.9990443423582898),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 26, 'Station_2': 5, 'Station_3': 9}},
#   0.999039405157751),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 26, 'Station_2': 4, 'Station_3': 10}},
#   0.9990345389640541),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 15, 'Station_3': 1}},
#   0.9990268731204346),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 26, 'Station_2': 2, 'Station_3': 12}},
#   0.9990226204871067),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 36, 'Station_2': 0, 'Station_3': 4}},
#   0.9989998411915618),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 23, 'Station_2': 7, 'Station_3': 10}},
#   0.9989902658436197),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 25, 'Station_2': 14, 'Station_3': 1}},
#   0.9989817049966024),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 36, 'Station_2': 1, 'Station_3': 3}},
#   0.9989719439460685),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 24, 'Station_2': 6, 'Station_3': 10}},
#   0.9989711438362752),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 36, 'Station_2': 2, 'Station_3': 2}},
#   0.9989667370527355),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 26, 'Station_2': 13, 'Station_3': 1}},
#   0.9989505622545556),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 27, 'Station_2': 12, 'Station_3': 1}},
#   0.9989296273137117),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 25, 'Station_2': 5, 'Station_3': 10}},
#   0.9989165730238023),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 28, 'Station_2': 11, 'Station_3': 1}},
#   0.9989095114305142),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 29, 'Station_2': 10, 'Station_3': 1}},
#   0.9988473975258827),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 30, 'Station_2': 8, 'Station_3': 2}},
#   0.9988165820310632),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 30, 'Station_2': 9, 'Station_3': 1}},
#   0.9987986841563757),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 37, 'Station_2': 0, 'Station_3': 3}},
#   0.9987826973387888),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 37, 'Station_2': 1, 'Station_3': 2}},
#   0.9987707697488939),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 34, 'Station_2': 5, 'Station_3': 1}},
#   0.9986371841893555),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 34, 'Station_2': 6, 'Station_3': 0}},
#   0.9986195124629308),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 35, 'Station_2': 4, 'Station_3': 1}},
#   0.9985709752650305),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 35, 'Station_2': 5, 'Station_3': 0}},
#   0.9985555360415382),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 38, 'Station_2': 0, 'Station_3': 2}},
#   0.9985157879370148),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 38, 'Station_2': 1, 'Station_3': 1}},
#   0.9985007502548562),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 39, 'Station_2': 0, 'Station_3': 1}},
#   0.9984511486292748),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 36, 'Station_2': 3, 'Station_3': 1}},
#   0.9983757963456734),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 36, 'Station_2': 4, 'Station_3': 0}},
#   0.9983583130773339),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 37, 'Station_2': 2, 'Station_3': 1}},
#   0.9983260982602239),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 37, 'Station_2': 3, 'Station_3': 0}},
#   0.9977466961714261),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 38, 'Station_2': 2, 'Station_3': 0}},
#   0.9977008410086939),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 39, 'Station_2': 1, 'Station_3': 0}},
#   0.997657472358853),
#  ({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
#    'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
#    'Night': {'Station_1': 40, 'Station_2': 0, 'Station_3': 0}},
#   0.9976056643725647)]

# %%
n = GreedyModel({'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
  'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
  'Night': {'Station_1': 9, 'Station_2': 3, 'Station_3': 28}}, police_stations_dict)

# %%
## Grid searching for best optimisation

shift_distribution = {'Early': {'Station_1': 0, 'Station_2': 5, 'Station_3': 10},
  'Day': {'Station_1': 2, 'Station_2': 19, 'Station_3': 4},
  'Night': {'Station_1': 9, 'Station_2': 3, 'Station_3': 28}}
                      
ps_coords = [ (p.x, p.y) for p in 
                [police_stations.one, 
                 police_stations.two, 
                 police_stations.three]]

simulation = SimulationWithMaxUtilisation(data, ps_coords, shift_distribution, verbose=1)

# %%
simulation.run(n)
calculate_simulation_performance(simulation.analyze_simulation_results())
# Out:
# 0.9973702067085207

# %%
simulation.analyze_simulation_results()
# Out:
# {'Completion Percentages': {'Immediate': 100.0,
#   'Prompt': 100.0,
#   'Standard': 100.0},
#  'Mean Response Times': {'Immediate': 88.36074011402184,
#   'Prompt': 84.70247039510707,
#   'Standard': 88.49373834489559},
#  'Mean Deployment Times': {'Immediate': 1.5403225806451613,
#   'Prompt': 1.5061196105702366,
#   'Standard': 1.4796755725190842},
#  'Threshold Compliance': {'Immediate': 100.0,
#   'Prompt': 99.58275382475661,
#   'Standard': 99.23664122137404},
#  'Mean Officer Hours': 56.9543844529505,
#  'Unresolved Incident Percentage': 0.0}

# %%
8*7
# Out:
# 56
